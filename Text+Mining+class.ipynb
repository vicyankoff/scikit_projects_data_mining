# %% [markdown]
# # Text Mining Class

# %%
import nltk

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# # Module 1: Getting familiar with NLTK

# %% [markdown]
# Concordance view: searching for occurrence of text

# %%
text1.concordance("simple")
# Out:
# Displaying 11 of 11 matches:
# . No , when I go to sea , I go as a simple sailor , right before the mast , pl
# leaping from his eye , made all his simple hearers look on him with a quick fe
# s , I thought I saw the traces of a simple honest heart ; and in his large , d
# to be much distrusted ; but in this simple savage those old rules would not ap
# ight have inferred as much from the simple fact of the accident ." " Look ye n
# hat his bones might be picked , the simple - witted steward all but shattered
# ate , I can tell him . But he ' s a simple old soul ,-- Rad , and a beauty too
# hese Leviathans been but a flock of simple sheep , pursued over the pasture by
# ish as I am , taught thee , a green simple boy , how to splice a rope ! CHAPTE
# ving things tapers off at last into simple child ' s play . CHAPTER 104 The Fo
# antucket commanders ; that from the simple observation of a whale when last de

# %%
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text1.concordance("pasture")
# Out:
# Displaying 4 of 4 matches:
# - pointing to the sea -- is a green pasture where our children ' s grand - chil
#  the morning . In the repose of the pasture , the curled brow of the bull has a
#  of simple sheep , pursued over the pasture by three fierce wolves , they could
# utlast all hunting , since he has a pasture to expatiate in , which is precisel

# %% [markdown]
# Find similar words

# %%
text2.similar("affection")
# Out:
# attention regard time love mother heart wishes opinion marianne
# kindness arrival sister wife conduct behaviour family visit side
# engagement sisters

# %%
text4.similar("affection")
# Out:
# freedom peace justice civilization hope each efficiency manufactures
# that policy property influence restriction all exploits help office
# being over armament

# %% [markdown]
# FInd common contexts

# %%
text2.common_contexts(["monstrous", "very"])
# Out:
# a_pretty is_pretty a_lucky am_glad be_glad

# %%
text2.common_contexts(["time", "affection"])
# Out:
# of_and no_for her_and the_of and_to any_and no_was his_to same_which

# %% [markdown]
# Dispersion plot

# %%
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])

# %% [markdown]
# ## Basic Pre-processing

# %%
len(text3)
# Out:
# 44764

# %%
sorted(set(text3))
# Out:
# [u'!',
#  u"'",
#  u'(',
#  u')',
#  u',',
#  u',)',
#  u'.',
#  u'.)',
#  u':',
#  u';',
#  u';)',
#  u'?',
#  u'?)',
#  u'A',
#  u'Abel',
#  u'Abelmizraim',
#  u'Abidah',
#  u'Abide',
#  u'Abimael',
#  u'Abimelech',
#  u'Abr',
#  u'Abrah',
#  u'Abraham',
#  u'Abram',
#  u'Accad',
#  u'Achbor',
#  u'Adah',
#  u'Adam',
#  u'Adbeel',
#  u'Admah',
#  u'Adullamite',
#  u'After',
#  u'Aholibamah',
#  u'Ahuzzath',
#  u'Ajah',
#  u'Akan',
#  u'All',
#  u'Allonbachuth',
#  u'Almighty',
#  u'Almodad',
#  u'Also',
#  u'Alvah',
#  u'Alvan',
#  u'Am',
#  u'Amal',
#  u'Amalek',
#  u'Amalekites',
#  u'Ammon',
#  u'Amorite',
#  u'Amorites',
#  u'Amraphel',
#  u'An',
#  u'Anah',
#  u'Anamim',
#  u'And',
#  u'Aner',
#  u'Angel',
#  u'Appoint',
#  u'Aram',
#  u'Aran',
#  u'Ararat',
#  u'Arbah',
#  u'Ard',
#  u'Are',
#  u'Areli',
#  u'Arioch',
#  u'Arise',
#  u'Arkite',
#  u'Arodi',
#  u'Arphaxad',
#  u'Art',
#  u'Arvadite',
#  u'As',
#  u'Asenath',
#  u'Ashbel',
#  u'Asher',
#  u'Ashkenaz',
#  u'Ashteroth',
#  u'Ask',
#  u'Asshur',
#  u'Asshurim',
#  u'Assyr',
#  u'Assyria',
#  u'At',
#  u'Atad',
#  u'Avith',
#  u'Baalhanan',
#  u'Babel',
#  u'Bashemath',
#  u'Be',
#  u'Because',
#  u'Becher',
#  u'Bedad',
#  u'Beeri',
#  u'Beerlahairoi',
#  u'Beersheba',
#  u'Behold',
#  u'Bela',
#  u'Belah',
#  u'Benam',
#  u'Benjamin',
#  u'Beno',
#  u'Beor',
#  u'Bera',
#  u'Bered',
#  u'Beriah',
#  u'Bethel',
#  u'Bethlehem',
#  u'Bethuel',
#  u'Beware',
#  u'Bilhah',
#  u'Bilhan',
#  u'Binding',
#  u'Birsha',
#  u'Bless',
#  u'Blessed',
#  u'Both',
#  u'Bow',
#  u'Bozrah',
#  u'Bring',
#  u'But',
#  u'Buz',
#  u'By',
#  u'Cain',
#  u'Cainan',
#  u'Calah',
#  u'Calneh',
#  u'Can',
#  u'Cana',
#  u'Canaan',
#  u'Canaanite',
#  u'Canaanites',
#  u'Canaanitish',
#  u'Caphtorim',
#  u'Carmi',
#  u'Casluhim',
#  u'Cast',
#  u'Cause',
#  u'Chaldees',
#  u'Chedorlaomer',
#  u'Cheran',
#  u'Cherubims',
#  u'Chesed',
#  u'Chezib',
#  u'Come',
#  u'Cursed',
#  u'Cush',
#  u'Damascus',
#  u'Dan',
#  u'Day',
#  u'Deborah',
#  u'Dedan',
#  u'Deliver',
#  u'Diklah',
#  u'Din',
#  u'Dinah',
#  u'Dinhabah',
#  u'Discern',
#  u'Dishan',
#  u'Dishon',
#  u'Do',
#  u'Dodanim',
#  u'Dothan',
#  u'Drink',
#  u'Duke',
#  u'Dumah',
#  u'Earth',
#  u'Ebal',
#  u'Eber',
#  u'Edar',
#  u'Eden',
#  u'Edom',
#  u'Edomites',
#  u'Egy',
#  u'Egypt',
#  u'Egyptia',
#  u'Egyptian',
#  u'Egyptians',
#  u'Ehi',
#  u'Elah',
#  u'Elam',
#  u'Elbethel',
#  u'Eldaah',
#  u'EleloheIsrael',
#  u'Eliezer',
#  u'Eliphaz',
#  u'Elishah',
#  u'Ellasar',
#  u'Elon',
#  u'Elparan',
#  u'Emins',
#  u'En',
#  u'Enmishpat',
#  u'Eno',
#  u'Enoch',
#  u'Enos',
#  u'Ephah',
#  u'Epher',
#  u'Ephra',
#  u'Ephraim',
#  u'Ephrath',
#  u'Ephron',
#  u'Er',
#  u'Erech',
#  u'Eri',
#  u'Es',
#  u'Esau',
#  u'Escape',
#  u'Esek',
#  u'Eshban',
#  u'Eshcol',
#  u'Ethiopia',
#  u'Euphrat',
#  u'Euphrates',
#  u'Eve',
#  u'Even',
#  u'Every',
#  u'Except',
#  u'Ezbon',
#  u'Ezer',
#  u'Fear',
#  u'Feed',
#  u'Fifteen',
#  u'Fill',
#  u'For',
#  u'Forasmuch',
#  u'Forgive',
#  u'From',
#  u'Fulfil',
#  u'G',
#  u'Gad',
#  u'Gaham',
#  u'Galeed',
#  u'Gatam',
#  u'Gather',
#  u'Gaza',
#  u'Gentiles',
#  u'Gera',
#  u'Gerar',
#  u'Gershon',
#  u'Get',
#  u'Gether',
#  u'Gihon',
#  u'Gilead',
#  u'Girgashites',
#  u'Girgasite',
#  u'Give',
#  u'Go',
#  u'God',
#  u'Gomer',
#  u'Gomorrah',
#  u'Goshen',
#  u'Guni',
#  u'Hadad',
#  u'Hadar',
#  u'Hadoram',
#  u'Hagar',
#  u'Haggi',
#  u'Hai',
#  u'Ham',
#  u'Hamathite',
#  u'Hamor',
#  u'Hamul',
#  u'Hanoch',
#  u'Happy',
#  u'Haran',
#  u'Hast',
#  u'Haste',
#  u'Have',
#  u'Havilah',
#  u'Hazarmaveth',
#  u'Hazezontamar',
#  u'Hazo',
#  u'He',
#  u'Hear',
#  u'Heaven',
#  u'Heber',
#  u'Hebrew',
#  u'Hebrews',
#  u'Hebron',
#  u'Hemam',
#  u'Hemdan',
#  u'Here',
#  u'Hereby',
#  u'Heth',
#  u'Hezron',
#  u'Hiddekel',
#  u'Hinder',
#  u'Hirah',
#  u'His',
#  u'Hitti',
#  u'Hittite',
#  u'Hittites',
#  u'Hivite',
#  u'Hobah',
#  u'Hori',
#  u'Horite',
#  u'Horites',
#  u'How',
#  u'Hul',
#  u'Huppim',
#  u'Husham',
#  u'Hushim',
#  u'Huz',
#  u'I',
#  u'If',
#  u'In',
#  u'Irad',
#  u'Iram',
#  u'Is',
#  u'Isa',
#  u'Isaac',
#  u'Iscah',
#  u'Ishbak',
#  u'Ishmael',
#  u'Ishmeelites',
#  u'Ishuah',
#  u'Isra',
#  u'Israel',
#  u'Issachar',
#  u'Isui',
#  u'It',
#  u'Ithran',
#  u'Jaalam',
#  u'Jabal',
#  u'Jabbok',
#  u'Jac',
#  u'Jachin',
#  u'Jacob',
#  u'Jahleel',
#  u'Jahzeel',
#  u'Jamin',
#  u'Japhe',
#  u'Japheth',
#  u'Jared',
#  u'Javan',
#  u'Jebusite',
#  u'Jebusites',
#  u'Jegarsahadutha',
#  u'Jehovahjireh',
#  u'Jemuel',
#  u'Jerah',
#  u'Jetheth',
#  u'Jetur',
#  u'Jeush',
#  u'Jezer',
#  u'Jidlaph',
#  u'Jimnah',
#  u'Job',
#  u'Jobab',
#  u'Jokshan',
#  u'Joktan',
#  u'Jordan',
#  u'Joseph',
#  u'Jubal',
#  u'Judah',
#  u'Judge',
#  u'Judith',
#  u'Kadesh',
#  u'Kadmonites',
#  u'Karnaim',
#  u'Kedar',
#  u'Kedemah',
#  u'Kemuel',
#  u'Kenaz',
#  u'Kenites',
#  u'Kenizzites',
#  u'Keturah',
#  u'Kiriathaim',
#  u'Kirjatharba',
#  u'Kittim',
#  u'Know',
#  u'Kohath',
#  u'Kor',
#  u'Korah',
#  u'LO',
#  u'LORD',
#  u'Laban',
#  u'Lahairoi',
#  u'Lamech',
#  u'Lasha',
#  u'Lay',
#  u'Leah',
#  u'Lehabim',
#  u'Lest',
#  u'Let',
#  u'Letushim',
#  u'Leummim',
#  u'Levi',
#  u'Lie',
#  u'Lift',
#  u'Lo',
#  u'Look',
#  u'Lot',
#  u'Lotan',
#  u'Lud',
#  u'Ludim',
#  u'Luz',
#  u'Maachah',
#  u'Machir',
#  u'Machpelah',
#  u'Madai',
#  u'Magdiel',
#  u'Magog',
#  u'Mahalaleel',
#  u'Mahalath',
#  u'Mahanaim',
#  u'Make',
#  u'Malchiel',
#  u'Male',
#  u'Mam',
#  u'Mamre',
#  u'Man',
#  u'Manahath',
#  u'Manass',
#  u'Manasseh',
#  u'Mash',
#  u'Masrekah',
#  u'Massa',
#  u'Matred',
#  u'Me',
#  u'Medan',
#  u'Mehetabel',
#  u'Mehujael',
#  u'Melchizedek',
#  u'Merari',
#  u'Mesha',
#  u'Meshech',
#  u'Mesopotamia',
#  u'Methusa',
#  u'Methusael',
#  u'Methuselah',
#  u'Mezahab',
#  u'Mibsam',
#  u'Mibzar',
#  u'Midian',
#  u'Midianites',
#  u'Milcah',
#  u'Mishma',
#  u'Mizpah',
#  u'Mizraim',
#  u'Mizz',
#  u'Moab',
#  u'Moabites',
#  u'Moreh',
#  u'Moreover',
#  u'Moriah',
#  u'Muppim',
#  u'My',
#  u'Naamah',
#  u'Naaman',
#  u'Nahath',
#  u'Nahor',
#  u'Naphish',
#  u'Naphtali',
#  u'Naphtuhim',
#  u'Nay',
#  u'Nebajoth',
#  u'Neither',
#  u'Night',
#  u'Nimrod',
#  u'Nineveh',
#  u'Noah',
#  u'Nod',
#  u'Not',
#  u'Now',
#  u'O',
#  u'Obal',
#  u'Of',
#  u'Oh',
#  u'Ohad',
#  u'Omar',
#  u'On',
#  u'Onam',
#  u'Onan',
#  u'Only',
#  u'Ophir',
#  u'Our',
#  u'Out',
#  u'Padan',
#  u'Padanaram',
#  u'Paran',
#  u'Pass',
#  u'Pathrusim',
#  u'Pau',
#  u'Peace',
#  u'Peleg',
#  u'Peniel',
#  u'Penuel',
#  u'Peradventure',
#  u'Perizzit',
#  u'Perizzite',
#  u'Perizzites',
#  u'Phallu',
#  u'Phara',
#  u'Pharaoh',
#  u'Pharez',
#  u'Phichol',
#  u'Philistim',
#  u'Philistines',
#  u'Phut',
#  u'Phuvah',
#  u'Pildash',
#  u'Pinon',
#  u'Pison',
#  u'Potiphar',
#  u'Potipherah',
#  u'Put',
#  u'Raamah',
#  u'Rachel',
#  u'Rameses',
#  u'Rebek',
#  u'Rebekah',
#  u'Rehoboth',
#  u'Remain',
#  u'Rephaims',
#  u'Resen',
#  u'Return',
#  u'Reu',
#  u'Reub',
#  u'Reuben',
#  u'Reuel',
#  u'Reumah',
#  u'Riphath',
#  u'Rosh',
#  u'Sabtah',
#  u'Sabtech',
#  u'Said',
#  u'Salah',
#  u'Salem',
#  u'Samlah',
#  u'Sarah',
#  u'Sarai',
#  u'Saul',
#  u'Save',
#  u'Say',
#  u'Se',
#  u'Seba',
#  u'See',
#  u'Seeing',
#  u'Seir',
#  u'Sell',
#  u'Send',
#  u'Sephar',
#  u'Serah',
#  u'Sered',
#  u'Serug',
#  u'Set',
#  u'Seth',
#  u'Shalem',
#  u'Shall',
#  u'Shalt',
#  u'Shammah',
#  u'Shaul',
#  u'Shaveh',
#  u'She',
#  u'Sheba',
#  u'Shebah',
#  u'Shechem',
#  u'Shed',
#  u'Shel',
#  u'Shelah',
#  u'Sheleph',
#  u'Shem',
#  u'Shemeber',
#  u'Shepho',
#  u'Shillem',
#  u'Shiloh',
#  u'Shimron',
#  u'Shinab',
#  u'Shinar',
#  u'Shobal',
#  u'Should',
#  u'Shuah',
#  u'Shuni',
#  u'Shur',
#  u'Sichem',
#  u'Siddim',
#  u'Sidon',
#  u'Simeon',
#  u'Sinite',
#  u'Sitnah',
#  u'Slay',
#  u'So',
#  u'Sod',
#  u'Sodom',
#  u'Sojourn',
#  u'Some',
#  u'Spake',
#  u'Speak',
#  u'Spirit',
#  u'Stand',
#  u'Succoth',
#  u'Surely',
#  u'Swear',
#  u'Syrian',
#  u'Take',
#  u'Tamar',
#  u'Tarshish',
#  u'Tebah',
#  u'Tell',
#  u'Tema',
#  u'Teman',
#  u'Temani',
#  u'Terah',
#  u'Thahash',
#  u'That',
#  u'The',
#  u'Then',
#  u'There',
#  u'Therefore',
#  u'These',
#  u'They',
#  u'Thirty',
#  u'This',
#  u'Thorns',
#  u'Thou',
#  u'Thus',
#  u'Thy',
#  u'Tidal',
#  u'Timna',
#  u'Timnah',
#  u'Timnath',
#  u'Tiras',
#  u'To',
#  u'Togarmah',
#  u'Tola',
#  u'Tubal',
#  u'Tubalcain',
#  u'Twelve',
#  u'Two',
#  u'Unstable',
#  u'Until',
#  u'Unto',
#  u'Up',
#  u'Upon',
#  u'Ur',
#  u'Uz',
#  u'Uzal',
#  u'We',
#  u'What',
#  u'When',
#  u'Whence',
#  u'Where',
#  u'Whereas',
#  u'Wherefore',
#  u'Which',
#  u'While',
#  u'Who',
#  u'Whose',
#  u'Whoso',
#  u'Why',
#  u'Wilt',
#  u'With',
#  u'Woman',
#  u'Ye',
#  u'Yea',
#  u'Yet',
#  u'Zaavan',
#  u'Zaphnathpaaneah',
#  u'Zar',
#  u'Zarah',
#  u'Zeboiim',
#  u'Zeboim',
#  u'Zebul',
#  u'Zebulun',
#  u'Zemarite',
#  u'Zepho',
#  u'Zerah',
#  u'Zibeon',
#  u'Zidon',
#  u'Zillah',
#  u'Zilpah',
#  u'Zimran',
#  u'Ziphion',
#  u'Zo',
#  u'Zoar',
#  u'Zohar',
#  u'Zuzims',
#  u'a',
#  u'abated',
#  u'abide',
#  u'able',
#  u'abode',
#  u'abomination',
#  u'about',
#  u'above',
#  u'abroad',
#  u'absent',
#  u'abundantly',
#  u'accept',
#  u'accepted',
#  u'according',
#  u'acknowledged',
#  u'activity',
#  u'add',
#  u'adder',
#  u'afar',
#  u'afflict',
#  u'affliction',
#  u'afraid',
#  u'after',
#  u'afterward',
#  u'afterwards',
#  u'aga',
#  u'again',
#  u'against',
#  u'age',
#  u'aileth',
#  u'air',
#  u'al',
#  u'alive',
#  u'all',
#  u'almon',
#  u'alo',
#  u'alone',
#  u'aloud',
#  u'also',
#  u'altar',
#  u'altogether',
#  u'always',
#  u'am',
#  u'among',
#  u'amongst',
#  u'an',
#  u'and',
#  u'angel',
#  u'angels',
#  u'anger',
#  u'angry',
#  u'anguish',
#  u'anointedst',
#  u'anoth',
#  u'another',
#  u'answer',
#  u'answered',
#  u'any',
#  u'anything',
#  u'appe',
#  u'appear',
#  u'appeared',
#  u'appease',
#  u'appoint',
#  u'appointed',
#  u'aprons',
#  u'archer',
#  u'archers',
#  u'are',
#  u'arise',
#  u'ark',
#  u'armed',
#  u'arms',
#  u'army',
#  u'arose',
#  u'arrayed',
#  u'art',
#  u'artificer',
#  u'as',
#  u'ascending',
#  u'ash',
#  u'ashamed',
#  u'ask',
#  u'asked',
#  u'asketh',
#  u'ass',
#  u'assembly',
#  u'asses',
#  u'assigned',
#  u'asswaged',
#  u'at',
#  u'attained',
#  u'audience',
#  u'avenged',
#  u'aw',
#  u'awaked',
#  u'away',
#  u'awoke',
#  u'back',
#  u'backward',
#  u'bad',
#  u'bade',
#  u'badest',
#  u'badne',
#  u'bak',
#  u'bake',
#  u'bakemeats',
#  u'baker',
#  u'bakers',
#  u'balm',
#  u'bands',
#  u'bank',
#  u'bare',
#  u'barr',
#  u'barren',
#  u'basket',
#  u'baskets',
#  u'battle',
#  u'bdellium',
#  u'be',
#  u'bear',
#  u'beari',
#  u'bearing',
#  u'beast',
#  u'beasts',
#  u'beautiful',
#  u'became',
#  u'because',
#  u'become',
#  u'bed',
#  u'been',
#  u'befall',
#  u'befell',
#  u'before',
#  u'began',
#  u'begat',
#  u'beget',
#  u'begettest',
#  u'begin',
#  u'beginning',
#  u'begotten',
#  u'beguiled',
#  u'beheld',
#  u'behind',
#  u'behold',
#  u'being',
#  u'believed',
#  u'belly',
#  u'belong',
#  u'beneath',
#  u'bereaved',
#  u'beside',
#  u'besides',
#  u'besought',
#  u'best',
#  u'betimes',
#  u'better',
#  u'between',
#  u'betwixt',
#  u'beyond',
#  u'binding',
#  u'bird',
#  u'birds',
#  u'birthday',
#  u'birthright',
#  u'biteth',
#  u'bitter',
#  u'blame',
#  u'blameless',
#  u'blasted',
#  u'bless',
#  u'blessed',
#  u'blesseth',
#  u'blessi',
#  u'blessing',
#  u'blessings',
#  u'blindness',
#  u'blood',
#  u'blossoms',
#  u'bodies',
#  u'boldly',
#  u'bondman',
#  u'bondmen',
#  u'bondwoman',
#  u'bone',
#  u'bones',
#  u'book',
#  u'booths',
#  u'border',
#  u'borders',
#  u'born',
#  u'bosom',
#  u'both',
#  u'bottle',
#  u'bou',
#  u'boug',
#  u'bough',
#  u'bought',
#  u'bound',
#  u'bow',
#  u'bowed',
#  u'bowels',
#  u'bowing',
#  u'boys',
#  u'bracelets',
#  u'branches',
#  u'brass',
#  u'bre',
#  u'breach',
#  u'bread',
#  u'breadth',
#  u'break',
#  u'breaketh',
#  u'breaking',
#  u'breasts',
#  u'breath',
#  u'breathed',
#  u'breed',
#  u'brethren',
#  u'brick',
#  u'brimstone',
#  u'bring',
#  u'brink',
#  u'broken',
#  u'brook',
#  u'broth',
#  u'brother',
#  u'brought',
#  u'brown',
#  u'bruise',
#  u'budded',
#  u'build',
#  u'builded',
#  u'built',
#  u'bulls',
#  u'bundle',
#  u'bundles',
#  u'burdens',
#  u'buried',
#  u'burn',
#  u'burning',
#  u'burnt',
#  u'bury',
#  u'buryingplace',
#  u'business',
#  u'but',
#  u'butler',
#  u'butlers',
#  u'butlership',
#  u'butter',
#  u'buy',
#  u'by',
#  u'cakes',
#  u'calf',
#  u'call',
#  u'called',
#  u'came',
#  u'camel',
#  u'camels',
#  u'camest',
#  u'can',
#  u'cannot',
#  u'canst',
#  u'captain',
#  u'captive',
#  u'captives',
#  u'carcases',
#  u'carried',
#  u'carry',
#  u'cast',
#  u'castles',
#  u'catt',
#  u'cattle',
#  u'caught',
#  u'cause',
#  u'caused',
#  u'cave',
#  u'cease',
#  u'ceased',
#  u'certain',
#  u'certainly',
#  u'chain',
#  u'chamber',
#  u'change',
#  u'changed',
#  u'changes',
#  u'charge',
#  u'charged',
#  u'chariot',
#  u'chariots',
#  u'chesnut',
#  u'chi',
#  u'chief',
#  u'child',
#  u'childless',
#  u'childr',
#  u'children',
#  u'chode',
#  u'choice',
#  u'chose',
#  u'circumcis',
#  u'circumcise',
#  u'circumcised',
#  u'citi',
#  u'cities',
#  u'city',
#  u'clave',
#  u'clean',
#  u'clear',
#  u'cleave',
#  u'clo',
#  u'closed',
#  u'clothed',
#  u'clothes',
#  u'cloud',
#  u'clusters',
#  u'co',
#  u'coat',
#  u'coats',
#  u'coffin',
#  u'cold',
#  ...]

# %% [markdown]
# Lexical richness

# %%
from __future__ import division
len(set(text3)) / len(text3)
# Out:
# 0.06230453042623537

# %% [markdown]
# Find out the lexical richness of text2.

# %%
len(set(text2)) / len(text2)
# Out:
# 0.04826383002768831

# %% [markdown]
# How many times does the word "affection" appear in text2? How much is this as a percentage of the total number of words in this text?

# %%
text2.count("affection")
100 * text4.count('a') / len(text4)
# Out:
# 1.4643016433938312

# %% [markdown]
# # Module 2: Text corpora

# %% [markdown]
# ## Gutenberg corpus

# %% [markdown]
# Import Gutenberg corpus

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# [u'austen-emma.txt',
#  u'austen-persuasion.txt',
#  u'austen-sense.txt',
#  u'bible-kjv.txt',
#  u'blake-poems.txt',
#  u'bryant-stories.txt',
#  u'burgess-busterbrown.txt',
#  u'carroll-alice.txt',
#  u'chesterton-ball.txt',
#  u'chesterton-brown.txt',
#  u'chesterton-thursday.txt',
#  u'edgeworth-parents.txt',
#  u'melville-moby_dick.txt',
#  u'milton-paradise.txt',
#  u'shakespeare-caesar.txt',
#  u'shakespeare-hamlet.txt',
#  u'shakespeare-macbeth.txt',
#  u'whitman-leaves.txt']

# %%
emma = gutenberg.words('austen-emma.txt')

# %%
emma
# Out:
# [u'[', u'Emma', u'by', u'Jane', u'Austen', u'1816', ...]

# %% [markdown]
# Problem: Write a python script to loop over gutenberg files and print
# 1. number of characters
# 2. number of words
# 3. number of sentences
# 4. length of vocabulary
# 5. filename
# for each file.

# %%
for fileid in gutenberg.fileids():
    num_chars = len(gutenberg.raw(fileid))
    num_words = len(gutenberg.words(fileid))
    num_sents = len(gutenberg.sents(fileid))
    num_vocab = len(set(w.lower() for w in gutenberg.words(fileid)))
    print(round(num_chars/num_words), round(num_words/num_sents), round(num_words/num_vocab), fileid)
# Out:
# (5.0, 25.0, 26.0, u'austen-emma.txt')
# (5.0, 26.0, 17.0, u'austen-persuasion.txt')
# (5.0, 28.0, 22.0, u'austen-sense.txt')
# (4.0, 34.0, 79.0, u'bible-kjv.txt')
# (5.0, 19.0, 5.0, u'blake-poems.txt')
# (4.0, 19.0, 14.0, u'bryant-stories.txt')
# (4.0, 18.0, 12.0, u'burgess-busterbrown.txt')
# (4.0, 20.0, 13.0, u'carroll-alice.txt')
# (5.0, 20.0, 12.0, u'chesterton-ball.txt')
# (5.0, 23.0, 11.0, u'chesterton-brown.txt')
# (5.0, 18.0, 11.0, u'chesterton-thursday.txt')
# (4.0, 21.0, 25.0, u'edgeworth-parents.txt')
# (5.0, 26.0, 15.0, u'melville-moby_dick.txt')
# (5.0, 52.0, 11.0, u'milton-paradise.txt')
# (4.0, 12.0, 9.0, u'shakespeare-caesar.txt')
# (4.0, 12.0, 8.0, u'shakespeare-hamlet.txt')
# (4.0, 12.0, 7.0, u'shakespeare-macbeth.txt')
# (5.0, 36.0, 12.0, u'whitman-leaves.txt')

# %%
from nltk.corpus import brown
for fileid in brown.fileids():
    num_chars = len(brown.raw(fileid))
    num_words = len(brown.words(fileid))
    num_sents = len(brown.sents(fileid))
    num_vocab = len(set(w.lower() for w in brown.words(fileid)))
    print(round(num_chars/num_words), round(num_words/num_sents), round(num_words/num_vocab), fileid)
# Out:
# (9.0, 23.0, 3.0, u'ca01')
# (9.0, 23.0, 3.0, u'ca02')
# (9.0, 20.0, 3.0, u'ca03')
# (9.0, 25.0, 3.0, u'ca04')
# (9.0, 27.0, 3.0, u'ca05')
# (9.0, 23.0, 3.0, u'ca06')
# (9.0, 19.0, 3.0, u'ca07')
# (9.0, 22.0, 3.0, u'ca08')
# (9.0, 20.0, 3.0, u'ca09')
# (9.0, 22.0, 3.0, u'ca10')
# (9.0, 23.0, 3.0, u'ca11')
# (8.0, 22.0, 3.0, u'ca12')
# (9.0, 21.0, 3.0, u'ca13')
# (9.0, 18.0, 3.0, u'ca14')
# (8.0, 21.0, 3.0, u'ca15')
# (8.0, 20.0, 2.0, u'ca16')
# (8.0, 22.0, 3.0, u'ca17')
# (9.0, 22.0, 3.0, u'ca18')
# (9.0, 20.0, 3.0, u'ca19')
# (9.0, 24.0, 3.0, u'ca20')
# (9.0, 20.0, 3.0, u'ca21')
# (9.0, 22.0, 3.0, u'ca22')
# (9.0, 21.0, 2.0, u'ca23')
# (9.0, 23.0, 3.0, u'ca24')
# (9.0, 22.0, 2.0, u'ca25')
# (9.0, 21.0, 3.0, u'ca26')
# (9.0, 20.0, 3.0, u'ca27')
# (9.0, 24.0, 3.0, u'ca28')
# (9.0, 20.0, 2.0, u'ca29')
# (9.0, 19.0, 3.0, u'ca30')
# (9.0, 20.0, 2.0, u'ca31')
# (9.0, 19.0, 2.0, u'ca32')
# (9.0, 25.0, 3.0, u'ca33')
# (9.0, 24.0, 3.0, u'ca34')
# (9.0, 30.0, 3.0, u'ca35')
# (9.0, 26.0, 3.0, u'ca36')
# (9.0, 24.0, 3.0, u'ca37')
# (8.0, 23.0, 3.0, u'ca38')
# (8.0, 19.0, 3.0, u'ca39')
# (9.0, 24.0, 2.0, u'ca40')
# (9.0, 22.0, 3.0, u'ca41')
# (9.0, 22.0, 3.0, u'ca42')
# (9.0, 18.0, 3.0, u'ca43')
# (9.0, 25.0, 3.0, u'ca44')
# (9.0, 21.0, 2.0, u'cb01')
# (9.0, 24.0, 3.0, u'cb02')
# (9.0, 23.0, 3.0, u'cb03')
# (9.0, 19.0, 2.0, u'cb04')
# (9.0, 21.0, 2.0, u'cb05')
# (9.0, 23.0, 3.0, u'cb06')
# (9.0, 24.0, 3.0, u'cb07')
# (8.0, 19.0, 3.0, u'cb08')
# (8.0, 18.0, 3.0, u'cb09')
# (8.0, 17.0, 3.0, u'cb10')
# (9.0, 21.0, 2.0, u'cb11')
# (9.0, 22.0, 3.0, u'cb12')
# (9.0, 16.0, 2.0, u'cb13')
# (9.0, 19.0, 3.0, u'cb14')
# (9.0, 23.0, 3.0, u'cb15')
# (9.0, 19.0, 3.0, u'cb16')
# (9.0, 18.0, 3.0, u'cb17')
# (9.0, 19.0, 3.0, u'cb18')
# (9.0, 17.0, 3.0, u'cb19')
# (9.0, 21.0, 3.0, u'cb20')
# (9.0, 29.0, 3.0, u'cb21')
# (9.0, 24.0, 3.0, u'cb22')
# (8.0, 18.0, 3.0, u'cb23')
# (9.0, 22.0, 2.0, u'cb24')
# (9.0, 30.0, 3.0, u'cb25')
# (9.0, 21.0, 3.0, u'cb26')
# (9.0, 21.0, 3.0, u'cb27')
# (9.0, 21.0, 2.0, u'cc01')
# (9.0, 23.0, 3.0, u'cc02')
# (9.0, 21.0, 3.0, u'cc03')
# (9.0, 23.0, 3.0, u'cc04')
# (9.0, 23.0, 2.0, u'cc05')
# (9.0, 29.0, 3.0, u'cc06')
# (9.0, 20.0, 3.0, u'cc07')
# (9.0, 26.0, 3.0, u'cc08')
# (9.0, 26.0, 3.0, u'cc09')
# (9.0, 22.0, 3.0, u'cc10')
# (9.0, 23.0, 3.0, u'cc11')
# (9.0, 25.0, 3.0, u'cc12')
# (9.0, 24.0, 3.0, u'cc13')
# (9.0, 25.0, 3.0, u'cc14')
# (9.0, 20.0, 2.0, u'cc15')
# (9.0, 24.0, 3.0, u'cc16')
# (9.0, 23.0, 3.0, u'cc17')
# (8.0, 26.0, 3.0, u'cd01')
# (9.0, 35.0, 3.0, u'cd02')
# (9.0, 28.0, 3.0, u'cd03')
# (8.0, 24.0, 4.0, u'cd04')
# (9.0, 34.0, 3.0, u'cd05')
# (8.0, 26.0, 3.0, u'cd06')
# (8.0, 19.0, 3.0, u'cd07')
# (9.0, 32.0, 3.0, u'cd08')
# (9.0, 14.0, 3.0, u'cd09')
# (9.0, 23.0, 3.0, u'cd10')
# (8.0, 34.0, 3.0, u'cd11')
# (9.0, 28.0, 3.0, u'cd12')
# (8.0, 22.0, 3.0, u'cd13')
# (9.0, 24.0, 3.0, u'cd14')
# (9.0, 23.0, 3.0, u'cd15')
# (8.0, 14.0, 5.0, u'cd16')
# (8.0, 16.0, 3.0, u'cd17')
# (9.0, 22.0, 3.0, u'ce01')
# (8.0, 18.0, 3.0, u'ce02')
# (9.0, 23.0, 3.0, u'ce03')
# (9.0, 24.0, 3.0, u'ce04')
# (9.0, 20.0, 3.0, u'ce05')
# (9.0, 24.0, 3.0, u'ce06')
# (8.0, 18.0, 4.0, u'ce07')
# (9.0, 17.0, 4.0, u'ce08')
# (8.0, 17.0, 3.0, u'ce09')
# (8.0, 18.0, 3.0, u'ce10')
# (8.0, 21.0, 3.0, u'ce11')
# (9.0, 19.0, 3.0, u'ce12')
# (9.0, 30.0, 3.0, u'ce13')
# (8.0, 14.0, 3.0, u'ce14')
# (8.0, 12.0, 4.0, u'ce15')
# (8.0, 17.0, 3.0, u'ce16')
# (8.0, 20.0, 3.0, u'ce17')
# (9.0, 28.0, 3.0, u'ce18')
# (8.0, 21.0, 3.0, u'ce19')
# (9.0, 18.0, 3.0, u'ce20')
# (8.0, 20.0, 4.0, u'ce21')
# (9.0, 22.0, 3.0, u'ce22')
# (8.0, 26.0, 3.0, u'ce23')
# (8.0, 18.0, 3.0, u'ce24')
# (9.0, 24.0, 3.0, u'ce25')
# (9.0, 25.0, 3.0, u'ce26')
# (9.0, 12.0, 4.0, u'ce27')
# (9.0, 18.0, 3.0, u'ce28')
# (9.0, 25.0, 3.0, u'ce29')
# (9.0, 15.0, 3.0, u'ce30')
# (9.0, 22.0, 3.0, u'ce31')
# (9.0, 20.0, 3.0, u'ce32')
# (9.0, 20.0, 3.0, u'ce33')
# (9.0, 21.0, 3.0, u'ce34')
# (9.0, 20.0, 3.0, u'ce35')
# (9.0, 30.0, 3.0, u'ce36')
# (9.0, 32.0, 3.0, u'cf01')
# (9.0, 18.0, 3.0, u'cf02')
# (9.0, 30.0, 3.0, u'cf03')
# (9.0, 18.0, 3.0, u'cf04')
# (9.0, 25.0, 3.0, u'cf05')
# (8.0, 15.0, 3.0, u'cf06')
# (9.0, 24.0, 3.0, u'cf07')
# (9.0, 21.0, 3.0, u'cf08')
# (8.0, 17.0, 3.0, u'cf09')
# (9.0, 23.0, 3.0, u'cf10')
# (9.0, 20.0, 3.0, u'cf11')
# (8.0, 25.0, 3.0, u'cf12')
# (8.0, 17.0, 4.0, u'cf13')
# (9.0, 33.0, 3.0, u'cf14')
# (9.0, 27.0, 3.0, u'cf15')
# (8.0, 19.0, 3.0, u'cf16')
# (9.0, 30.0, 3.0, u'cf17')
# (8.0, 23.0, 3.0, u'cf18')
# (9.0, 26.0, 3.0, u'cf19')
# (9.0, 25.0, 2.0, u'cf20')
# (9.0, 21.0, 3.0, u'cf21')
# (9.0, 21.0, 3.0, u'cf22')
# (9.0, 23.0, 3.0, u'cf23')
# (8.0, 16.0, 3.0, u'cf24')
# (9.0, 21.0, 3.0, u'cf25')
# (8.0, 19.0, 3.0, u'cf26')
# (8.0, 27.0, 3.0, u'cf27')
# (9.0, 24.0, 3.0, u'cf28')
# (9.0, 23.0, 2.0, u'cf29')
# (9.0, 24.0, 3.0, u'cf30')
# (8.0, 21.0, 3.0, u'cf31')
# (8.0, 21.0, 3.0, u'cf32')
# (9.0, 25.0, 3.0, u'cf33')
# (9.0, 20.0, 3.0, u'cf34')
# (8.0, 25.0, 3.0, u'cf35')
# (8.0, 19.0, 3.0, u'cf36')
# (9.0, 24.0, 3.0, u'cf37')
# (8.0, 40.0, 3.0, u'cf38')
# (9.0, 31.0, 3.0, u'cf39')
# (9.0, 26.0, 3.0, u'cf40')
# (9.0, 23.0, 3.0, u'cf41')
# (8.0, 22.0, 3.0, u'cf42')
# (8.0, 24.0, 3.0, u'cf43')
# (9.0, 23.0, 4.0, u'cf44')
# (9.0, 23.0, 3.0, u'cf45')
# (9.0, 20.0, 2.0, u'cf46')
# (8.0, 21.0, 3.0, u'cf47')
# (9.0, 39.0, 3.0, u'cf48')
# (9.0, 23.0, 3.0, u'cg01')
# (9.0, 26.0, 3.0, u'cg02')
# (9.0, 20.0, 3.0, u'cg03')
# (8.0, 16.0, 3.0, u'cg04')
# (8.0, 25.0, 3.0, u'cg05')
# (9.0, 22.0, 3.0, u'cg06')
# (9.0, 27.0, 3.0, u'cg07')
# (9.0, 26.0, 3.0, u'cg08')
# (9.0, 21.0, 3.0, u'cg09')
# (9.0, 32.0, 4.0, u'cg10')
# (9.0, 24.0, 3.0, u'cg11')
# (8.0, 16.0, 3.0, u'cg12')
# (9.0, 22.0, 3.0, u'cg13')
# (8.0, 24.0, 3.0, u'cg14')
# (8.0, 27.0, 3.0, u'cg15')
# (9.0, 30.0, 3.0, u'cg16')
# (8.0, 22.0, 3.0, u'cg17')
# (8.0, 21.0, 3.0, u'cg18')
# (9.0, 19.0, 3.0, u'cg19')
# (9.0, 26.0, 3.0, u'cg20')
# (9.0, 25.0, 3.0, u'cg21')
# (9.0, 24.0, 3.0, u'cg22')
# (9.0, 18.0, 3.0, u'cg23')
# (9.0, 30.0, 3.0, u'cg24')
# (9.0, 21.0, 4.0, u'cg25')
# (9.0, 26.0, 3.0, u'cg26')
# (8.0, 23.0, 3.0, u'cg27')
# (9.0, 35.0, 3.0, u'cg28')
# (9.0, 28.0, 3.0, u'cg29')
# (9.0, 19.0, 3.0, u'cg30')
# (9.0, 32.0, 3.0, u'cg31')
# (8.0, 23.0, 3.0, u'cg32')
# (8.0, 32.0, 3.0, u'cg33')
# (9.0, 19.0, 3.0, u'cg34')
# (9.0, 23.0, 3.0, u'cg35')
# (8.0, 16.0, 3.0, u'cg36')
# (9.0, 20.0, 3.0, u'cg37')
# (9.0, 31.0, 3.0, u'cg38')
# (8.0, 24.0, 3.0, u'cg39')
# (8.0, 19.0, 3.0, u'cg40')
# (8.0, 21.0, 3.0, u'cg41')
# (9.0, 22.0, 3.0, u'cg42')
# (8.0, 29.0, 3.0, u'cg43')
# (9.0, 31.0, 3.0, u'cg44')
# (9.0, 23.0, 3.0, u'cg45')
# (9.0, 26.0, 3.0, u'cg46')
# (8.0, 18.0, 3.0, u'cg47')
# (9.0, 21.0, 3.0, u'cg48')
# (8.0, 29.0, 3.0, u'cg49')
# (9.0, 23.0, 2.0, u'cg50')
# (8.0, 21.0, 3.0, u'cg51')
# (9.0, 26.0, 3.0, u'cg52')
# (9.0, 23.0, 3.0, u'cg53')
# (8.0, 20.0, 3.0, u'cg54')
# (8.0, 20.0, 3.0, u'cg55')
# (8.0, 26.0, 3.0, u'cg56')
# (9.0, 27.0, 3.0, u'cg57')
# (9.0, 30.0, 3.0, u'cg58')
# (9.0, 46.0, 3.0, u'cg59')
# (8.0, 19.0, 4.0, u'cg60')
# (9.0, 28.0, 3.0, u'cg61')
# (9.0, 28.0, 3.0, u'cg62')
# (9.0, 21.0, 3.0, u'cg63')
# (8.0, 33.0, 3.0, u'cg64')
# (9.0, 25.0, 3.0, u'cg65')
# (8.0, 32.0, 3.0, u'cg66')
# (8.0, 29.0, 3.0, u'cg67')
# (9.0, 29.0, 3.0, u'cg68')
# (9.0, 43.0, 3.0, u'cg69')
# (8.0, 25.0, 3.0, u'cg70')
# (9.0, 31.0, 3.0, u'cg71')
# (9.0, 27.0, 3.0, u'cg72')
# (9.0, 23.0, 3.0, u'cg73')
# (9.0, 24.0, 3.0, u'cg74')
# (8.0, 18.0, 3.0, u'cg75')
# (9.0, 16.0, 4.0, u'ch01')
# (9.0, 20.0, 3.0, u'ch02')
# (9.0, 27.0, 3.0, u'ch03')
# (9.0, 19.0, 3.0, u'ch04')
# (9.0, 27.0, 4.0, u'ch05')
# (10.0, 23.0, 3.0, u'ch06')
# (9.0, 18.0, 4.0, u'ch07')
# (9.0, 29.0, 4.0, u'ch08')
# (9.0, 24.0, 4.0, u'ch09')
# (10.0, 22.0, 3.0, u'ch10')
# (9.0, 22.0, 3.0, u'ch11')
# (9.0, 31.0, 6.0, u'ch12')
# (9.0, 22.0, 3.0, u'ch13')
# (9.0, 22.0, 5.0, u'ch14')
# (9.0, 15.0, 3.0, u'ch15')
# (9.0, 30.0, 4.0, u'ch16')
# (9.0, 24.0, 4.0, u'ch17')
# (9.0, 26.0, 3.0, u'ch18')
# (9.0, 24.0, 3.0, u'ch19')
# (9.0, 22.0, 4.0, u'ch20')
# (9.0, 26.0, 3.0, u'ch21')
# (9.0, 31.0, 5.0, u'ch22')
# (9.0, 33.0, 4.0, u'ch23')
# (9.0, 19.0, 5.0, u'ch24')
# (9.0, 28.0, 3.0, u'ch25')
# (9.0, 31.0, 3.0, u'ch26')
# (9.0, 21.0, 3.0, u'ch27')
# (9.0, 19.0, 3.0, u'ch28')
# (9.0, 30.0, 3.0, u'ch29')
# (9.0, 22.0, 3.0, u'ch30')
# (9.0, 31.0, 4.0, u'cj01')
# (9.0, 20.0, 4.0, u'cj02')
# (9.0, 26.0, 4.0, u'cj03')
# (9.0, 21.0, 3.0, u'cj04')
# (9.0, 24.0, 3.0, u'cj05')
# (9.0, 27.0, 3.0, u'cj06')
# (9.0, 23.0, 4.0, u'cj07')
# (9.0, 20.0, 3.0, u'cj08')
# (9.0, 24.0, 4.0, u'cj09')
# (8.0, 23.0, 3.0, u'cj10')
# (9.0, 22.0, 3.0, u'cj11')
# (9.0, 23.0, 4.0, u'cj12')
# (9.0, 30.0, 4.0, u'cj13')
# (9.0, 21.0, 3.0, u'cj14')
# (9.0, 20.0, 3.0, u'cj15')
# (9.0, 24.0, 4.0, u'cj16')
# (10.0, 27.0, 3.0, u'cj17')
# (8.0, 18.0, 6.0, u'cj18')
# (8.0, 18.0, 4.0, u'cj19')
# (8.0, 20.0, 6.0, u'cj20')
# (8.0, 29.0, 7.0, u'cj21')
# (9.0, 25.0, 3.0, u'cj22')
# (9.0, 21.0, 3.0, u'cj23')
# (9.0, 34.0, 3.0, u'cj24')
# (9.0, 19.0, 4.0, u'cj25')
# (9.0, 23.0, 3.0, u'cj26')
# (9.0, 24.0, 3.0, u'cj27')
# (9.0, 25.0, 4.0, u'cj28')
# (9.0, 23.0, 3.0, u'cj29')
# (9.0, 22.0, 3.0, u'cj30')
# (8.0, 38.0, 3.0, u'cj31')
# (9.0, 22.0, 5.0, u'cj32')
# (9.0, 23.0, 4.0, u'cj33')
# (9.0, 21.0, 3.0, u'cj34')
# (9.0, 23.0, 3.0, u'cj35')
# (9.0, 28.0, 3.0, u'cj36')
# (9.0, 26.0, 3.0, u'cj37')
# (9.0, 23.0, 3.0, u'cj38')
# (9.0, 25.0, 3.0, u'cj39')
# (9.0, 31.0, 3.0, u'cj40')
# (9.0, 27.0, 4.0, u'cj41')
# (9.0, 25.0, 3.0, u'cj42')
# (9.0, 24.0, 3.0, u'cj43')
# (9.0, 29.0, 4.0, u'cj44')
# (9.0, 21.0, 4.0, u'cj45')
# (9.0, 25.0, 3.0, u'cj46')
# (9.0, 20.0, 3.0, u'cj47')
# (9.0, 20.0, 4.0, u'cj48')
# (9.0, 27.0, 3.0, u'cj49')
# (9.0, 33.0, 4.0, u'cj50')
# (9.0, 23.0, 3.0, u'cj51')
# (8.0, 23.0, 4.0, u'cj52')
# (8.0, 33.0, 3.0, u'cj53')
# (9.0, 23.0, 3.0, u'cj54')
# (9.0, 26.0, 3.0, u'cj55')
# (9.0, 23.0, 3.0, u'cj56')
# (9.0, 26.0, 3.0, u'cj57')
# (9.0, 28.0, 3.0, u'cj58')
# (9.0, 32.0, 4.0, u'cj59')
# (9.0, 29.0, 3.0, u'cj60')
# (8.0, 26.0, 3.0, u'cj61')
# (9.0, 26.0, 3.0, u'cj62')
# (9.0, 26.0, 3.0, u'cj63')
# (9.0, 20.0, 3.0, u'cj64')
# (8.0, 29.0, 3.0, u'cj65')
# (9.0, 20.0, 3.0, u'cj66')
# (9.0, 28.0, 3.0, u'cj67')
# (9.0, 40.0, 3.0, u'cj68')
# (9.0, 22.0, 5.0, u'cj69')
# (9.0, 19.0, 3.0, u'cj70')
# (9.0, 18.0, 3.0, u'cj71')
# (9.0, 21.0, 3.0, u'cj72')
# (9.0, 13.0, 3.0, u'cj73')
# (9.0, 21.0, 3.0, u'cj74')
# (9.0, 24.0, 4.0, u'cj75')
# (9.0, 24.0, 3.0, u'cj76')
# (9.0, 21.0, 4.0, u'cj77')
# (9.0, 20.0, 4.0, u'cj78')
# (8.0, 23.0, 5.0, u'cj79')
# (9.0, 19.0, 4.0, u'cj80')
# (8.0, 14.0, 3.0, u'ck01')
# (8.0, 16.0, 3.0, u'ck02')
# (8.0, 17.0, 3.0, u'ck03')
# (8.0, 18.0, 3.0, u'ck04')
# (8.0, 13.0, 3.0, u'ck05')
# (8.0, 12.0, 3.0, u'ck06')
# (8.0, 10.0, 4.0, u'ck07')
# (8.0, 17.0, 3.0, u'ck08')
# (8.0, 25.0, 3.0, u'ck09')
# (8.0, 15.0, 3.0, u'ck10')
# (8.0, 16.0, 3.0, u'ck11')
# (8.0, 17.0, 3.0, u'ck12')
# (8.0, 17.0, 3.0, u'ck13')
# (8.0, 17.0, 3.0, u'ck14')
# (8.0, 18.0, 3.0, u'ck15')
# (8.0, 18.0, 3.0, u'ck16')
# (8.0, 13.0, 3.0, u'ck17')
# (8.0, 15.0, 3.0, u'ck18')
# (8.0, 20.0, 3.0, u'ck19')
# (8.0, 17.0, 3.0, u'ck20')
# (8.0, 11.0, 3.0, u'ck21')
# (8.0, 18.0, 3.0, u'ck22')
# (8.0, 21.0, 3.0, u'ck23')
# (8.0, 11.0, 4.0, u'ck24')
# (8.0, 33.0, 3.0, u'ck25')
# (8.0, 18.0, 4.0, u'ck26')
# (8.0, 24.0, 3.0, u'ck27')
# (8.0, 13.0, 4.0, u'ck28')
# (8.0, 27.0, 3.0, u'ck29')
# (8.0, 16.0, 3.0, u'cl01')
# (8.0, 16.0, 4.0, u'cl02')
# (8.0, 13.0, 3.0, u'cl03')
# (8.0, 14.0, 3.0, u'cl04')
# (8.0, 16.0, 3.0, u'cl05')
# (8.0, 16.0, 4.0, u'cl06')
# (8.0, 16.0, 3.0, u'cl07')
# (8.0, 17.0, 4.0, u'cl08')
# (8.0, 15.0, 4.0, u'cl09')
# (8.0, 13.0, 4.0, u'cl10')
# (8.0, 16.0, 3.0, u'cl11')
# (8.0, 12.0, 3.0, u'cl12')
# (8.0, 14.0, 3.0, u'cl13')
# (8.0, 13.0, 3.0, u'cl14')
# (8.0, 15.0, 3.0, u'cl15')
# (8.0, 13.0, 3.0, u'cl16')
# (8.0, 19.0, 3.0, u'cl17')
# (8.0, 17.0, 3.0, u'cl18')
# (8.0, 16.0, 3.0, u'cl19')
# (8.0, 14.0, 3.0, u'cl20')
# (8.0, 12.0, 3.0, u'cl21')
# (8.0, 17.0, 3.0, u'cl22')
# (8.0, 15.0, 3.0, u'cl23')
# (8.0, 15.0, 4.0, u'cl24')
# (8.0, 14.0, 3.0, u'cm01')
# (8.0, 16.0, 3.0, u'cm02')
# (8.0, 16.0, 3.0, u'cm03')
# (8.0, 12.0, 3.0, u'cm04')
# (9.0, 20.0, 3.0, u'cm05')
# (8.0, 15.0, 3.0, u'cm06')
# (8.0, 14.0, 4.0, u'cn01')
# (8.0, 14.0, 4.0, u'cn02')
# (8.0, 11.0, 3.0, u'cn03')
# (8.0, 13.0, 3.0, u'cn04')
# (8.0, 12.0, 4.0, u'cn05')
# (8.0, 18.0, 3.0, u'cn06')
# (8.0, 12.0, 3.0, u'cn07')
# (8.0, 20.0, 3.0, u'cn08')
# (8.0, 14.0, 3.0, u'cn09')
# (8.0, 12.0, 3.0, u'cn10')
# (8.0, 18.0, 3.0, u'cn11')
# (8.0, 13.0, 3.0, u'cn12')
# (8.0, 20.0, 3.0, u'cn13')
# (8.0, 14.0, 3.0, u'cn14')
# (8.0, 13.0, 3.0, u'cn15')
# (8.0, 19.0, 3.0, u'cn16')
# (8.0, 13.0, 4.0, u'cn17')
# (8.0, 18.0, 3.0, u'cn18')
# (8.0, 17.0, 3.0, u'cn19')
# (8.0, 15.0, 3.0, u'cn20')
# (8.0, 16.0, 3.0, u'cn21')
# (8.0, 16.0, 3.0, u'cn22')
# (8.0, 18.0, 3.0, u'cn23')
# (8.0, 14.0, 4.0, u'cn24')
# (8.0, 12.0, 3.0, u'cn25')
# (8.0, 18.0, 3.0, u'cn26')
# (8.0, 19.0, 4.0, u'cn27')
# (9.0, 19.0, 3.0, u'cn28')
# (8.0, 13.0, 3.0, u'cn29')
# (8.0, 18.0, 3.0, u'cp01')
# (8.0, 24.0, 3.0, u'cp02')
# (8.0, 17.0, 3.0, u'cp03')
# (8.0, 19.0, 3.0, u'cp04')
# (8.0, 18.0, 3.0, u'cp05')
# (8.0, 14.0, 3.0, u'cp06')
# (8.0, 17.0, 3.0, u'cp07')
# (8.0, 13.0, 3.0, u'cp08')
# (8.0, 32.0, 3.0, u'cp09')
# (8.0, 19.0, 3.0, u'cp10')
# (8.0, 20.0, 3.0, u'cp11')
# (8.0, 14.0, 4.0, u'cp12')
# (8.0, 21.0, 3.0, u'cp13')
# (8.0, 11.0, 3.0, u'cp14')
# (8.0, 14.0, 3.0, u'cp15')
# (8.0, 12.0, 3.0, u'cp16')
# (8.0, 20.0, 3.0, u'cp17')
# (8.0, 13.0, 4.0, u'cp18')
# (8.0, 14.0, 4.0, u'cp19')
# (8.0, 13.0, 3.0, u'cp20')
# (8.0, 21.0, 3.0, u'cp21')
# (8.0, 14.0, 4.0, u'cp22')
# (8.0, 15.0, 3.0, u'cp23')
# (8.0, 11.0, 4.0, u'cp24')
# (8.0, 23.0, 3.0, u'cp25')
# (8.0, 22.0, 4.0, u'cp26')
# (8.0, 12.0, 3.0, u'cp27')
# (8.0, 15.0, 3.0, u'cp28')
# (9.0, 16.0, 3.0, u'cp29')
# (8.0, 21.0, 3.0, u'cr01')
# (8.0, 21.0, 3.0, u'cr02')
# (8.0, 28.0, 3.0, u'cr03')
# (8.0, 19.0, 3.0, u'cr04')
# (8.0, 17.0, 3.0, u'cr05')
# (8.0, 20.0, 3.0, u'cr06')
# (8.0, 13.0, 4.0, u'cr07')
# (9.0, 34.0, 2.0, u'cr08')
# (8.0, 24.0, 2.0, u'cr09')

# %% [markdown]
# ## Brown Corpus

# %%
from nltk.corpus import brown

# %%
brown.categories()
# Out:
# [u'adventure',
#  u'belles_lettres',
#  u'editorial',
#  u'fiction',
#  u'government',
#  u'hobbies',
#  u'humor',
#  u'learned',
#  u'lore',
#  u'mystery',
#  u'news',
#  u'religion',
#  u'reviews',
#  u'romance',
#  u'science_fiction']

# %%
brown.words(categories='news')
# Out:
# [u'The', u'Fulton', u'County', u'Grand', u'Jury', ...]

# %%
brown.words(fileids=['cg22'])
# Out:
# [u'Does', u'our', u'society', u'have', u'a', ...]

# %%
news_text = brown.words(categories='news')

# %%
fdist = nltk.FreqDist(w.lower() for w in news_text)

# %%
modals = ['can', 'could', 'may', 'might', 'must', 'will', 'the']

# %%
import nltk
for m in modals:
    print(m + ':', fdist[m])
# Out:
# ('can:', 94)
# ('could:', 87)
# ('may:', 93)
# ('might:', 38)
# ('must:', 53)
# ('will:', 389)
# ('the:', 6386)

# %% [markdown]
# ### Problem
# Find the Frequency Distribution of words in brown corpus.
# #### words: "what", "why", "where", "which"

# %% [markdown]
# ### Problem
# Get counts for each genre of interest.

# %%
cfd = nltk.ConditionalFreqDist(
    (genre, word)
    for genre in brown.categories()
    for word in brown.words(categories=genre))
genres = ['news', 'religion', 'hobbies', 'science_fiction', 'romance', 'humor']
modals = ['can', 'could', 'may', 'might', 'must', 'will']
cfd.tabulate(conditions=genres, samples=modals)
# Out:
#                  can could  may might must will
#            news   93   86   66   38   50  389
#        religion   82   59   78   12   54   71
#         hobbies  268   58  131   22   83  264
# science_fiction   16   49    4   12    8   16
#         romance   74  193   11   51   45   43
#           humor   16   30    8    8    9   13

# %% [markdown]
# ### Inaugural Corpus

# %%
from nltk.corpus import inaugural

# %% [markdown]
# ### Problem:
# How is word usage changing over time for words "america" and "citizen" in the inaugural corpus. Pick a file in the corpus. Restrict to when these words are used in the beginning of sentence.
# ### Hint: use ConditionalFreqDist in nltk

# %% [markdown]
# ### Problem
# Working with the news and romance genres from the Brown Corpus, find out which days of the week are most newsworthy, and which
# are most romantic. Define a variable called days containing a list of days of the week, i.e. ['Monday', ...].
# Now tabulate the counts for these words using cfd.tabulate(samples=days).
# Now try the same thing using plot in place of tabulate.

# %% [markdown]
# # Module 3: NLP Pipeline

# %% [markdown]
# ## Stemmer

# %%
tokens = gutenberg.words('austen-emma.txt')
porter = nltk.PorterStemmer()

print tokens[1]
lancaster = nltk.LancasterStemmer()
# Out:
# Emma

# %%
[porter.stem(t) for t in tokens]
# Out:
# [u'[',
#  u'Emma',
#  u'by',
#  u'Jane',
#  u'Austen',
#  u'1816',
#  u']',
#  u'VOLUM',
#  u'I',
#  u'CHAPTER',
#  u'I',
#  u'Emma',
#  u'Woodhous',
#  u',',
#  u'handsom',
#  u',',
#  u'clever',
#  u',',
#  u'and',
#  u'rich',
#  u',',
#  u'with',
#  u'a',
#  u'comfort',
#  u'home',
#  u'and',
#  u'happi',
#  u'disposit',
#  u',',
#  u'seem',
#  u'to',
#  u'unit',
#  u'some',
#  u'of',
#  u'the',
#  u'best',
#  u'bless',
#  u'of',
#  u'exist',
#  u';',
#  u'and',
#  u'had',
#  u'live',
#  u'nearli',
#  u'twenti',
#  u'-',
#  u'one',
#  u'year',
#  u'in',
#  u'the',
#  u'world',
#  u'with',
#  u'veri',
#  u'littl',
#  u'to',
#  u'distress',
#  u'or',
#  u'vex',
#  u'her',
#  u'.',
#  u'She',
#  u'wa',
#  u'the',
#  u'youngest',
#  u'of',
#  u'the',
#  u'two',
#  u'daughter',
#  u'of',
#  u'a',
#  u'most',
#  u'affection',
#  u',',
#  u'indulg',
#  u'father',
#  u';',
#  u'and',
#  u'had',
#  u',',
#  u'in',
#  u'consequ',
#  u'of',
#  u'her',
#  u'sister',
#  u"'",
#  u's',
#  u'marriag',
#  u',',
#  u'been',
#  u'mistress',
#  u'of',
#  u'hi',
#  u'hous',
#  u'from',
#  u'a',
#  u'veri',
#  u'earli',
#  u'period',
#  u'.',
#  u'Her',
#  u'mother',
#  u'had',
#  u'die',
#  u'too',
#  u'long',
#  u'ago',
#  u'for',
#  u'her',
#  u'to',
#  u'have',
#  u'more',
#  u'than',
#  u'an',
#  u'indistinct',
#  u'remembr',
#  u'of',
#  u'her',
#  u'caress',
#  u';',
#  u'and',
#  u'her',
#  u'place',
#  u'had',
#  u'been',
#  u'suppli',
#  u'by',
#  u'an',
#  u'excel',
#  u'woman',
#  u'as',
#  u'gover',
#  u',',
#  u'who',
#  u'had',
#  u'fallen',
#  u'littl',
#  u'short',
#  u'of',
#  u'a',
#  u'mother',
#  u'in',
#  u'affect',
#  u'.',
#  u'Sixteen',
#  u'year',
#  u'had',
#  u'Miss',
#  u'Taylor',
#  u'been',
#  u'in',
#  u'Mr',
#  u'.',
#  u'Woodhous',
#  u"'",
#  u's',
#  u'famili',
#  u',',
#  u'less',
#  u'as',
#  u'a',
#  u'gover',
#  u'than',
#  u'a',
#  u'friend',
#  u',',
#  u'veri',
#  u'fond',
#  u'of',
#  u'both',
#  u'daughter',
#  u',',
#  u'but',
#  u'particularli',
#  u'of',
#  u'Emma',
#  u'.',
#  u'Between',
#  u'_them_',
#  u'it',
#  u'wa',
#  u'more',
#  u'the',
#  u'intimaci',
#  u'of',
#  u'sister',
#  u'.',
#  u'Even',
#  u'befor',
#  u'Miss',
#  u'Taylor',
#  u'had',
#  u'ceas',
#  u'to',
#  u'hold',
#  u'the',
#  u'nomin',
#  u'offic',
#  u'of',
#  u'gover',
#  u',',
#  u'the',
#  u'mild',
#  u'of',
#  u'her',
#  u'temper',
#  u'had',
#  u'hardli',
#  u'allow',
#  u'her',
#  u'to',
#  u'impos',
#  u'ani',
#  u'restraint',
#  u';',
#  u'and',
#  u'the',
#  u'shadow',
#  u'of',
#  u'author',
#  u'be',
#  u'now',
#  u'long',
#  u'pass',
#  u'away',
#  u',',
#  u'they',
#  u'had',
#  u'been',
#  u'live',
#  u'togeth',
#  u'as',
#  u'friend',
#  u'and',
#  u'friend',
#  u'veri',
#  u'mutual',
#  u'attach',
#  u',',
#  u'and',
#  u'Emma',
#  u'do',
#  u'just',
#  u'what',
#  u'she',
#  u'like',
#  u';',
#  u'highli',
#  u'esteem',
#  u'Miss',
#  u'Taylor',
#  u"'",
#  u's',
#  u'judgment',
#  u',',
#  u'but',
#  u'direct',
#  u'chiefli',
#  u'by',
#  u'her',
#  u'own',
#  u'.',
#  u'The',
#  u'real',
#  u'evil',
#  u',',
#  u'inde',
#  u',',
#  u'of',
#  u'Emma',
#  u"'",
#  u's',
#  u'situat',
#  u'were',
#  u'the',
#  u'power',
#  u'of',
#  u'have',
#  u'rather',
#  u'too',
#  u'much',
#  u'her',
#  u'own',
#  u'way',
#  u',',
#  u'and',
#  u'a',
#  u'disposit',
#  u'to',
#  u'think',
#  u'a',
#  u'littl',
#  u'too',
#  u'well',
#  u'of',
#  u'herself',
#  u';',
#  u'these',
#  u'were',
#  u'the',
#  u'disadvantag',
#  u'which',
#  u'threaten',
#  u'alloy',
#  u'to',
#  u'her',
#  u'mani',
#  u'enjoy',
#  u'.',
#  u'The',
#  u'danger',
#  u',',
#  u'howev',
#  u',',
#  u'wa',
#  u'at',
#  u'present',
#  u'so',
#  u'unperceiv',
#  u',',
#  u'that',
#  u'they',
#  u'did',
#  u'not',
#  u'by',
#  u'ani',
#  u'mean',
#  u'rank',
#  u'as',
#  u'misfortun',
#  u'with',
#  u'her',
#  u'.',
#  u'Sorrow',
#  u'came',
#  u'--',
#  u'a',
#  u'gentl',
#  u'sorrow',
#  u'--',
#  u'but',
#  u'not',
#  u'at',
#  u'all',
#  u'in',
#  u'the',
#  u'shape',
#  u'of',
#  u'ani',
#  u'disagre',
#  u'conscious',
#  u'.--',
#  u'Miss',
#  u'Taylor',
#  u'marri',
#  u'.',
#  u'It',
#  u'wa',
#  u'Miss',
#  u'Taylor',
#  u"'",
#  u's',
#  u'loss',
#  u'which',
#  u'first',
#  u'brought',
#  u'grief',
#  u'.',
#  u'It',
#  u'wa',
#  u'on',
#  u'the',
#  u'wed',
#  u'-',
#  u'day',
#  u'of',
#  u'thi',
#  u'belov',
#  u'friend',
#  u'that',
#  u'Emma',
#  u'first',
#  u'sat',
#  u'in',
#  u'mourn',
#  u'thought',
#  u'of',
#  u'ani',
#  u'continu',
#  u'.',
#  u'The',
#  u'wed',
#  u'over',
#  u',',
#  u'and',
#  u'the',
#  u'bride',
#  u'-',
#  u'peopl',
#  u'gone',
#  u',',
#  u'her',
#  u'father',
#  u'and',
#  u'herself',
#  u'were',
#  u'left',
#  u'to',
#  u'dine',
#  u'togeth',
#  u',',
#  u'with',
#  u'no',
#  u'prospect',
#  u'of',
#  u'a',
#  u'third',
#  u'to',
#  u'cheer',
#  u'a',
#  u'long',
#  u'even',
#  u'.',
#  u'Her',
#  u'father',
#  u'compos',
#  u'himself',
#  u'to',
#  u'sleep',
#  u'after',
#  u'dinner',
#  u',',
#  u'as',
#  u'usual',
#  u',',
#  u'and',
#  u'she',
#  u'had',
#  u'then',
#  u'onli',
#  u'to',
#  u'sit',
#  u'and',
#  u'think',
#  u'of',
#  u'what',
#  u'she',
#  u'had',
#  u'lost',
#  u'.',
#  u'The',
#  u'event',
#  u'had',
#  u'everi',
#  u'promis',
#  u'of',
#  u'happi',
#  u'for',
#  u'her',
#  u'friend',
#  u'.',
#  u'Mr',
#  u'.',
#  u'Weston',
#  u'wa',
#  u'a',
#  u'man',
#  u'of',
#  u'unexception',
#  u'charact',
#  u',',
#  u'easi',
#  u'fortun',
#  u',',
#  u'suitabl',
#  u'age',
#  u',',
#  u'and',
#  u'pleasant',
#  u'manner',
#  u';',
#  u'and',
#  u'there',
#  u'wa',
#  u'some',
#  u'satisfact',
#  u'in',
#  u'consid',
#  u'with',
#  u'what',
#  u'self',
#  u'-',
#  u'deni',
#  u',',
#  u'gener',
#  u'friendship',
#  u'she',
#  u'had',
#  u'alway',
#  u'wish',
#  u'and',
#  u'promot',
#  u'the',
#  u'match',
#  u';',
#  u'but',
#  u'it',
#  u'wa',
#  u'a',
#  u'black',
#  u'morn',
#  u"'",
#  u's',
#  u'work',
#  u'for',
#  u'her',
#  u'.',
#  u'The',
#  u'want',
#  u'of',
#  u'Miss',
#  u'Taylor',
#  u'would',
#  u'be',
#  u'felt',
#  u'everi',
#  u'hour',
#  u'of',
#  u'everi',
#  u'day',
#  u'.',
#  u'She',
#  u'recal',
#  u'her',
#  u'past',
#  u'kind',
#  u'--',
#  u'the',
#  u'kind',
#  u',',
#  u'the',
#  u'affect',
#  u'of',
#  u'sixteen',
#  u'year',
#  u'--',
#  u'how',
#  u'she',
#  u'had',
#  u'taught',
#  u'and',
#  u'how',
#  u'she',
#  u'had',
#  u'play',
#  u'with',
#  u'her',
#  u'from',
#  u'five',
#  u'year',
#  u'old',
#  u'--',
#  u'how',
#  u'she',
#  u'had',
#  u'devot',
#  u'all',
#  u'her',
#  u'power',
#  u'to',
#  u'attach',
#  u'and',
#  u'amus',
#  u'her',
#  u'in',
#  u'health',
#  u'--',
#  u'and',
#  u'how',
#  u'nurs',
#  u'her',
#  u'through',
#  u'the',
#  u'variou',
#  u'ill',
#  u'of',
#  u'childhood',
#  u'.',
#  u'A',
#  u'larg',
#  u'debt',
#  u'of',
#  u'gratitud',
#  u'wa',
#  u'owe',
#  u'here',
#  u';',
#  u'but',
#  u'the',
#  u'intercours',
#  u'of',
#  u'the',
#  u'last',
#  u'seven',
#  u'year',
#  u',',
#  u'the',
#  u'equal',
#  u'foot',
#  u'and',
#  u'perfect',
#  u'unreserv',
#  u'which',
#  u'had',
#  u'soon',
#  u'follow',
#  u'Isabella',
#  u"'",
#  u's',
#  u'marriag',
#  u',',
#  u'on',
#  u'their',
#  u'be',
#  u'left',
#  u'to',
#  u'each',
#  u'other',
#  u',',
#  u'wa',
#  u'yet',
#  u'a',
#  u'dearer',
#  u',',
#  u'tender',
#  u'recollect',
#  u'.',
#  u'She',
#  u'had',
#  u'been',
#  u'a',
#  u'friend',
#  u'and',
#  u'companion',
#  u'such',
#  u'as',
#  u'few',
#  u'possess',
#  u':',
#  u'intellig',
#  u',',
#  u'well',
#  u'-',
#  u'inform',
#  u',',
#  u'use',
#  u',',
#  u'gentl',
#  u',',
#  u'know',
#  u'all',
#  u'the',
#  u'way',
#  u'of',
#  u'the',
#  u'famili',
#  u',',
#  u'interest',
#  u'in',
#  u'all',
#  u'it',
#  u'concern',
#  u',',
#  u'and',
#  u'peculiarli',
#  u'interest',
#  u'in',
#  u'herself',
#  u',',
#  u'in',
#  u'everi',
#  u'pleasur',
#  u',',
#  u'everi',
#  u'scheme',
#  u'of',
#  u'her',
#  u'--',
#  u'one',
#  u'to',
#  u'whom',
#  u'she',
#  u'could',
#  u'speak',
#  u'everi',
#  u'thought',
#  u'as',
#  u'it',
#  u'aros',
#  u',',
#  u'and',
#  u'who',
#  u'had',
#  u'such',
#  u'an',
#  u'affect',
#  u'for',
#  u'her',
#  u'as',
#  u'could',
#  u'never',
#  u'find',
#  u'fault',
#  u'.',
#  u'How',
#  u'wa',
#  u'she',
#  u'to',
#  u'bear',
#  u'the',
#  u'chang',
#  u'?--',
#  u'It',
#  u'wa',
#  u'true',
#  u'that',
#  u'her',
#  u'friend',
#  u'wa',
#  u'go',
#  u'onli',
#  u'half',
#  u'a',
#  u'mile',
#  u'from',
#  u'them',
#  u';',
#  u'but',
#  u'Emma',
#  u'wa',
#  u'awar',
#  u'that',
#  u'great',
#  u'must',
#  u'be',
#  u'the',
#  u'differ',
#  u'between',
#  u'a',
#  u'Mr',
#  u'.',
#  u'Weston',
#  u',',
#  u'onli',
#  u'half',
#  u'a',
#  u'mile',
#  u'from',
#  u'them',
#  u',',
#  u'and',
#  u'a',
#  u'Miss',
#  u'Taylor',
#  u'in',
#  u'the',
#  u'hous',
#  u';',
#  u'and',
#  u'with',
#  u'all',
#  u'her',
#  u'advantag',
#  u',',
#  u'natur',
#  u'and',
#  u'domest',
#  u',',
#  u'she',
#  u'wa',
#  u'now',
#  u'in',
#  u'great',
#  u'danger',
#  u'of',
#  u'suffer',
#  u'from',
#  u'intellectu',
#  u'solitud',
#  u'.',
#  u'She',
#  u'dearli',
#  u'love',
#  u'her',
#  u'father',
#  u',',
#  u'but',
#  u'he',
#  u'wa',
#  u'no',
#  u'companion',
#  u'for',
#  u'her',
#  u'.',
#  u'He',
#  u'could',
#  u'not',
#  u'meet',
#  u'her',
#  u'in',
#  u'convers',
#  u',',
#  u'ration',
#  u'or',
#  u'play',
#  u'.',
#  u'The',
#  u'evil',
#  u'of',
#  u'the',
#  u'actual',
#  u'dispar',
#  u'in',
#  u'their',
#  u'age',
#  u'(',
#  u'and',
#  u'Mr',
#  u'.',
#  u'Woodhous',
#  u'had',
#  u'not',
#  u'marri',
#  u'earli',
#  u')',
#  u'wa',
#  u'much',
#  u'increas',
#  u'by',
#  u'hi',
#  u'constitut',
#  u'and',
#  u'habit',
#  u';',
#  u'for',
#  u'have',
#  u'been',
#  u'a',
#  u'valetudinarian',
#  u'all',
#  u'hi',
#  u'life',
#  u',',
#  u'without',
#  u'activ',
#  u'of',
#  u'mind',
#  u'or',
#  u'bodi',
#  u',',
#  u'he',
#  u'wa',
#  u'a',
#  u'much',
#  u'older',
#  u'man',
#  u'in',
#  u'way',
#  u'than',
#  u'in',
#  u'year',
#  u';',
#  u'and',
#  u'though',
#  u'everywher',
#  u'belov',
#  u'for',
#  u'the',
#  u'friendli',
#  u'of',
#  u'hi',
#  u'heart',
#  u'and',
#  u'hi',
#  u'amiabl',
#  u'temper',
#  u',',
#  u'hi',
#  u'talent',
#  u'could',
#  u'not',
#  u'have',
#  u'recommend',
#  u'him',
#  u'at',
#  u'ani',
#  u'time',
#  u'.',
#  u'Her',
#  u'sister',
#  u',',
#  u'though',
#  u'compar',
#  u'but',
#  u'littl',
#  u'remov',
#  u'by',
#  u'matrimoni',
#  u',',
#  u'be',
#  u'settl',
#  u'in',
#  u'London',
#  u',',
#  u'onli',
#  u'sixteen',
#  u'mile',
#  u'off',
#  u',',
#  u'wa',
#  u'much',
#  u'beyond',
#  u'her',
#  u'daili',
#  u'reach',
#  u';',
#  u'and',
#  u'mani',
#  u'a',
#  u'long',
#  u'Octob',
#  u'and',
#  u'Novemb',
#  u'even',
#  u'must',
#  u'be',
#  u'struggl',
#  u'through',
#  u'at',
#  u'Hartfield',
#  u',',
#  u'befor',
#  u'Christma',
#  u'brought',
#  u'the',
#  u'next',
#  u'visit',
#  u'from',
#  u'Isabella',
#  u'and',
#  u'her',
#  u'husband',
#  u',',
#  u'and',
#  u'their',
#  u'littl',
#  u'children',
#  u',',
#  u'to',
#  u'fill',
#  u'the',
#  u'hous',
#  u',',
#  u'and',
#  u'give',
#  u'her',
#  u'pleasant',
#  u'societi',
#  u'again',
#  u'.',
#  u'Highburi',
#  u',',
#  u'the',
#  u'larg',
#  u'and',
#  u'popul',
#  u'villag',
#  u',',
#  u'almost',
#  u'amount',
#  u'to',
#  u'a',
#  u'town',
#  u',',
#  u'to',
#  u'which',
#  u'Hartfield',
#  u',',
#  u'in',
#  u'spite',
#  u'of',
#  u'it',
#  u'separ',
#  u'lawn',
#  u',',
#  u'and',
#  u'shrubberi',
#  u',',
#  u'and',
#  u'name',
#  u',',
#  ...]

# %%
[lancaster.stem(t) for t in tokens]
# Out:
# [u'[',
#  u'emm',
#  u'by',
#  u'jan',
#  u'aust',
#  u'1816',
#  u']',
#  u'volum',
#  u'i',
#  u'chapt',
#  u'i',
#  u'emm',
#  u'woodh',
#  u',',
#  u'handsom',
#  u',',
#  u'clev',
#  u',',
#  u'and',
#  u'rich',
#  u',',
#  u'with',
#  u'a',
#  u'comfort',
#  u'hom',
#  u'and',
#  u'happy',
#  u'disposit',
#  u',',
#  u'seem',
#  u'to',
#  u'unit',
#  u'som',
#  u'of',
#  u'the',
#  u'best',
#  u'bless',
#  u'of',
#  u'ex',
#  u';',
#  u'and',
#  u'had',
#  u'liv',
#  u'near',
#  u'twenty',
#  u'-',
#  u'on',
#  u'year',
#  u'in',
#  u'the',
#  u'world',
#  u'with',
#  u'very',
#  u'littl',
#  u'to',
#  u'distress',
#  u'or',
#  u'vex',
#  u'her',
#  u'.',
#  u'she',
#  u'was',
#  u'the',
#  u'youngest',
#  u'of',
#  u'the',
#  u'two',
#  u'daught',
#  u'of',
#  u'a',
#  u'most',
#  u'affect',
#  u',',
#  u'indulg',
#  u'fath',
#  u';',
#  u'and',
#  u'had',
#  u',',
#  u'in',
#  u'consequ',
#  u'of',
#  u'her',
#  u'sist',
#  u"'",
#  u's',
#  u'marry',
#  u',',
#  u'been',
#  u'mistress',
#  u'of',
#  u'his',
#  u'hous',
#  u'from',
#  u'a',
#  u'very',
#  u'ear',
#  u'period',
#  u'.',
#  u'her',
#  u'moth',
#  u'had',
#  u'died',
#  u'too',
#  u'long',
#  u'ago',
#  u'for',
#  u'her',
#  u'to',
#  u'hav',
#  u'mor',
#  u'than',
#  u'an',
#  u'indistinct',
#  u'remembr',
#  u'of',
#  u'her',
#  u'caress',
#  u';',
#  u'and',
#  u'her',
#  u'plac',
#  u'had',
#  u'been',
#  u'supply',
#  u'by',
#  u'an',
#  u'excel',
#  u'wom',
#  u'as',
#  u'gov',
#  u',',
#  u'who',
#  u'had',
#  u'fal',
#  u'littl',
#  u'short',
#  u'of',
#  u'a',
#  u'moth',
#  u'in',
#  u'affect',
#  u'.',
#  u'sixteen',
#  u'year',
#  u'had',
#  u'miss',
#  u'tayl',
#  u'been',
#  u'in',
#  u'mr',
#  u'.',
#  u'woodh',
#  u"'",
#  u's',
#  u'famy',
#  u',',
#  u'less',
#  u'as',
#  u'a',
#  u'gov',
#  u'than',
#  u'a',
#  u'friend',
#  u',',
#  u'very',
#  u'fond',
#  u'of',
#  u'both',
#  u'daught',
#  u',',
#  u'but',
#  u'particul',
#  u'of',
#  u'emm',
#  u'.',
#  u'between',
#  u'_them_',
#  u'it',
#  u'was',
#  u'mor',
#  u'the',
#  u'intim',
#  u'of',
#  u'sist',
#  u'.',
#  u'ev',
#  u'bef',
#  u'miss',
#  u'tayl',
#  u'had',
#  u'ceas',
#  u'to',
#  u'hold',
#  u'the',
#  u'nomin',
#  u'off',
#  u'of',
#  u'gov',
#  u',',
#  u'the',
#  u'mild',
#  u'of',
#  u'her',
#  u'temp',
#  u'had',
#  u'hard',
#  u'allow',
#  u'her',
#  u'to',
#  u'impos',
#  u'any',
#  u'restraint',
#  u';',
#  u'and',
#  u'the',
#  u'shadow',
#  u'of',
#  u'auth',
#  u'being',
#  u'now',
#  u'long',
#  u'pass',
#  u'away',
#  u',',
#  u'they',
#  u'had',
#  u'been',
#  u'liv',
#  u'togeth',
#  u'as',
#  u'friend',
#  u'and',
#  u'friend',
#  u'very',
#  u'mut',
#  u'attach',
#  u',',
#  u'and',
#  u'emm',
#  u'doing',
#  u'just',
#  u'what',
#  u'she',
#  u'lik',
#  u';',
#  u'high',
#  u'esteem',
#  u'miss',
#  u'tayl',
#  u"'",
#  u's',
#  u'judg',
#  u',',
#  u'but',
#  u'direct',
#  u'chief',
#  u'by',
#  u'her',
#  u'own',
#  u'.',
#  u'the',
#  u'real',
#  u'evil',
#  u',',
#  u'indee',
#  u',',
#  u'of',
#  u'emm',
#  u"'",
#  u's',
#  u'situ',
#  u'wer',
#  u'the',
#  u'pow',
#  u'of',
#  u'hav',
#  u'rath',
#  u'too',
#  u'much',
#  u'her',
#  u'own',
#  u'way',
#  u',',
#  u'and',
#  u'a',
#  u'disposit',
#  u'to',
#  u'think',
#  u'a',
#  u'littl',
#  u'too',
#  u'wel',
#  u'of',
#  u'herself',
#  u';',
#  u'thes',
#  u'wer',
#  u'the',
#  u'disadv',
#  u'which',
#  u'threatened',
#  u'alloy',
#  u'to',
#  u'her',
#  u'many',
#  u'enjoy',
#  u'.',
#  u'the',
#  u'dang',
#  u',',
#  u'howev',
#  u',',
#  u'was',
#  u'at',
#  u'pres',
#  u'so',
#  u'unperceiv',
#  u',',
#  u'that',
#  u'they',
#  u'did',
#  u'not',
#  u'by',
#  u'any',
#  u'mean',
#  u'rank',
#  u'as',
#  u'misfortun',
#  u'with',
#  u'her',
#  u'.',
#  u'sorrow',
#  u'cam',
#  u'--',
#  u'a',
#  u'gentl',
#  u'sorrow',
#  u'--',
#  u'but',
#  u'not',
#  u'at',
#  u'al',
#  u'in',
#  u'the',
#  u'shap',
#  u'of',
#  u'any',
#  u'disagr',
#  u'conscy',
#  u'.--',
#  u'miss',
#  u'tayl',
#  u'marry',
#  u'.',
#  u'it',
#  u'was',
#  u'miss',
#  u'tayl',
#  u"'",
#  u's',
#  u'loss',
#  u'which',
#  u'first',
#  u'brought',
#  u'grief',
#  u'.',
#  u'it',
#  u'was',
#  u'on',
#  u'the',
#  u'wed',
#  u'-',
#  u'day',
#  u'of',
#  u'thi',
#  u'belov',
#  u'friend',
#  u'that',
#  u'emm',
#  u'first',
#  u'sat',
#  u'in',
#  u'mourn',
#  u'thought',
#  u'of',
#  u'any',
#  u'continu',
#  u'.',
#  u'the',
#  u'wed',
#  u'ov',
#  u',',
#  u'and',
#  u'the',
#  u'brid',
#  u'-',
#  u'peopl',
#  u'gon',
#  u',',
#  u'her',
#  u'fath',
#  u'and',
#  u'herself',
#  u'wer',
#  u'left',
#  u'to',
#  u'din',
#  u'togeth',
#  u',',
#  u'with',
#  u'no',
#  u'prospect',
#  u'of',
#  u'a',
#  u'third',
#  u'to',
#  u'che',
#  u'a',
#  u'long',
#  u'ev',
#  u'.',
#  u'her',
#  u'fath',
#  u'compos',
#  u'himself',
#  u'to',
#  u'sleep',
#  u'aft',
#  u'din',
#  u',',
#  u'as',
#  u'us',
#  u',',
#  u'and',
#  u'she',
#  u'had',
#  u'then',
#  u'on',
#  u'to',
#  u'sit',
#  u'and',
#  u'think',
#  u'of',
#  u'what',
#  u'she',
#  u'had',
#  u'lost',
#  u'.',
#  u'the',
#  u'ev',
#  u'had',
#  u'every',
#  u'prom',
#  u'of',
#  u'happy',
#  u'for',
#  u'her',
#  u'friend',
#  u'.',
#  u'mr',
#  u'.',
#  u'weston',
#  u'was',
#  u'a',
#  u'man',
#  u'of',
#  u'unexceiv',
#  u'charact',
#  u',',
#  u'easy',
#  u'fortun',
#  u',',
#  u'suit',
#  u'ag',
#  u',',
#  u'and',
#  u'pleas',
#  u'man',
#  u';',
#  u'and',
#  u'ther',
#  u'was',
#  u'som',
#  u'satisfact',
#  u'in',
#  u'consid',
#  u'with',
#  u'what',
#  u'self',
#  u'-',
#  u'deny',
#  u',',
#  u'gen',
#  u'friend',
#  u'she',
#  u'had',
#  u'alway',
#  u'wish',
#  u'and',
#  u'promot',
#  u'the',
#  u'match',
#  u';',
#  u'but',
#  u'it',
#  u'was',
#  u'a',
#  u'black',
#  u'morn',
#  u"'",
#  u's',
#  u'work',
#  u'for',
#  u'her',
#  u'.',
#  u'the',
#  u'want',
#  u'of',
#  u'miss',
#  u'tayl',
#  u'would',
#  u'be',
#  u'felt',
#  u'every',
#  u'hour',
#  u'of',
#  u'every',
#  u'day',
#  u'.',
#  u'she',
#  u'recal',
#  u'her',
#  u'past',
#  u'kind',
#  u'--',
#  u'the',
#  u'kind',
#  u',',
#  u'the',
#  u'affect',
#  u'of',
#  u'sixteen',
#  u'year',
#  u'--',
#  u'how',
#  u'she',
#  u'had',
#  u'taught',
#  u'and',
#  u'how',
#  u'she',
#  u'had',
#  u'play',
#  u'with',
#  u'her',
#  u'from',
#  u'fiv',
#  u'year',
#  u'old',
#  u'--',
#  u'how',
#  u'she',
#  u'had',
#  u'devot',
#  u'al',
#  u'her',
#  u'pow',
#  u'to',
#  u'attach',
#  u'and',
#  u'amus',
#  u'her',
#  u'in',
#  u'heal',
#  u'--',
#  u'and',
#  u'how',
#  u'nurs',
#  u'her',
#  u'through',
#  u'the',
#  u'vary',
#  u'il',
#  u'of',
#  u'child',
#  u'.',
#  u'a',
#  u'larg',
#  u'debt',
#  u'of',
#  u'gratitud',
#  u'was',
#  u'ow',
#  u'her',
#  u';',
#  u'but',
#  u'the',
#  u'intercours',
#  u'of',
#  u'the',
#  u'last',
#  u'sev',
#  u'year',
#  u',',
#  u'the',
#  u'eq',
#  u'foot',
#  u'and',
#  u'perfect',
#  u'unreserv',
#  u'which',
#  u'had',
#  u'soon',
#  u'follow',
#  u'isabell',
#  u"'",
#  u's',
#  u'marry',
#  u',',
#  u'on',
#  u'their',
#  u'being',
#  u'left',
#  u'to',
#  u'each',
#  u'oth',
#  u',',
#  u'was',
#  u'yet',
#  u'a',
#  u'dear',
#  u',',
#  u'tend',
#  u'recollect',
#  u'.',
#  u'she',
#  u'had',
#  u'been',
#  u'a',
#  u'friend',
#  u'and',
#  u'comp',
#  u'such',
#  u'as',
#  u'few',
#  u'possess',
#  u':',
#  u'intellig',
#  u',',
#  u'wel',
#  u'-',
#  u'inform',
#  u',',
#  u'us',
#  u',',
#  u'gentl',
#  u',',
#  u'know',
#  u'al',
#  u'the',
#  u'way',
#  u'of',
#  u'the',
#  u'famy',
#  u',',
#  u'interest',
#  u'in',
#  u'al',
#  u'it',
#  u'concern',
#  u',',
#  u'and',
#  u'peculi',
#  u'interest',
#  u'in',
#  u'herself',
#  u',',
#  u'in',
#  u'every',
#  u'pleas',
#  u',',
#  u'every',
#  u'scheme',
#  u'of',
#  u'her',
#  u'--',
#  u'on',
#  u'to',
#  u'whom',
#  u'she',
#  u'could',
#  u'speak',
#  u'every',
#  u'thought',
#  u'as',
#  u'it',
#  u'aros',
#  u',',
#  u'and',
#  u'who',
#  u'had',
#  u'such',
#  u'an',
#  u'affect',
#  u'for',
#  u'her',
#  u'as',
#  u'could',
#  u'nev',
#  u'find',
#  u'fault',
#  u'.',
#  u'how',
#  u'was',
#  u'she',
#  u'to',
#  u'bear',
#  u'the',
#  u'chang',
#  u'?--',
#  u'it',
#  u'was',
#  u'tru',
#  u'that',
#  u'her',
#  u'friend',
#  u'was',
#  u'going',
#  u'on',
#  u'half',
#  u'a',
#  u'mil',
#  u'from',
#  u'them',
#  u';',
#  u'but',
#  u'emm',
#  u'was',
#  u'aw',
#  u'that',
#  u'gre',
#  u'must',
#  u'be',
#  u'the',
#  u'diff',
#  u'between',
#  u'a',
#  u'mrs',
#  u'.',
#  u'weston',
#  u',',
#  u'on',
#  u'half',
#  u'a',
#  u'mil',
#  u'from',
#  u'them',
#  u',',
#  u'and',
#  u'a',
#  u'miss',
#  u'tayl',
#  u'in',
#  u'the',
#  u'hous',
#  u';',
#  u'and',
#  u'with',
#  u'al',
#  u'her',
#  u'adv',
#  u',',
#  u'nat',
#  u'and',
#  u'domest',
#  u',',
#  u'she',
#  u'was',
#  u'now',
#  u'in',
#  u'gre',
#  u'dang',
#  u'of',
#  u'suff',
#  u'from',
#  u'intellect',
#  u'solitud',
#  u'.',
#  u'she',
#  u'dear',
#  u'lov',
#  u'her',
#  u'fath',
#  u',',
#  u'but',
#  u'he',
#  u'was',
#  u'no',
#  u'comp',
#  u'for',
#  u'her',
#  u'.',
#  u'he',
#  u'could',
#  u'not',
#  u'meet',
#  u'her',
#  u'in',
#  u'convers',
#  u',',
#  u'rat',
#  u'or',
#  u'play',
#  u'.',
#  u'the',
#  u'evil',
#  u'of',
#  u'the',
#  u'act',
#  u'disp',
#  u'in',
#  u'their',
#  u'ag',
#  u'(',
#  u'and',
#  u'mr',
#  u'.',
#  u'woodh',
#  u'had',
#  u'not',
#  u'marry',
#  u'ear',
#  u')',
#  u'was',
#  u'much',
#  u'increas',
#  u'by',
#  u'his',
#  u'constitut',
#  u'and',
#  u'habit',
#  u';',
#  u'for',
#  u'hav',
#  u'been',
#  u'a',
#  u'valetudin',
#  u'al',
#  u'his',
#  u'lif',
#  u',',
#  u'without',
#  u'act',
#  u'of',
#  u'mind',
#  u'or',
#  u'body',
#  u',',
#  u'he',
#  u'was',
#  u'a',
#  u'much',
#  u'old',
#  u'man',
#  u'in',
#  u'way',
#  u'than',
#  u'in',
#  u'year',
#  u';',
#  u'and',
#  u'though',
#  u'everywh',
#  u'belov',
#  u'for',
#  u'the',
#  u'friend',
#  u'of',
#  u'his',
#  u'heart',
#  u'and',
#  u'his',
#  u'amy',
#  u'temp',
#  u',',
#  u'his',
#  u'tal',
#  u'could',
#  u'not',
#  u'hav',
#  u'recommend',
#  u'him',
#  u'at',
#  u'any',
#  u'tim',
#  u'.',
#  u'her',
#  u'sist',
#  u',',
#  u'though',
#  u'comp',
#  u'but',
#  u'littl',
#  u'remov',
#  u'by',
#  u'matrimony',
#  u',',
#  u'being',
#  u'settl',
#  u'in',
#  u'london',
#  u',',
#  u'on',
#  u'sixteen',
#  u'mil',
#  u'off',
#  u',',
#  u'was',
#  u'much',
#  u'beyond',
#  u'her',
#  u'dai',
#  u'reach',
#  u';',
#  u'and',
#  u'many',
#  u'a',
#  u'long',
#  u'octob',
#  u'and',
#  u'novemb',
#  u'ev',
#  u'must',
#  u'be',
#  u'struggled',
#  u'through',
#  u'at',
#  u'hartfield',
#  u',',
#  u'bef',
#  u'christmas',
#  u'brought',
#  u'the',
#  u'next',
#  u'visit',
#  u'from',
#  u'isabell',
#  u'and',
#  u'her',
#  u'husband',
#  u',',
#  u'and',
#  u'their',
#  u'littl',
#  u'childr',
#  u',',
#  u'to',
#  u'fil',
#  u'the',
#  u'hous',
#  u',',
#  u'and',
#  u'giv',
#  u'her',
#  u'pleas',
#  u'socy',
#  u'again',
#  u'.',
#  u'highbury',
#  u',',
#  u'the',
#  u'larg',
#  u'and',
#  u'pop',
#  u'vil',
#  u',',
#  u'almost',
#  u'amount',
#  u'to',
#  u'a',
#  u'town',
#  u',',
#  u'to',
#  u'which',
#  u'hartfield',
#  u',',
#  u'in',
#  u'spit',
#  u'of',
#  u'it',
#  u'sep',
#  u'lawn',
#  u',',
#  u'and',
#  u'shrubberies',
#  u',',
#  u'and',
#  u'nam',
#  u',',
#  ...]

# %% [markdown]
# ### Tokenize text

# %%
text = nltk.corpus.gutenberg.raw('chesterton-thursday.txt')
sents = nltk.sent_tokenize(text)

# %%
sents
# Out:
# [u'[The Man Who Was Thursday by G. K. Chesterton 1908]\n\nTo Edmund Clerihew Bentley\n\nA cloud was on the mind of men, and wailing went the weather,\nYea, a sick cloud upon the soul when we were boys together.',
#  u'Science announced nonentity and art admired decay;\nThe world was old and ended: but you and I were gay;\nRound us in antic order their crippled vices came--\nLust that had lost its laughter, fear that had lost its shame.',
#  u'Like the white lock of Whistler, that lit our aimless gloom,\nMen showed their own white feather as proudly as a plume.',
#  u'Life was a fly that faded, and death a drone that stung;\nThe world was very old indeed when you and I were young.',
#  u'They twisted even decent sin to shapes not to be named:\nMen were ashamed of honour; but we were not ashamed.',
#  u'Weak if we were and foolish, not thus we failed, not thus;\nWhen that black Baal blocked the heavens he had no hymns from us\nChildren we were--our forts of sand were even as weak as eve,\nHigh as they went we piled them up to break that bitter sea.',
#  u'Fools as we were in motley, all jangling and absurd,\nWhen all church bells were silent our cap and beds were heard.',
#  u'Not all unhelped we held the fort, our tiny flags unfurled;\nSome giants laboured in that cloud to lift it from the world.',
#  u'I find again the book we found, I feel the hour that flings\nFar out of fish-shaped Paumanok some cry of cleaner things;\nAnd the Green Carnation withered, as in forest fires that pass,\nRoared in the wind of all the world ten million leaves of grass;\nOr sane and sweet and sudden as a bird sings in the rain--\nTruth out of Tusitala spoke and pleasure out of pain.',
#  u'Yea, cool and clear and sudden as a bird sings in the grey,\nDunedin to Samoa spoke, and darkness unto day.',
#  u'But we were young; we lived to see God break their bitter charms.',
#  u'God and the good Republic come riding back in arms:\nWe have seen the City of Mansoul, even as it rocked, relieved--\nBlessed are they who did not see, but being blind, believed.',
#  u'This is a tale of those old fears, even of those emptied hells,\nAnd none but you shall understand the true thing that it tells--\nOf what colossal gods of shame could cow men and yet crash,\nOf what huge devils hid the stars, yet fell at a pistol flash.',
#  u'The doubts that were so plain to chase, so dreadful to withstand--\nOh, who shall understand but you; yea, who shall understand?',
#  u"The doubts that drove us through the night as we two talked amain,\nAnd day had broken on the streets e'er it broke upon the brain.",
#  u'Between us, by the peace of God, such truth can now be told;\nYea, there is strength in striking root and good in growing old.',
#  u'We have found common things at last and marriage and a creed,\nAnd I may safely write it now, and you may safely read.',
#  u'G. K. C.\n\n\n\nCHAPTER I\n\nTHE TWO POETS OF SAFFRON PARK\n\nTHE suburb of Saffron Park lay on the sunset side of London, as\nred and ragged as a cloud of sunset.',
#  u'It was built of a bright\nbrick throughout; its sky-line was fantastic, and even its ground\nplan was wild.',
#  u'It had been the outburst of a speculative builder,\nfaintly tinged with art, who called its architecture sometimes\nElizabethan and sometimes Queen Anne, apparently under the\nimpression that the two sovereigns were identical.',
#  u'It was described\nwith some justice as an artistic colony, though it never in any\ndefinable way produced any art.',
#  u'But although its pretensions to be\nan intellectual centre were a little vague, its pretensions to be a\npleasant place were quite indisputable.',
#  u'The stranger who looked for\nthe first time at the quaint red houses could only think how very\noddly shaped the people must be who could fit in to them.',
#  u'Nor when\nhe met the people was he disappointed in this respect.',
#  u'The place\nwas not only pleasant, but perfect, if once he could regard it not\nas a deception but rather as a dream.',
#  u'Even if the people were not\n"artists," the whole was nevertheless artistic.',
#  u'That young man with\nthe long, auburn hair and the impudent face--that young man was not\nreally a poet; but surely he was a poem.',
#  u'That old gentleman with\nthe wild, white beard and the wild, white hat--that venerable\nhumbug was not really a philosopher; but at least he was the cause\nof philosophy in others.',
#  u'That scientific gentleman with the bald,\negg-like head and the bare, bird-like neck had no real right to the\nairs of science that he assumed.',
#  u'He had not discovered anything new\nin biology; but what biological creature could he have discovered\nmore singular than himself?',
#  u'Thus, and thus only, the whole place\nhad properly to be regarded; it had to be considered not so much\nas a workshop for artists, but as a frail but finished work of art.',
#  u'A man who stepped into its social atmosphere felt as if he had\nstepped into a written comedy.',
#  u'More especially this attractive unreality fell upon it about\nnightfall, when the extravagant roofs were dark against the\nafterglow and the whole insane village seemed as separate as a\ndrifting cloud.',
#  u'This again was more strongly true of the many\nnights of local festivity, when the little gardens were often\nilluminated, and the big Chinese lanterns glowed in the dwarfish\ntrees like some fierce and monstrous fruit.',
#  u'And this was strongest\nof all on one particular evening, still vaguely remembered in the\nlocality, of which the auburn-haired poet was the hero.',
#  u'It was not\nby any means the only evening of which he was the hero.',
#  u'On many\nnights those passing by his little back garden might hear his high,\ndidactic voice laying down the law to men and particularly to\nwomen.',
#  u'The attitude of women in such cases was indeed one of the\nparadoxes of the place.',
#  u'Most of the women were of the kind vaguely\ncalled emancipated, and professed some protest against male\nsupremacy.',
#  u'Yet these new women would always pay to a man the\nextravagant compliment which no ordinary woman ever pays to him,\nthat of listening while he is talking.',
#  u'And Mr. Lucian Gregory, the\nred-haired poet, was really (in some sense) a man worth listening\nto, even if one only laughed at the end of it.',
#  u'He put the old cant\nof the lawlessness of art and the art of lawlessness with a certain\nimpudent freshness which gave at least a momentary pleasure.',
#  u'He was\nhelped in some degree by the arresting oddity of his appearance,\nwhich he worked, as the phrase goes, for all it was worth.',
#  u"His dark\nred hair parted in the middle was literally like a woman's, and\ncurved into the slow curls of a virgin in a pre-Raphaelite picture.",
#  u'From within this almost saintly oval, however, his face projected\nsuddenly broad and brutal, the chin carried forward with a look of\ncockney contempt.',
#  u'This combination at once tickled and terrified\nthe nerves of a neurotic population.',
#  u'He seemed like a walking\nblasphemy, a blend of the angel and the ape.',
#  u'This particular evening, if it is remembered for nothing else,\nwill be remembered in that place for its strange sunset.',
#  u'It looked\nlike the end of the world.',
#  u'All the heaven seemed covered with a\nquite vivid and palpable plumage; you could only say that the sky\nwas full of feathers, and of feathers that almost brushed the\nface.',
#  u'Across the great part of the dome they were grey, with the\nstrangest tints of violet and mauve and an unnatural pink or pale\ngreen; but towards the west the whole grew past description,\ntransparent and passionate, and the last red-hot plumes of it\ncovered up the sun like something too good to be seen.',
#  u'The whole\nwas so close about the earth, as to express nothing but a violent\nsecrecy.',
#  u'The very empyrean seemed to be a secret.',
#  u'It expressed\nthat splendid smallness which is the soul of local patriotism.',
#  u'The\nvery sky seemed small.',
#  u'I say that there are some inhabitants who may remember the evening\nif only by that oppressive sky.',
#  u'There are others who may remember\nit because it marked the first appearance in the place of the\nsecond poet of Saffron Park.',
#  u'For a long time the red-haired\nrevolutionary had reigned without a rival; it was upon the night\nof the sunset that his solitude suddenly ended.',
#  u'The new poet, who\nintroduced himself by the name of Gabriel Syme was a very\nmild-looking mortal, with a fair, pointed beard and faint, yellow\nhair.',
#  u'But an impression grew that he was less meek than he looked.',
#  u'He signalised his entrance by differing with the established poet,\nGregory, upon the whole nature of poetry.',
#  u'He said that he (Syme)\nwas poet of law, a poet of order; nay, he said he was a poet of\nrespectability.',
#  u'So all the Saffron Parkers looked at him as if he\nhad that moment fallen out of that impossible sky.',
#  u'In fact, Mr. Lucian Gregory, the anarchic poet, connected the two\nevents.',
#  u'"It may well be," he said, in his sudden lyrical manner, "it may\nwell be on such a night of clouds and cruel colours that there is\nbrought forth upon the earth such a portent as a respectable poet.',
#  u'You say you are a poet of law; I say you are a contradiction in\nterms.',
#  u'I only wonder there were not comets and earthquakes on the\nnight you appeared in this garden."',
#  u'The man with the meek blue eyes and the pale, pointed beard endured\nthese thunders with a certain submissive solemnity.',
#  u"The third party\nof the group, Gregory's sister Rosamond, who had her brother's\nbraids of red hair, but a kindlier face underneath them, laughed\nwith such mixture of admiration and disapproval as she gave\ncommonly to the family oracle.",
#  u'Gregory resumed in high oratorical good humour.',
#  u'"An artist is identical with an anarchist," he cried.',
#  u'"You might\ntranspose the words anywhere.',
#  u'An anarchist is an artist.',
#  u'The man\nwho throws a bomb is an artist, because he prefers a great moment\nto everything.',
#  u'He sees how much more valuable is one burst of\nblazing light, one peal of perfect thunder, than the mere common\nbodies of a few shapeless policemen.',
#  u'An artist disregards all\ngovernments, abolishes all conventions.',
#  u'The poet delights in\ndisorder only.',
#  u'If it were not so, the most poetical thing in the\nworld would be the Underground Railway."',
#  u'"So it is," said Mr. Syme.',
#  u'"Nonsense!"',
#  u'said Gregory, who was very rational when anyone else\nattempted paradox.',
#  u'"Why do all the clerks and navvies in the\nrailway trains look so sad and tired, so very sad and tired?',
#  u'I will\ntell you.',
#  u'It is because they know that the train is going right.',
#  u'It\nis because they know that whatever place they have taken a ticket\nfor that place they will reach.',
#  u'It is because after they have\npassed Sloane Square they know that the next station must be\nVictoria, and nothing but Victoria.',
#  u'Oh, their wild rapture!',
#  u'oh,\ntheir eyes like stars and their souls again in Eden, if the next\nstation were unaccountably Baker Street!"',
#  u'"It is you who are unpoetical," replied the poet Syme.',
#  u'"If what you\nsay of clerks is true, they can only be as prosaic as your poetry.',
#  u'The rare, strange thing is to hit the mark; the gross, obvious\nthing is to miss it.',
#  u'We feel it is epical when man with one wild\narrow strikes a distant bird.',
#  u'Is it not also epical when man with\none wild engine strikes a distant station?',
#  u'Chaos is dull; because\nin chaos the train might indeed go anywhere, to Baker Street or to\nBagdad.',
#  u'But man is a magician, and his whole magic is in this, that\nhe does say Victoria, and lo!',
#  u'it is Victoria.',
#  u'No, take your books\nof mere poetry and prose; let me read a time table, with tears of\npride.',
#  u'Take your Byron, who commemorates the defeats of man; give\nme Bradshaw, who commemorates his victories.',
#  u'Give me Bradshaw, I\nsay!"',
#  u'"Must you go?"',
#  u'inquired Gregory sarcastically.',
#  u'"I tell you," went on Syme with passion, "that every time a train\ncomes in I feel that it has broken past batteries of besiegers, and\nthat man has won a battle against chaos.',
#  u'You say contemptuously\nthat when one has left Sloane Square one must come to Victoria.',
#  u'I\nsay that one might do a thousand things instead, and that whenever\nI really come there I have the sense of hairbreadth escape.',
#  u"And\nwhen I hear the guard shout out the word 'Victoria,' it is not an\nunmeaning word.",
#  u'It is to me the cry of a herald announcing\nconquest.',
#  u'It is to me indeed \'Victoria\'; it is the victory of\nAdam."',
#  u'Gregory wagged his heavy, red head with a slow and sad smile.',
#  u'"And even then," he said, "we poets always ask the question, \'And\nwhat is Victoria now that you have got there ?\'',
#  u'You think Victoria\nis like the New Jerusalem.',
#  u'We know that the New Jerusalem will only\nbe like Victoria.',
#  u'Yes, the poet will be discontented even in the\nstreets of heaven.',
#  u'The poet is always in revolt."',
#  u'"There again," said Syme irritably, "what is there poetical about\nbeing in revolt ?',
#  u'You might as well say that it is poetical to be\nsea-sick.',
#  u'Being sick is a revolt.',
#  u"Both being sick and being\nrebellious may be the wholesome thing on certain desperate\noccasions; but I'm hanged if I can see why they are poetical.",
#  u'Revolt in the abstract is--revolting.',
#  u'It\'s mere vomiting."',
#  u'The girl winced for a flash at the unpleasant word, but Syme was\ntoo hot to heed her.',
#  u'"It is things going right," he cried, "that is poetical I Our\ndigestions, for instance, going sacredly and silently right, that\nis the foundation of all poetry.',
#  u'Yes, the most poetical thing, more\npoetical than the flowers, more poetical than the stars--the most\npoetical thing in the world is not being sick."',
#  u'"Really," said Gregory superciliously, "the examples you choose--"\n\n"I beg your pardon," said Syme grimly, "I forgot we had abolished\nall conventions."',
#  u"For the first time a red patch appeared on Gregory's forehead.",
#  u'"You don\'t expect me," he said, "to revolutionise society on this\nlawn ?"',
#  u'Syme looked straight into his eyes and smiled sweetly.',
#  u'"No, I don\'t," he said; "but I suppose that if you were serious\nabout your anarchism, that is exactly what you would do."',
#  u"Gregory's big bull's eyes blinked suddenly like those of an angry\nlion, and one could almost fancy that his red mane rose.",
#  u'"Don\'t you think, then," he said in a dangerous voice, "that I am\nserious about my anarchism?"',
#  u'"I beg your pardon ?"',
#  u'said Syme.',
#  u'"Am I not serious about my anarchism ?"',
#  u'cried Gregory, with knotted\nfists.',
#  u'"My dear fellow!"',
#  u'said Syme, and strolled away.',
#  u'With surprise, but with a curious pleasure, he found Rosamond\nGregory still in his company.',
#  u'"Mr. Syme," she said, "do the people who talk like you and my\nbrother often mean what they say ?',
#  u'Do you mean what you say now ?"',
#  u'Syme smiled.',
#  u'"Do you ?"',
#  u'he asked.',
#  u'"What do you mean ?"',
#  u'asked the girl, with grave eyes.',
#  u'"My dear Miss Gregory," said Syme gently, "there are many kinds of\nsincerity and insincerity.',
#  u"When you say 'thank you' for the salt,\ndo you mean what you say ?",
#  u'No.',
#  u"When you say 'the world is round,'\ndo you mean what you say ?",
#  u'No.',
#  u"It is true, but you don't mean it.",
#  u'Now, sometimes a man like your brother really finds a thing he does\nmean.',
#  u'It may be only a half-truth, quarter-truth, tenth-truth; but\nthen he says more than he means--from sheer force of meaning it."',
#  u'She was looking at him from under level brows; her face was grave\nand open, and there had fallen upon it the shadow of that\nunreasoning responsibility which is at the bottom of the most\nfrivolous woman, the maternal watch which is as old as the world.',
#  u'"Is he really an anarchist, then?"',
#  u'she asked.',
#  u'"Only in that sense I speak of," replied Syme; "or if you prefer\nit, in that nonsense."',
#  u'She drew her broad brows together and said abruptly--\n\n"He wouldn\'t really use--bombs or that sort of thing?"',
#  u'Syme broke into a great laugh, that seemed too large for his slight\nand somewhat dandified figure.',
#  u'"Good Lord, no!"',
#  u'he said, "that has to be done anonymously."',
#  u"And at that the corners of her own mouth broke into a smile, and\nshe thought with a simultaneous pleasure of Gregory's absurdity\nand of his safety.",
#  u'Syme strolled with her to a seat in the corner of the garden, and\ncontinued to pour out his opinions.',
#  u'For he was a sincere man, and\nin spite of his superficial airs and graces, at root a humble one.',
#  u'And it is always the humble man who talks too much; the proud man\nwatches himself too closely.',
#  u'He defended respectability with\nviolence and exaggeration.',
#  u'He grew passionate in his praise of\ntidiness and propriety.',
#  u'All the time there was a smell of lilac\nall round him.',
#  u'Once he heard very faintly in some distant street a\nbarrel-organ begin to play, and it seemed to him that his heroic\nwords were moving to a tiny tune from under or beyond the world.',
#  u"He stared and talked at the girl's red hair and amused face for\nwhat seemed to be a few minutes; and then, feeling that the groups\nin such a place should mix, rose to his feet.",
#  u'To his astonishment,\nhe discovered the whole garden empty.',
#  u'Everyone had gone long ago,\nand he went himself with a rather hurried apology.',
#  u'He left with a\nsense of champagne in his head, which he could not afterwards\nexplain.',
#  u'In the wild events which were to follow this girl had no\npart at all; he never saw her again until all his tale was over.',
#  u'And yet, in some indescribable way, she kept recurring like a\nmotive in music through all his mad adventures afterwards, and the\nglory of her strange hair ran like a red thread through those dark\nand ill-drawn tapestries of the night.',
#  u'For what followed was so\nimprobable, that it might well have been a dream.',
#  u'When Syme went out into the starlit street, he found it for the\nmoment empty.',
#  u'Then he realised (in some odd way) that the silence\nwas rather a living silence than a dead one.',
#  u'Directly outside the\ndoor stood a street lamp, whose gleam gilded the leaves of the tree\nthat bent out over the fence behind him.',
#  u'About a foot from the\nlamp-post stood a figure almost as rigid and motionless as the\nlamp-post itself.',
#  u'The tall hat and long frock coat were black; the\nface, in an abrupt shadow, was almost as dark.',
#  u'Only a fringe of\nfiery hair against the light, and also something aggressive in the\nattitude, proclaimed that it was the poet Gregory.',
#  u'He had something\nof the look of a masked bravo waiting sword in hand for his foe.',
#  u'He made a sort of doubtful salute, which Syme somewhat more\nformally returned.',
#  u'"I was waiting for you," said Gregory.',
#  u'"Might I have a moment\'s\nconversation?"',
#  u'"Certainly.',
#  u'About what?"',
#  u'asked Syme in a sort of weak wonder.',
#  u'Gregory struck out with his stick at the lamp-post, and then at the\ntree.',
#  u'"About this and this," he cried; "about order and anarchy.',
#  u'There is your precious order, that lean, iron lamp, ugly and\nbarren; and there is anarchy, rich, living, reproducing\nitself--there is anarchy, splendid in green and gold."',
#  u'"All the same," replied Syme patiently, "just at present you only\nsee the tree by the light of the lamp.',
#  u'I wonder when you would ever\nsee the lamp by the light of the tree."',
#  u'Then after a pause he said,\n"But may I ask if you have been standing out here in the dark only\nto resume our little argument?"',
#  u'"No," cried out Gregory, in a voice that rang down the street, "I\ndid not stand here to resume our argument, but to end it for ever."',
#  u'The silence fell again, and Syme, though he understood nothing,\nlistened instinctively for something serious.',
#  u'Gregory began in a\nsmooth voice and with a rather bewildering smile.',
#  u'"Mr. Syme," he said, "this evening you succeeded in doing something\nrather remarkable.',
#  u'You did something to me that no man born of\nwoman has ever succeeded in doing before."',
#  u'"Indeed!"',
#  u'"Now I remember," resumed Gregory reflectively, "one other person\nsucceeded in doing it.',
#  u'The captain of a penny steamer (if I\nremember correctly) at Southend.',
#  u'You have irritated me."',
#  u'"I am very sorry," replied Syme with gravity.',
#  u'"I am afraid my fury and your insult are too shocking to be wiped\nout even with an apology," said Gregory very calmly.',
#  u'"No duel\ncould wipe it out.',
#  u'If I struck you dead I could not wipe it out.',
#  u'There is only one way by which that insult can be erased, and that\nway I choose.',
#  u'I am going, at the possible sacrifice of my life and\nhonour, to prove to you that you were wrong in what you said."',
#  u'"In what I said?"',
#  u'"You said I was not serious about being an anarchist."',
#  u'"There are degrees of seriousness," replied Syme.',
#  u'"I have never\ndoubted that you were perfectly sincere in this sense, that you\nthought what you said well worth saying, that you thought a\nparadox might wake men up to a neglected truth."',
#  u'Gregory stared at him steadily and painfully.',
#  u'"And in no other sense," he asked, "you think me serious?',
#  u'You think\nme a flaneur who lets fall occasional truths.',
#  u'You do not think that\nin a deeper, a more deadly sense, I am serious."',
#  u'Syme struck his stick violently on the stones of the road.',
#  u'"Serious!"',
#  u'he cried.',
#  u'"Good Lord!',
#  u'is this street serious?',
#  u'Are these\ndamned Chinese lanterns serious?',
#  u'Is the whole caboodle serious?',
#  u'One comes here and talks a pack of bosh, and perhaps some sense as\nwell, but I should think very little of a man who didn\'t keep\nsomething in the background of his life that was more serious than\nall this talking--something more serious, whether it was religion\nor only drink."',
#  u'"Very well," said Gregory, his face darkening, "you shall see\nsomething more serious than either drink or religion."',
#  u'Syme stood waiting with his usual air of mildness until Gregory\nagain opened his lips.',
#  u'"You spoke just now of having a religion.',
#  u'Is it really true that\nyou have one?"',
#  u'"Oh," said Syme with a beaming smile, "we are all Catholics now."',
#  u'"Then may I ask you to swear by whatever gods or saints your\nreligion involves that you will not reveal what I am now going to\ntell you to any son of Adam, and especially not to the police?',
#  u'Will you swear that!',
#  u'If you will take upon yourself this awful\nabnegations if you will consent to burden your soul with a vow\nthat you should never make and a knowledge you should never dream\nabout, I will promise you in return--"\n\n"You will promise me in return?"',
#  u'inquired Syme, as the other\npaused.',
#  u'"I will promise you a very entertaining evening."',
#  u'Syme suddenly\ntook off his hat.',
#  u'"Your offer," he said, "is far too idiotic to be declined.',
#  u'You say\nthat a poet is always an anarchist.',
#  u'I disagree; but I hope at least\nthat he is always a sportsman.',
#  u'Permit me, here and now, to swear as\na Christian, and promise as a good comrade and a fellow-artist,\nthat I will not report anything of this, whatever it is, to the\npolice.',
#  u'And now, in the name of Colney Hatch, what is it?"',
#  u'"I think," said Gregory, with placid irrelevancy, "that we will\ncall a cab."',
#  u'He gave two long whistles, and a hansom came rattling down the\nroad.',
#  u'The two got into it in silence.',
#  u'Gregory gave through the\ntrap the address of an obscure public-house on the Chiswick bank\nof the river.',
#  u'The cab whisked itself away again, and in it these\ntwo fantastics quitted their fantastic town.',
#  u'CHAPTER II\n\nTHE SECRET OF GABRIEL SYME\n\nTHE cab pulled up before a particularly dreary and greasy beershop,\ninto which Gregory rapidly conducted his companion.',
#  u'They seated\nthemselves in a close and dim sort of bar-parlour, at a stained\nwooden table with one wooden leg.',
#  u'The room was so small and dark,\nthat very little could be seen of the attendant who was summoned,\nbeyond a vague and dark impression of something bulky and bearded.',
#  u'"Will you take a little supper?"',
#  u'asked Gregory politely.',
#  u'"The pate\nde foie gras is not good here, but I can recommend the game."',
#  u'Syme received the remark with stolidity, imagining it to be a joke.',
#  u'Accepting the vein of humour, he said, with a well-bred\nindifference--\n\n"Oh, bring me some lobster mayonnaise."',
#  u'To his indescribable astonishment, the man only said "Certainly,\nsir!"',
#  u'and went away apparently to get it.',
#  u'"What will you drink?"',
#  u'resumed Gregory, with the same careless yet\napologetic air.',
#  u'"I shall only have a crepe de menthe myself; I have\ndined.',
#  u'But the champagne can really be trusted.',
#  u'Do let me start you\nwith a half-bottle of Pommery at least?"',
#  u'"Thank you!"',
#  u'said the motionless Syme.',
#  u'"You are very good."',
#  u'His further attempts at conversation, somewhat disorganised in\nthemselves, were cut short finally as by a thunderbolt by the\nactual appearance of the lobster.',
#  u'Syme tasted it, and found it\nparticularly good.',
#  u'Then he suddenly began to eat with great\nrapidity and appetite.',
#  u'"Excuse me if I enjoy myself rather obviously!"',
#  u'he said to Gregory,\nsmiling.',
#  u'"I don\'t often have the luck to have a dream like this.',
#  u'It\nis new to me for a nightmare to lead to a lobster.',
#  u'It is commonly\nthe other way."',
#  u'"You are not asleep, I assure you," said Gregory.',
#  u'"You are, on the\ncontrary, close to the most actual and rousing moment of your\nexistence.',
#  u'Ah, here comes your champagne!',
#  u'I admit that there may be\na slight disproportion, let us say, between the inner arrangements\nof this excellent hotel and its simple and unpretentious exterior.',
#  u'But that is all our modesty.',
#  u'We are the most modest men that ever\nlived on earth."',
#  u'"And who are we?"',
#  u'asked Syme, emptying his champagne glass.',
#  u'"It is quite simple," replied Gregory.',
#  u'"We are the serious\nanarchists, in whom you do not believe."',
#  u'"Oh!"',
#  u'said Syme shortly.',
#  u'"You do yourselves well in drinks."',
#  u'"Yes, we are serious about everything," answered Gregory.',
#  u'Then after a pause he added--\n\n"If in a few moments this table begins to turn round a little,\ndon\'t put it down to your inroads into the champagne.',
#  u'I don\'t wish\nyou to do yourself an injustice."',
#  u'"Well, if I am not drunk, I am mad," replied Syme with perfect\ncalm; "but I trust I can behave like a gentleman in either\ncondition.',
#  u'May I smoke?"',
#  u'"Certainly!"',
#  u'said Gregory, producing a cigar-case.',
#  u'"Try one of\nmine."',
#  u'Syme took the cigar, clipped the end off with a cigar-cutter out\nof his waistcoat pocket, put it in his mouth, lit it slowly, and\nlet out a long cloud of smoke.',
#  u'It is not a little to his credit\nthat he performed these rites with so much composure, for almost\nbefore he had begun them the table at which he sat had begun to\nrevolve, first slowly, and then rapidly, as if at an insane\nseance.',
#  u'"You must not mind it," said Gregory; "it\'s a kind of screw."',
#  u'"Quite so," said Syme placidly, "a kind of screw.',
#  u'How simple that\nis!"',
#  u'The next moment the smoke of his cigar, which had been wavering\nacross the room in snaky twists, went straight up as if from a\nfactory chimney, and the two, with their chairs and table, shot\ndown through the floor as if the earth had swallowed them.',
#  u'They\nwent rattling down a kind of roaring chimney as rapidly as a lift\ncut loose, and they came with an abrupt bump to the bottom.',
#  u'But\nwhen Gregory threw open a pair of doors and let in a red\nsubterranean light, Syme was still smoking with one leg thrown\nover the other, and had not turned a yellow hair.',
#  u'Gregory led him down a low, vaulted passage, at the end of which\nwas the red light.',
#  u'It was an enormous crimson lantern, nearly as\nbig as a fireplace, fixed over a small but heavy iron door.',
#  u'In the\ndoor there was a sort of hatchway or grating, and on this Gregory\nstruck five times.',
#  u'A heavy voice with a foreign accent asked him\nwho he was.',
#  u'To this he gave the more or less unexpected reply,\n"Mr. Joseph Chamberlain."',
#  u'The heavy hinges began to move; it was\nobviously some kind of password.',
#  u'Inside the doorway the passage gleamed as if it were lined with a\nnetwork of steel.',
#  u'On a second glance, Syme saw that the glittering\npattern was really made up of ranks and ranks of rifles and\nrevolvers, closely packed or interlocked.',
#  u'"I must ask you to forgive me all these formalities," said Gregory;\n"we have to be very strict here."',
#  u'"Oh, don\'t apologise," said Syme.',
#  u'"I know your passion for law and\norder," and he stepped into the passage lined with the steel\nweapons.',
#  u'With his long, fair hair and rather foppish frock-coat, he\nlooked a singularly frail and fanciful figure as he walked down\nthat shining avenue of death.',
#  u'They passed through several such passages, and came out at last\ninto a queer steel chamber with curved walls, almost spherical in\nshape, but presenting, with its tiers of benches, something of the\nappearance of a scientific lecture-theatre.',
#  u'There were no rifles or\npistols in this apartment, but round the walls of it were hung more\ndubious and dreadful shapes, things that looked like the bulbs of\niron plants, or the eggs of iron birds.',
#  u'They were bombs, and the\nvery room itself seemed like the inside of a bomb.',
#  u'Syme knocked his\ncigar ash off against the wall, and went in.',
#  u'"And now, my dear Mr. Syme," said Gregory, throwing himself in an\nexpansive manner on the bench under the largest bomb, "now we are\nquite cosy, so let us talk properly.',
#  u'Now no human words can give\nyou any notion of why I brought you here.',
#  u'It was one of those quite\narbitrary emotions, like jumping off a cliff or falling in love.',
#  u'Suffice it to say that you were an inexpressibly irritating fellow,\nand, to do you justice, you are still.',
#  u'I would break twenty oaths\nof secrecy for the pleasure of taking you down a peg.',
#  u'That way you\nhave of lighting a cigar would make a priest break the seal of\nconfession.',
#  u'Well, you said that you were quite certain I was not a\nserious anarchist.',
#  u'Does this place strike you as being serious?"',
#  u'"It does seem to have a moral under all its gaiety," assented\nSyme; "but may I ask you two questions?',
#  u'You need not fear to give\nme information, because, as you remember, you very wisely extorted\nfrom me a promise not to tell the police, a promise I shall\ncertainly keep.',
#  u'So it is in mere curiosity that I make my queries.',
#  u'First of all, what is it really all about?',
#  u'What is it you object\nto?',
#  u'You want to abolish Government?"',
#  u'"To abolish God!"',
#  u'said Gregory, opening the eyes of a fanatic.',
#  u'"We\ndo not only want to upset a few despotisms and police regulations;\nthat sort of anarchism does exist, but it is a mere branch of the\nNonconformists.',
#  u'We dig deeper and we blow you higher.',
#  u'We wish to\ndeny all those arbitrary distinctions of vice and virtue, honour\nand treachery, upon which mere rebels base themselves.',
#  u'The silly\nsentimentalists of the French Revolution talked of the Rights of\nMan!',
#  u'We hate Rights as we hate Wrongs.',
#  u'We have abolished Right and\nWrong."',
#  u'"And Right and Left," said Syme with a simple eagerness, "I hope\nyou will abolish them too.',
#  u'They are much more troublesome to me."',
#  u'"You spoke of a second question," snapped Gregory.',
#  u'"With pleasure," resumed Syme.',
#  u'"In all your present acts and\nsurroundings there is a scientific attempt at secrecy.',
#  u'I have an\naunt who lived over a shop, but this is the first time I have\nfound people living from preference under a public-house.',
#  u'You have\na heavy iron door.',
#  u'You cannot pass it without submitting to the\nhumiliation of calling yourself Mr. Chamberlain.',
#  u'You surround\nyourself with steel instruments which make the place, if I may say\nso, more impressive than homelike.',
#  u'May I ask why, after taking all\nthis trouble to barricade yourselves in the bowels of the earth,\nyou then parade your whole secret by talking about anarchism to\nevery silly woman in Saffron Park?"',
#  u'Gregory smiled.',
#  u'"The answer is simple," he said.',
#  u'"I told you I was a serious\nanarchist, and you did not believe me.',
#  u'Nor do they believe me.',
#  u'Unless I took them into this infernal room they would not believe\nme."',
#  u'Syme smoked thoughtfully, and looked at him with interest.',
#  u'Gregory\nwent on.',
#  u'"The history of the thing might amuse you," he said.',
#  u'"When first I\nbecame one of the New Anarchists I tried all kinds of respectable\ndisguises.',
#  u'I dressed up as a bishop.',
#  u'I read up all about bishops\nin our anarchist pamphlets, in Superstition the Vampire and\nPriests of Prey.',
#  u'I certainly understood from them that bishops are\nstrange and terrible old men keeping a cruel secret from mankind.',
#  u'I was misinformed.',
#  u"When on my first appearing in episcopal gaiters\nin a drawing-room I cried out in a voice of thunder, 'Down!",
#  u'down!',
#  u"presumptuous human reason!'",
#  u'they found out in some way that I was\nnot a bishop at all.',
#  u'I was nabbed at once.',
#  u'Then I made up as a\nmillionaire; but I defended Capital with so much intelligence that\na fool could see that I was quite poor.',
#  u'Then I tried being a\nmajor.',
#  u'Now I am a humanitarian myself, but I have, I hope, enough\nintellectual breadth to understand the position of those who, like\nNietzsche, admire violence--the proud, mad war of Nature and all\nthat, you know.',
#  u'I threw myself into the major.',
#  u'I drew my sword and\nwaved it constantly.',
#  u"I called out 'Blood!'",
#  u'abstractedly, like a\nman calling for wine.',
#  u"I often said, 'Let the weak perish; it is\nthe Law.'",
#  u"Well, well, it seems majors don't do this.",
#  u'I was nabbed\nagain.',
#  u'At last I went in despair to the President of the Central\nAnarchist Council, who is the greatest man in Europe."',
#  u'"What is his name?"',
#  u'asked Syme.',
#  u'"You would not know it," answered Gregory.',
#  u'"That is his greatness.',
#  u'Caesar and Napoleon put all their genius into being heard of, and\nthey were heard of.',
#  u'He puts all his genius into not being heard of,\nand he is not heard of.',
#  u'But you cannot be for five minutes in the\nroom with him without feeling that Caesar and Napoleon would have\nbeen children in his hands."',
#  u'He was silent and even pale for a moment, and then resumed--\n\n"But whenever he gives advice it is always something as startling\nas an epigram, and yet as practical as the Bank of England.',
#  u"I said\nto him, 'What disguise will hide me from the world?",
#  u"What can I find\nmore respectable than bishops and majors?'",
#  u'He looked at me with his\nlarge but indecipherable face.',
#  u"'You want a safe disguise, do you?",
#  u"You want a dress which will guarantee you harmless; a dress in\nwhich no one would ever look for a bomb?'",
#  u'I nodded.',
#  u"He suddenly\nlifted his lion's voice.",
#  u"'Why, then, dress up as an anarchist, you\nfool!'",
#  u'he roared so that the room shook.',
#  u"'Nobody will ever expect\nyou to do anything dangerous then.'",
#  u'And he turned his broad back\non me without another word.',
#  u'I took his advice, and have never\nregretted it.',
#  u'I preached blood and murder to those women day and\nnight, and--by God!--they would let me wheel their perambulators."',
#  u'Syme sat watching him with some respect in his large, blue eyes.',
#  u'"You took me in," he said.',
#  u'"It is really a smart dodge."',
#  u'Then after a pause he added--\n\n"What do you call this tremendous President of yours?"',
#  u'"We generally call him Sunday," replied Gregory with simplicity.',
#  u"'You see, there are seven members of the Central Anarchist\nCouncil, and they are named after days of the week.",
#  u'He is called\nSunday, by some of his admirers Bloody Sunday.',
#  u'It is curious you\nshould mention the matter, because the very night you have dropped\nin (if I may so express it) is the night on which our London\nbranch, which assembles in this room, has to elect its own deputy\nto fill a vacancy in the Council.',
#  u'The gentleman who has for some\ntime past played, with propriety and general applause, the\ndifficult part of Thursday, has died quite suddenly.',
#  u'Consequently,\nwe have called a meeting this very evening to elect a successor."',
#  u'He got to his feet and strolled across the room with a sort of\nsmiling embarrassment.',
#  u'"I feel somehow as if you were my mother, Syme," he continued\ncasually.',
#  u'"I feel that I can confide anything to you, as you have\npromised to tell nobody.',
#  u'In fact, I will confide to you something\nthat I would not say in so many words to the anarchists who will be\ncoming to the room in about ten minutes.',
#  u'We shall, of course, go\nthrough a form of election; but I don\'t mind telling you that it is\npractically certain what the result will be."',
#  u'He looked down for a\nmoment modestly.',
#  u'"It is almost a settled thing that I am to be\nThursday."',
#  u'"My dear fellow."',
#  u'said Syme heartily, "I congratulate you.',
#  u'A great\ncareer!"',
#  u'Gregory smiled in deprecation, and walked across the room, talking\nrapidly.',
#  u'"As a matter of fact, everything is ready for me on this table," he\nsaid, "and the ceremony will probably be the shortest possible."',
#  u"Syme also strolled across to the table, and found lying across it a\nwalking-stick, which turned out on examination to be a sword-stick,\na large Colt's revolver, a sandwich case, and a formidable flask of\nbrandy.",
#  u'Over the chair, beside the table, was thrown a\nheavy-looking cape or cloak.',
#  u'"I have only to get the form of election finished," continued\nGregory with animation, "then I snatch up this cloak and stick,\nstuff these other things into my pocket, step out of a door in\nthis cavern, which opens on the river, where there is a steam-tug\nalready waiting for me, and then--then--oh, the wild joy of being\nThursday!"',
#  u'And he clasped his hands.',
#  u'Syme, who had sat down once more with his usual insolent languor,\ngot to his feet with an unusual air of hesitation.',
#  u'"Why is it," he asked vaguely, "that I think you are quite a decent\nfellow?',
#  u'Why do I positively like you, Gregory?"',
#  u'He paused a moment,\nand then added with a sort of fresh curiosity, "Is it because you\nare such an ass?"',
#  u'There was a thoughtful silence again, and then he cried out--\n\n"Well, damn it all!',
#  u'this is the funniest situation I have ever been\nin in my life, and I am going to act accordingly.',
#  u'Gregory, I gave\nyou a promise before I came into this place.',
#  u'That promise I would\nkeep under red-hot pincers.',
#  u'Would you give me, for my own safety, a\nlittle promise of the same kind? "',
#  u'"A promise?"',
#  u'asked Gregory, wondering.',
#  u'"Yes," said Syme very seriously, "a promise.',
#  u'I swore before God\nthat I would not tell your secret to the police.',
#  u'Will you swear by\nHumanity, or whatever beastly thing you believe in, that you will\nnot tell my secret to the anarchists?"',
#  u'"Your secret?"',
#  u'asked the staring Gregory.',
#  u'"Have you got a secret?"',
#  u'"Yes," said Syme, "I have a secret."',
#  u'Then after a pause, "Will you\nswear?"',
#  u'Gregory glared at him gravely for a few moments, and then said\nabruptly--\n\n"You must have bewitched me, but I feel a furious curiosity about\nyou.',
#  u'Yes, I will swear not to tell the anarchists anything you tell\nme.',
#  u'But look sharp, for they will be here in a couple of minutes."',
#  u"Syme rose slowly to his feet and thrust his long, white hands into\nhis long, grey trousers' pockets.",
#  u'Almost as he did so there came\nfive knocks on the outer grating, proclaiming the arrival of the\nfirst of the conspirators.',
#  u'"Well," said Syme slowly, "I don\'t know how to tell you the truth\nmore shortly than by saying that your expedient of dressing up as\nan aimless poet is not confined to you or your President.',
#  u'We have\nknown the dodge for some time at Scotland Yard."',
#  u'Gregory tried to spring up straight, but he swayed thrice.',
#  u'"What do you say?"',
#  u'he asked in an inhuman voice.',
#  u'"Yes," said Syme simply, "I am a police detective.',
#  u'But I think I\nhear your friends coming."',
#  u'From the doorway there came a murmur of "Mr. Joseph Chamberlain."',
#  u'It was repeated twice and thrice, and then thirty times, and the\ncrowd of Joseph Chamberlains (a solemn thought) could be heard\ntrampling down the corridor.',
#  u"CHAPTER III\n\nTHE MAN WHO WAS THURSDAY\n\nBEFORE one of the fresh faces could appear at the doorway,\nGregory's stunned surprise had fallen from him.",
#  u'He was beside the\ntable with a bound, and a noise in his throat like a wild beast.',
#  u"He caught up the Colt's revolver and took aim at Syme.",
#  u'Syme did\nnot flinch, but he put up a pale and polite hand.',
#  u'"Don\'t be such a silly man," he said, with the effeminate dignity\nof a curate.',
#  u'"Don\'t you see it\'s not necessary?',
#  u"Don't you see that\nwe're both in the same boat?",
#  u'Yes, and jolly sea-sick."',
#  u'Gregory could not speak, but he could not fire either, and he\nlooked his question.',
#  u'"Don\'t you see we\'ve checkmated each other?"',
#  u'cried Syme.',
#  u'"I can\'t\ntell the police you are an anarchist.',
#  u"You can't tell the anarchists\nI'm a policeman.",
#  u'I can only watch you, knowing what you are; you\ncan only watch me, knowing what I am.',
#  u"In short, it's a lonely,\nintellectual duel, my head against yours.",
#  u"I'm a policeman deprived\nof the help of the police.",
#  u'You, my poor fellow, are an anarchist\ndeprived of the help of that law and organisation which is so\nessential to anarchy.',
#  u'The one solitary difference is in your\nfavour.',
#  u'You are not surrounded by inquisitive policemen; I am\nsurrounded by inquisitive anarchists.',
#  u'I cannot betray you, but I\nmight betray myself.',
#  u'Come, come!',
#  u'wait and see me betray myself.',
#  u'I\nshall do it so nicely."',
#  u'Gregory put the pistol slowly down, still staring at Syme as if he\nwere a sea-monster.',
#  u'"I don\'t believe in immortality," he said at last, "but if, after\nall this, you were to break your word, God would make a hell only\nfor you, to howl in for ever."',
#  u'"I shall not break my word," said Syme sternly, "nor will you\nbreak yours.',
#  u'Here are your friends."',
#  u'The mass of the anarchists entered the room heavily, with a\nslouching and somewhat weary gait; but one little man, with a\nblack beard and glasses--a man somewhat of the type of Mr. Tim\nHealy--detached himself, and bustled forward with some papers\nin his hand.',
#  u'"Comrade Gregory," he said, "I suppose this man is a delegate?"',
#  u'Gregory, taken by surprise, looked down and muttered the name of\nSyme; but Syme replied almost pertly--\n\n"I am glad to see that your gate is well enough guarded to make it\nhard for anyone to be here who was not a delegate."',
#  u'The brow of the little man with the black beard was, however, still\ncontracted with something like suspicion.',
#  u'"What branch do you represent?"',
#  u'he asked sharply.',
#  u'"I should hardly call it a branch," said Syme, laughing; "I should\ncall it at the very least a root."',
#  u'"What do you mean?"',
#  u'"The fact is," said Syme serenely, "the truth is I am a\nSabbatarian.',
#  u'I have been specially sent here to see that you show\na due observance of Sunday."',
#  u'The little man dropped one of his papers, and a flicker of fear\nwent over all the faces of the group.',
#  u'Evidently the awful\nPresident, whose name was Sunday, did sometimes send down such\nirregular ambassadors to such branch meetings.',
#  u'"Well, comrade," said the man with the papers after a pause, "I\nsuppose we\'d better give you a seat in the meeting?"',
#  u'"If you ask my advice as a friend," said Syme with severe\nbenevolence, "I think you\'d better."',
#  u'When Gregory heard the dangerous dialogue end, with a sudden safety\nfor his rival, he rose abruptly and paced the floor in painful\nthought.',
#  u'He was, indeed, in an agony of diplomacy.',
#  u"It was clear\nthat Syme's inspired impudence was likely to bring him out of all\nmerely accidental dilemmas.",
#  u'Little was to be hoped from them.',
#  u'He\ncould not himself betray Syme, partly from honour, but partly also\nbecause, if he betrayed him and for some reason failed to destroy\nhim, the Syme who escaped would be a Syme freed from all obligation\nof secrecy, a Syme who would simply walk to the nearest police\nstation.',
#  u"After all, it was only one night's discussion, and only\none detective who would know of it.",
#  u'He would let out as little as\npossible of their plans that night, and then let Syme go, and\nchance it.',
#  u'He strode across to the group of anarchists, which was already\ndistributing itself along the benches.',
#  u'"I think it is time we began," he said; "the steam-tug is waiting\non the river already.',
#  u'I move that Comrade Buttons takes the chair."',
#  u'This being approved by a show of hands, the little man with the\npapers slipped into the presidential seat.',
#  u'"Comrades," he began, as sharp as a pistol-shot, "our meeting\ntonight is important, though it need not be long.',
#  u'This branch\nhas always had the honour of electing Thursdays for the Central\nEuropean Council.',
#  u'We have elected many and splendid Thursdays.',
#  u'We\nall lament the sad decease of the heroic worker who occupied the\npost until last week.',
#  u'As you know, his services to the cause were\nconsiderable.',
#  u'He organised the great dynamite coup of Brighton\nwhich, under happier circumstances, ought to have killed everybody\non the pier.',
#  u'As you also know, his death was as self-denying as\nhis life, for he died through his faith in a hygienic mixture of\nchalk and water as a substitute for milk, which beverage he\nregarded as barbaric, and as involving cruelty to the cow.',
#  u'Cruelty, or anything approaching to cruelty, revolted him always.',
#  u'But it is not to acclaim his virtues that we are met, but for a\nharder task.',
#  u'It is difficult properly to praise his qualities, but\nit is more difficult to replace them.',
#  u'Upon you, comrades, it\ndevolves this evening to choose out of the company present the man\nwho shall be Thursday.',
#  u'If any comrade suggests a name I will put\nit to the vote.',
#  u'If no comrade suggests a name, I can only tell\nmyself that that dear dynamiter, who is gone from us, has carried\ninto the unknowable abysses the last secret of his virtue and his\ninnocence."',
#  u'There was a stir of almost inaudible applause, such as is sometimes\nheard in church.',
#  u'Then a large old man, with a long and venerable\nwhite beard, perhaps the only real working-man present, rose\nlumberingly and said--\n\n"I move that Comrade Gregory be elected Thursday," and sat\nlumberingly down again.',
#  u'"Does anyone second?"',
#  u'asked the chairman.',
#  u'A little man with a velvet coat and pointed beard seconded.',
#  u'"Before I put the matter to the vote," said the chairman, "I will\ncall on Comrade Gregory to make a statement."',
#  u'Gregory rose amid a great rumble of applause.',
#  u'His face was deadly\npale, so that by contrast his queer red hair looked almost scarlet.',
#  u'But he was smiling and altogether at ease.',
#  u'He had made up his mind,\nand he saw his best policy quite plain in front of him like a white\nroad.',
#  u"His best chance was to make a softened and ambiguous speech,\nsuch as would leave on the detective's mind the impression that the\nanarchist brotherhood was a very mild affair after all.",
# ...
#  u'Before he finally left the\npolice premises his friend provided him with a small blue card,\non which was written, "The Last Crusade," and a number, the sign\nof his official authority.',
#  u'He put this carefully in his upper\nwaistcoat pocket, lit a cigarette, and went forth to track and\nfight the enemy in all the drawing-rooms of London.',
#  u'Where his\nadventure ultimately led him we have already seen.',
#  u'At about\nhalf-past one on a February night he found himself steaming in a\nsmall tug up the silent Thames, armed with swordstick and revolver,\nthe duly elected Thursday of the Central Council of Anarchists.',
#  u'When Syme stepped out on to the steam-tug he had a singular\nsensation of stepping out into something entirely new; not merely\ninto the landscape of a new land, but even into the landscape of a\nnew planet.',
#  u'This was mainly due to the insane yet solid decision of\nthat evening, though partly also to an entire change in the weather\nand the sky since he entered the little tavern some two hours\nbefore.',
#  u'Every trace of the passionate plumage of the cloudy sunset\nhad been swept away, and a naked moon stood in a naked sky.',
#  u'The\nmoon was so strong and full that (by a paradox often to be noticed)\nit seemed like a weaker sun.',
#  u'It gave, not the sense of bright\nmoonshine, but rather of a dead daylight.',
#  u'Over the whole landscape lay a luminous and unnatural\ndiscoloration, as of that disastrous twilight which Milton spoke\nof as shed by the sun in eclipse; so that Syme fell easily into\nhis first thought, that he was actually on some other and emptier\nplanet, which circled round some sadder star.',
#  u'But the more he felt\nthis glittering desolation in the moonlit land, the more his own\nchivalric folly glowed in the night like a great fire.',
#  u'Even the\ncommon things he carried with him--the food and the brandy and the\nloaded pistol--took on exactly that concrete and material poetry\nwhich a child feels when he takes a gun upon a journey or a bun\nwith him to bed.',
#  u'The sword-stick and the brandy-flask, though in\nthemselves only the tools of morbid conspirators, became the\nexpressions of his own more healthy romance.',
#  u'The sword-stick\nbecame almost the sword of chivalry, and the brandy the wine of\nthe stirrup-cup.',
#  u'For even the most dehumanised modern fantasies\ndepend on some older and simpler figure; the adventures may be\nmad, but the adventurer must be sane.',
#  u'The dragon without St.\nGeorge would not even be grotesque.',
#  u'So this inhuman landscape was\nonly imaginative by the presence of a man really human.',
#  u"To Syme's\nexaggerative mind the bright, bleak houses and terraces by the\nThames looked as empty as the mountains of the moon.",
#  u'But even the\nmoon is only poetical because there is a man in the moon.',
#  u'The tug was worked by two men, and with much toil went\ncomparatively slowly.',
#  u'The clear moon that had lit up Chiswick had\ngone down by the time that they passed Battersea, and when they\ncame under the enormous bulk of Westminster day had already begun\nto break.',
#  u'It broke like the splitting of great bars of lead,\nshowing bars of silver; and these had brightened like white fire\nwhen the tug, changing its onward course, turned inward to a large\nlanding stage rather beyond Charing Cross.',
#  u'The great stones of the Embankment seemed equally dark and gigantic\nas Syme looked up at them.',
#  u'They were big and black against the huge\nwhite dawn.',
#  u'They made him feel that he was landing on the colossal\nsteps of some Egyptian palace; and, indeed, the thing suited his\nmood, for he was, in his own mind, mounting to attack the solid\nthrones of horrible and heathen kings.',
#  u'He leapt out of the boat on\nto one slimy step, and stood, a dark and slender figure, amid the\nenormous masonry.',
#  u'The two men in the tug put her off again and\nturned up stream.',
#  u'They had never spoken a word.',
#  u'CHAPTER V\n\nTHE FEAST OF FEAR\n\nAT first the large stone stair seemed to Syme as deserted as a\npyramid; but before he reached the top he had realised that there\nwas a man leaning over the parapet of the Embankment and looking\nout across the river.',
#  u'As a figure he was quite conventional, clad\nin a silk hat and frock-coat of the more formal type of fashion;\nhe had a red flower in his buttonhole.',
#  u'As Syme drew nearer to him\nstep by step, he did not even move a hair; and Syme could come\nclose enough to notice even in the dim, pale morning light that\nhis face was long, pale and intellectual, and ended in a small\ntriangular tuft of dark beard at the very point of the chin, all\nelse being clean-shaven.',
#  u'This scrap of hair almost seemed a mere\noversight; the rest of the face was of the type that is best\nshaven--clear-cut, ascetic, and in its way noble.',
#  u'Syme drew closer\nand closer, noting all this, and still the figure did not stir.',
#  u'At first an instinct had told Syme that this was the man whom he\nwas meant to meet.',
#  u'Then, seeing that the man made no sign, he had\nconcluded that he was not.',
#  u'And now again he had come back to a\ncertainty that the man had something to do with his mad adventure.',
#  u'For the man remained more still than would have been natural if a\nstranger had come so close.',
#  u'He was as motionless as a wax-work,\nand got on the nerves somewhat in the same way.',
#  u'Syme looked again\nand again at the pale, dignified and delicate face, and the face\nstill looked blankly across the river.',
#  u'Then he took out of his\npocket the note from Buttons proving his election, and put it\nbefore that sad and beautiful face.',
#  u'Then the man smiled, and his\nsmile was a shock, for it was all on one side, going up in the\nright cheek and down in the left.',
#  u'There was nothing, rationally speaking, to scare anyone about\nthis.',
#  u'Many people have this nervous trick of a crooked smile, and\nin many it is even attractive.',
#  u"But in all Syme's circumstances,\nwith the dark dawn and the deadly errand and the loneliness on the\ngreat dripping stones, there was something unnerving in it.",
#  u'There was the silent river and the silent man, a man of even\nclassic face.',
#  u'And there was the last nightmare touch that his\nsmile suddenly went wrong.',
#  u"The spasm of smile was instantaneous, and the man's face dropped\nat once into its harmonious melancholy.",
#  u'He spoke without further\nexplanation or inquiry, like a man speaking to an old colleague.',
#  u'"If we walk up towards Leicester Square," he said, "we shall just\nbe in time for breakfast.',
#  u'Sunday always insists on an early\nbreakfast.',
#  u'Have you had any sleep?"',
#  u'"No," said Syme.',
#  u'"Nor have I," answered the man in an ordinary tone.',
#  u'"I shall try to\nget to bed after breakfast."',
#  u'He spoke with casual civility, but in an utterly dead voice that\ncontradicted the fanaticism of his face.',
#  u'It seemed almost as if all\nfriendly words were to him lifeless conveniences, and that his only\nlife was hate.',
#  u'After a pause the man spoke again.',
#  u'"Of course, the Secretary of the branch told you everything that\ncan be told.',
#  u'But the one thing that can never be told is the last\nnotion of the President, for his notions grow like a tropical\nforest.',
#  u"So in case you don't know, I'd better tell you that he is\ncarrying out his notion of concealing ourselves by not concealing\nourselves to the most extraordinary lengths just now.",
#  u'Originally,\nof course, we met in a cell underground, just as your branch does.',
#  u'Then Sunday made us take a private room at an ordinary restaurant.',
#  u"He said that if you didn't seem to be hiding nobody hunted you out.",
#  u'Well, he is the only man on earth, I know; but sometimes I really\nthink that his huge brain is going a little mad in its old age.',
#  u'For\nnow we flaunt ourselves before the public.',
#  u'We have our breakfast on\na balcony--on a balcony, if you please--overlooking Leicester\nSquare."',
#  u'"And what do the people say?"',
#  u'asked Syme.',
#  u'"It\'s quite simple what they say," answered his guide.',
#  u'"They say we are a lot of jolly gentlemen who pretend they are\nanarchists."',
#  u'"It seems to me a very clever idea," said Syme.',
#  u'"Clever!',
#  u'God blast your impudence!',
#  u'Clever!"',
#  u'cried out the other in\na sudden, shrill voice which was as startling and discordant as his\ncrooked smile.',
#  u'"When you\'ve seen Sunday for a split second you\'ll\nleave off calling him clever."',
#  u'With this they emerged out of a narrow street, and saw the early\nsunlight filling Leicester Square.',
#  u'It will never be known, I\nsuppose, why this square itself should look so alien and in some\nways so continental.',
#  u'It will never be known whether it was the\nforeign look that attracted the foreigners or the foreigners who\ngave it the foreign look.',
#  u'But on this particular morning the effect\nseemed singularly bright and clear.',
#  u'Between the open square and the\nsunlit leaves and the statue and the Saracenic outlines of the\nAlhambra, it looked the replica of some French or even Spanish\npublic place.',
#  u'And this effect increased in Syme the sensation,\nwhich in many shapes he had had through the whole adventure, the\neerie sensation of having strayed into a new world.',
#  u'As a fact, he\nhad bought bad cigars round Leicester Square ever since he was a\nboy.',
#  u'But as he turned that corner, and saw the trees and the\nMoorish cupolas, he could have sworn that he was turning into an\nunknown Place de something or other in some foreign town.',
#  u'At one corner of the square there projected a kind of angle of a\nprosperous but quiet hotel, the bulk of which belonged to a street\nbehind.',
#  u'In the wall there was one large French window, probably\nthe window of a large coffee-room; and outside this window, almost\nliterally overhanging the square, was a formidably buttressed\nbalcony, big enough to contain a dining-table.',
#  u'In fact, it did\ncontain a dining-table, or more strictly a breakfast-table; and\nround the breakfast-table, glowing in the sunlight and evident to\nthe street, were a group of noisy and talkative men, all dressed\nin the insolence of fashion, with white waistcoats and expensive\nbutton-holes.',
#  u'Some of their jokes could almost be heard across the\nsquare.',
#  u'Then the grave Secretary gave his unnatural smile, and Syme\nknew that this boisterous breakfast party was the secret conclave\nof the European Dynamiters.',
#  u'Then, as Syme continued to stare at them, he saw something that he\nhad not seen before.',
#  u'He had not seen it literally because it was\ntoo large to see.',
#  u'At the nearest end of the balcony, blocking up a\ngreat part of the perspective, was the back of a great mountain of\na man.',
#  u'When Syme had seen him, his first thought was that the\nweight of him must break down the balcony of stone.',
#  u'His vastness\ndid not lie only in the fact that he was abnormally tall and quite\nincredibly fat.',
#  u'This man was planned enormously in his original\nproportions, like a statue carved deliberately as colossal.',
#  u'His\nhead, crowned with white hair, as seen from behind looked bigger\nthan a head ought to be.',
#  u'The ears that stood out from it looked\nlarger than human ears.',
#  u'He was enlarged terribly to scale; and this\nsense of size was so staggering, that when Syme saw him all the\nother figures seemed quite suddenly to dwindle and become dwarfish.',
#  u'They were still sitting there as before with their flowers and\nfrock-coats, but now it looked as if the big man was entertaining\nfive children to tea.',
#  u'As Syme and the guide approached the side door of the hotel, a\nwaiter came out smiling with every tooth in his head.',
#  u'"The gentlemen are up there, sare," he said.',
#  u'"They do talk and they\ndo laugh at what they talk.',
#  u'They do say they will throw bombs at ze\nking."',
#  u'And the waiter hurried away with a napkin over his arm, much\npleased with the singular frivolity of the gentlemen upstairs.',
#  u'The two men mounted the stairs in silence.',
#  u'Syme had never thought of asking whether the monstrous man who\nalmost filled and broke the balcony was the great President of whom\nthe others stood in awe.',
#  u'He knew it was so, with an unaccountable\nbut instantaneous certainty.',
#  u'Syme, indeed, was one of those men who\nare open to all the more nameless psychological influences in a\ndegree a little dangerous to mental health.',
#  u'Utterly devoid of fear\nin physical dangers, he was a great deal too sensitive to the smell\nof spiritual evil.',
#  u'Twice already that night little unmeaning things\nhad peeped out at him almost pruriently, and given him a sense of\ndrawing nearer and nearer to the head-quarters of hell.',
#  u'And this\nsense became overpowering as he drew nearer to the great President.',
#  u'The form it took was a childish and yet hateful fancy.',
#  u'As he walked\nacross the inner room towards the balcony, the large face of Sunday\ngrew larger and larger; and Syme was gripped with a fear that when\nhe was quite close the face would be too big to be possible, and\nthat he would scream aloud.',
#  u'He remembered that as a child he would\nnot look at the mask of Memnon in the British Museum, because it\nwas a face, and so large.',
#  u'By an effort, braver than that of leaping over a cliff, he went to\nan empty seat at the breakfast-table and sat down.',
#  u'The men greeted\nhim with good-humoured raillery as if they had always known him.',
#  u'He\nsobered himself a little by looking at their conventional coats and\nsolid, shining coffee-pot; then he looked again at Sunday.',
#  u'His face\nwas very large, but it was still possible to humanity.',
#  u"In the presence of the President the whole company looked\nsufficiently commonplace; nothing about them caught the eye at\nfirst, except that by the President's caprice they had been dressed\nup with a festive respectability, which gave the meal the look of a\nwedding breakfast.",
#  u'One man indeed stood out at even a superficial\nglance.',
#  u'He at least was the common or garden Dynamiter.',
#  u'He wore,\nindeed, the high white collar and satin tie that were the uniform\nof the occasion; but out of this collar there sprang a head quite\nunmanageable and quite unmistakable, a bewildering bush of brown\nhair and beard that almost obscured the eyes like those of a Skye\nterrier.',
#  u'But the eyes did look out of the tangle, and they were the\nsad eyes of some Russian serf.',
#  u'The effect of this figure was not\nterrible like that of the President, but it had every diablerie\nthat can come from the utterly grotesque.',
#  u'If out of that stiff tie\nand collar there had come abruptly the head of a cat or a dog, it\ncould not have been a more idiotic contrast.',
#  u"The man's name, it seemed, was Gogol; he was a Pole, and in this\ncircle of days he was called Tuesday.",
#  u'His soul and speech were\nincurably tragic; he could not force himself to play the\nprosperous and frivolous part demanded of him by President Sunday.',
#  u'And, indeed, when Syme came in the President, with that daring\ndisregard of public suspicion which was his policy, was actually\nchaffing Gogol upon his inability to assume conventional graces.',
#  u'"Our friend Tuesday," said the President in a deep voice at once\nof quietude and volume, "our friend Tuesday doesn\'t seem to grasp\nthe idea.',
#  u'He dresses up like a gentleman, but he seems to be too\ngreat a soul to behave like one.',
#  u'He insists on the ways of the\nstage conspirator.',
#  u'Now if a gentleman goes about London in a top\nhat and a frock-coat, no one need know that he is an anarchist.',
#  u'But if a gentleman puts on a top hat and a frock-coat, and then\ngoes about on his hands and knees--well, he may attract attention.',
#  u"That's what Brother Gogol does.",
#  ...]

# %%
import pprint
pprint.pprint(sents[79:89])
# Out:
# [u'"Nonsense!"',
#  u'said Gregory, who was very rational when anyone else\nattempted paradox.',
#  u'"Why do all the clerks and navvies in the\nrailway trains look so sad and tired, so very sad and tired?',
#  u'I will\ntell you.',
#  u'It is because they know that the train is going right.',
#  u'It\nis because they know that whatever place they have taken a ticket\nfor that place they will reach.',
#  u'It is because after they have\npassed Sloane Square they know that the next station must be\nVictoria, and nothing but Victoria.',
#  u'Oh, their wild rapture!',
#  u'oh,\ntheir eyes like stars and their souls again in Eden, if the next\nstation were unaccountably Baker Street!"',
#  u'"It is you who are unpoetical," replied the poet Syme.']

# %% [markdown]
# ### Lemmatization

# %%
wnl = nltk.WordNetLemmatizer()

# %%
[wnl.lemmatize(t) for t in tokens]
# Out:
# [u'[',
#  u'Emma',
#  u'by',
#  u'Jane',
#  u'Austen',
#  u'1816',
#  u']',
#  u'VOLUME',
#  u'I',
#  u'CHAPTER',
#  u'I',
#  u'Emma',
#  u'Woodhouse',
#  u',',
#  u'handsome',
#  u',',
#  u'clever',
#  u',',
#  u'and',
#  u'rich',
#  u',',
#  u'with',
#  u'a',
#  u'comfortable',
#  u'home',
#  u'and',
#  u'happy',
#  u'disposition',
#  u',',
#  u'seemed',
#  u'to',
#  u'unite',
#  u'some',
#  u'of',
#  u'the',
#  u'best',
#  u'blessing',
#  u'of',
#  u'existence',
#  u';',
#  u'and',
#  u'had',
#  u'lived',
#  u'nearly',
#  u'twenty',
#  u'-',
#  u'one',
#  u'year',
#  u'in',
#  u'the',
#  u'world',
#  u'with',
#  u'very',
#  u'little',
#  u'to',
#  u'distress',
#  u'or',
#  u'vex',
#  u'her',
#  u'.',
#  u'She',
#  u'wa',
#  u'the',
#  u'youngest',
#  u'of',
#  u'the',
#  u'two',
#  u'daughter',
#  u'of',
#  u'a',
#  u'most',
#  u'affectionate',
#  u',',
#  u'indulgent',
#  u'father',
#  u';',
#  u'and',
#  u'had',
#  u',',
#  u'in',
#  u'consequence',
#  u'of',
#  u'her',
#  u'sister',
#  u"'",
#  u's',
#  u'marriage',
#  u',',
#  u'been',
#  u'mistress',
#  u'of',
#  u'his',
#  u'house',
#  u'from',
#  u'a',
#  u'very',
#  u'early',
#  u'period',
#  u'.',
#  u'Her',
#  u'mother',
#  u'had',
#  u'died',
#  u'too',
#  u'long',
#  u'ago',
#  u'for',
#  u'her',
#  u'to',
#  u'have',
#  u'more',
#  u'than',
#  u'an',
#  u'indistinct',
#  u'remembrance',
#  u'of',
#  u'her',
#  u'caress',
#  u';',
#  u'and',
#  u'her',
#  u'place',
#  u'had',
#  u'been',
#  u'supplied',
#  u'by',
#  u'an',
#  u'excellent',
#  u'woman',
#  u'a',
#  u'governess',
#  u',',
#  u'who',
#  u'had',
#  u'fallen',
#  u'little',
#  u'short',
#  u'of',
#  u'a',
#  u'mother',
#  u'in',
#  u'affection',
#  u'.',
#  u'Sixteen',
#  u'year',
#  u'had',
#  u'Miss',
#  u'Taylor',
#  u'been',
#  u'in',
#  u'Mr',
#  u'.',
#  u'Woodhouse',
#  u"'",
#  u's',
#  u'family',
#  u',',
#  u'le',
#  u'a',
#  u'a',
#  u'governess',
#  u'than',
#  u'a',
#  u'friend',
#  u',',
#  u'very',
#  u'fond',
#  u'of',
#  u'both',
#  u'daughter',
#  u',',
#  u'but',
#  u'particularly',
#  u'of',
#  u'Emma',
#  u'.',
#  u'Between',
#  u'_them_',
#  u'it',
#  u'wa',
#  u'more',
#  u'the',
#  u'intimacy',
#  u'of',
#  u'sister',
#  u'.',
#  u'Even',
#  u'before',
#  u'Miss',
#  u'Taylor',
#  u'had',
#  u'ceased',
#  u'to',
#  u'hold',
#  u'the',
#  u'nominal',
#  u'office',
#  u'of',
#  u'governess',
#  u',',
#  u'the',
#  u'mildness',
#  u'of',
#  u'her',
#  u'temper',
#  u'had',
#  u'hardly',
#  u'allowed',
#  u'her',
#  u'to',
#  u'impose',
#  u'any',
#  u'restraint',
#  u';',
#  u'and',
#  u'the',
#  u'shadow',
#  u'of',
#  u'authority',
#  u'being',
#  u'now',
#  u'long',
#  u'passed',
#  u'away',
#  u',',
#  u'they',
#  u'had',
#  u'been',
#  u'living',
#  u'together',
#  u'a',
#  u'friend',
#  u'and',
#  u'friend',
#  u'very',
#  u'mutually',
#  u'attached',
#  u',',
#  u'and',
#  u'Emma',
#  u'doing',
#  u'just',
#  u'what',
#  u'she',
#  u'liked',
#  u';',
#  u'highly',
#  u'esteeming',
#  u'Miss',
#  u'Taylor',
#  u"'",
#  u's',
#  u'judgment',
#  u',',
#  u'but',
#  u'directed',
#  u'chiefly',
#  u'by',
#  u'her',
#  u'own',
#  u'.',
#  u'The',
#  u'real',
#  u'evil',
#  u',',
#  u'indeed',
#  u',',
#  u'of',
#  u'Emma',
#  u"'",
#  u's',
#  u'situation',
#  u'were',
#  u'the',
#  u'power',
#  u'of',
#  u'having',
#  u'rather',
#  u'too',
#  u'much',
#  u'her',
#  u'own',
#  u'way',
#  u',',
#  u'and',
#  u'a',
#  u'disposition',
#  u'to',
#  u'think',
#  u'a',
#  u'little',
#  u'too',
#  u'well',
#  u'of',
#  u'herself',
#  u';',
#  u'these',
#  u'were',
#  u'the',
#  u'disadvantage',
#  u'which',
#  u'threatened',
#  u'alloy',
#  u'to',
#  u'her',
#  u'many',
#  u'enjoyment',
#  u'.',
#  u'The',
#  u'danger',
#  u',',
#  u'however',
#  u',',
#  u'wa',
#  u'at',
#  u'present',
#  u'so',
#  u'unperceived',
#  u',',
#  u'that',
#  u'they',
#  u'did',
#  u'not',
#  u'by',
#  u'any',
#  u'mean',
#  u'rank',
#  u'a',
#  u'misfortune',
#  u'with',
#  u'her',
#  u'.',
#  u'Sorrow',
#  u'came',
#  u'--',
#  u'a',
#  u'gentle',
#  u'sorrow',
#  u'--',
#  u'but',
#  u'not',
#  u'at',
#  u'all',
#  u'in',
#  u'the',
#  u'shape',
#  u'of',
#  u'any',
#  u'disagreeable',
#  u'consciousness',
#  u'.--',
#  u'Miss',
#  u'Taylor',
#  u'married',
#  u'.',
#  u'It',
#  u'wa',
#  u'Miss',
#  u'Taylor',
#  u"'",
#  u's',
#  u'loss',
#  u'which',
#  u'first',
#  u'brought',
#  u'grief',
#  u'.',
#  u'It',
#  u'wa',
#  u'on',
#  u'the',
#  u'wedding',
#  u'-',
#  u'day',
#  u'of',
#  u'this',
#  u'beloved',
#  u'friend',
#  u'that',
#  u'Emma',
#  u'first',
#  u'sat',
#  u'in',
#  u'mournful',
#  u'thought',
#  u'of',
#  u'any',
#  u'continuance',
#  u'.',
#  u'The',
#  u'wedding',
#  u'over',
#  u',',
#  u'and',
#  u'the',
#  u'bride',
#  u'-',
#  u'people',
#  u'gone',
#  u',',
#  u'her',
#  u'father',
#  u'and',
#  u'herself',
#  u'were',
#  u'left',
#  u'to',
#  u'dine',
#  u'together',
#  u',',
#  u'with',
#  u'no',
#  u'prospect',
#  u'of',
#  u'a',
#  u'third',
#  u'to',
#  u'cheer',
#  u'a',
#  u'long',
#  u'evening',
#  u'.',
#  u'Her',
#  u'father',
#  u'composed',
#  u'himself',
#  u'to',
#  u'sleep',
#  u'after',
#  u'dinner',
#  u',',
#  u'a',
#  u'usual',
#  u',',
#  u'and',
#  u'she',
#  u'had',
#  u'then',
#  u'only',
#  u'to',
#  u'sit',
#  u'and',
#  u'think',
#  u'of',
#  u'what',
#  u'she',
#  u'had',
#  u'lost',
#  u'.',
#  u'The',
#  u'event',
#  u'had',
#  u'every',
#  u'promise',
#  u'of',
#  u'happiness',
#  u'for',
#  u'her',
#  u'friend',
#  u'.',
#  u'Mr',
#  u'.',
#  u'Weston',
#  u'wa',
#  u'a',
#  u'man',
#  u'of',
#  u'unexceptionable',
#  u'character',
#  u',',
#  u'easy',
#  u'fortune',
#  u',',
#  u'suitable',
#  u'age',
#  u',',
#  u'and',
#  u'pleasant',
#  u'manner',
#  u';',
#  u'and',
#  u'there',
#  u'wa',
#  u'some',
#  u'satisfaction',
#  u'in',
#  u'considering',
#  u'with',
#  u'what',
#  u'self',
#  u'-',
#  u'denying',
#  u',',
#  u'generous',
#  u'friendship',
#  u'she',
#  u'had',
#  u'always',
#  u'wished',
#  u'and',
#  u'promoted',
#  u'the',
#  u'match',
#  u';',
#  u'but',
#  u'it',
#  u'wa',
#  u'a',
#  u'black',
#  u'morning',
#  u"'",
#  u's',
#  u'work',
#  u'for',
#  u'her',
#  u'.',
#  u'The',
#  u'want',
#  u'of',
#  u'Miss',
#  u'Taylor',
#  u'would',
#  u'be',
#  u'felt',
#  u'every',
#  u'hour',
#  u'of',
#  u'every',
#  u'day',
#  u'.',
#  u'She',
#  u'recalled',
#  u'her',
#  u'past',
#  u'kindness',
#  u'--',
#  u'the',
#  u'kindness',
#  u',',
#  u'the',
#  u'affection',
#  u'of',
#  u'sixteen',
#  u'year',
#  u'--',
#  u'how',
#  u'she',
#  u'had',
#  u'taught',
#  u'and',
#  u'how',
#  u'she',
#  u'had',
#  u'played',
#  u'with',
#  u'her',
#  u'from',
#  u'five',
#  u'year',
#  u'old',
#  u'--',
#  u'how',
#  u'she',
#  u'had',
#  u'devoted',
#  u'all',
#  u'her',
#  u'power',
#  u'to',
#  u'attach',
#  u'and',
#  u'amuse',
#  u'her',
#  u'in',
#  u'health',
#  u'--',
#  u'and',
#  u'how',
#  u'nursed',
#  u'her',
#  u'through',
#  u'the',
#  u'various',
#  u'illness',
#  u'of',
#  u'childhood',
#  u'.',
#  u'A',
#  u'large',
#  u'debt',
#  u'of',
#  u'gratitude',
#  u'wa',
#  u'owing',
#  u'here',
#  u';',
#  u'but',
#  u'the',
#  u'intercourse',
#  u'of',
#  u'the',
#  u'last',
#  u'seven',
#  u'year',
#  u',',
#  u'the',
#  u'equal',
#  u'footing',
#  u'and',
#  u'perfect',
#  u'unreserve',
#  u'which',
#  u'had',
#  u'soon',
#  u'followed',
#  u'Isabella',
#  u"'",
#  u's',
#  u'marriage',
#  u',',
#  u'on',
#  u'their',
#  u'being',
#  u'left',
#  u'to',
#  u'each',
#  u'other',
#  u',',
#  u'wa',
#  u'yet',
#  u'a',
#  u'dearer',
#  u',',
#  u'tenderer',
#  u'recollection',
#  u'.',
#  u'She',
#  u'had',
#  u'been',
#  u'a',
#  u'friend',
#  u'and',
#  u'companion',
#  u'such',
#  u'a',
#  u'few',
#  u'possessed',
#  u':',
#  u'intelligent',
#  u',',
#  u'well',
#  u'-',
#  u'informed',
#  u',',
#  u'useful',
#  u',',
#  u'gentle',
#  u',',
#  u'knowing',
#  u'all',
#  u'the',
#  u'way',
#  u'of',
#  u'the',
#  u'family',
#  u',',
#  u'interested',
#  u'in',
#  u'all',
#  u'it',
#  u'concern',
#  u',',
#  u'and',
#  u'peculiarly',
#  u'interested',
#  u'in',
#  u'herself',
#  u',',
#  u'in',
#  u'every',
#  u'pleasure',
#  u',',
#  u'every',
#  u'scheme',
#  u'of',
#  u'hers',
#  u'--',
#  u'one',
#  u'to',
#  u'whom',
#  u'she',
#  u'could',
#  u'speak',
#  u'every',
#  u'thought',
#  u'a',
#  u'it',
#  u'arose',
#  u',',
#  u'and',
#  u'who',
#  u'had',
#  u'such',
#  u'an',
#  u'affection',
#  u'for',
#  u'her',
#  u'a',
#  u'could',
#  u'never',
#  u'find',
#  u'fault',
#  u'.',
#  u'How',
#  u'wa',
#  u'she',
#  u'to',
#  u'bear',
#  u'the',
#  u'change',
#  u'?--',
#  u'It',
#  u'wa',
#  u'true',
#  u'that',
#  u'her',
#  u'friend',
#  u'wa',
#  u'going',
#  u'only',
#  u'half',
#  u'a',
#  u'mile',
#  u'from',
#  u'them',
#  u';',
#  u'but',
#  u'Emma',
#  u'wa',
#  u'aware',
#  u'that',
#  u'great',
#  u'must',
#  u'be',
#  u'the',
#  u'difference',
#  u'between',
#  u'a',
#  u'Mrs',
#  u'.',
#  u'Weston',
#  u',',
#  u'only',
#  u'half',
#  u'a',
#  u'mile',
#  u'from',
#  u'them',
#  u',',
#  u'and',
#  u'a',
#  u'Miss',
#  u'Taylor',
#  u'in',
#  u'the',
#  u'house',
#  u';',
#  u'and',
#  u'with',
#  u'all',
#  u'her',
#  u'advantage',
#  u',',
#  u'natural',
#  u'and',
#  u'domestic',
#  u',',
#  u'she',
#  u'wa',
#  u'now',
#  u'in',
#  u'great',
#  u'danger',
#  u'of',
#  u'suffering',
#  u'from',
#  u'intellectual',
#  u'solitude',
#  u'.',
#  u'She',
#  u'dearly',
#  u'loved',
#  u'her',
#  u'father',
#  u',',
#  u'but',
#  u'he',
#  u'wa',
#  u'no',
#  u'companion',
#  u'for',
#  u'her',
#  u'.',
#  u'He',
#  u'could',
#  u'not',
#  u'meet',
#  u'her',
#  u'in',
#  u'conversation',
#  u',',
#  u'rational',
#  u'or',
#  u'playful',
#  u'.',
#  u'The',
#  u'evil',
#  u'of',
#  u'the',
#  u'actual',
#  u'disparity',
#  u'in',
#  u'their',
#  u'age',
#  u'(',
#  u'and',
#  u'Mr',
#  u'.',
#  u'Woodhouse',
#  u'had',
#  u'not',
#  u'married',
#  u'early',
#  u')',
#  u'wa',
#  u'much',
#  u'increased',
#  u'by',
#  u'his',
#  u'constitution',
#  u'and',
#  u'habit',
#  u';',
#  u'for',
#  u'having',
#  u'been',
#  u'a',
#  u'valetudinarian',
#  u'all',
#  u'his',
#  u'life',
#  u',',
#  u'without',
#  u'activity',
#  u'of',
#  u'mind',
#  u'or',
#  u'body',
#  u',',
#  u'he',
#  u'wa',
#  u'a',
#  u'much',
#  u'older',
#  u'man',
#  u'in',
#  u'way',
#  u'than',
#  u'in',
#  u'year',
#  u';',
#  u'and',
#  u'though',
#  u'everywhere',
#  u'beloved',
#  u'for',
#  u'the',
#  u'friendliness',
#  u'of',
#  u'his',
#  u'heart',
#  u'and',
#  u'his',
#  u'amiable',
#  u'temper',
#  u',',
#  u'his',
#  u'talent',
#  u'could',
#  u'not',
#  u'have',
#  u'recommended',
#  u'him',
#  u'at',
#  u'any',
#  u'time',
#  u'.',
#  u'Her',
#  u'sister',
#  u',',
#  u'though',
#  u'comparatively',
#  u'but',
#  u'little',
#  u'removed',
#  u'by',
#  u'matrimony',
#  u',',
#  u'being',
#  u'settled',
#  u'in',
#  u'London',
#  u',',
#  u'only',
#  u'sixteen',
#  u'mile',
#  u'off',
#  u',',
#  u'wa',
#  u'much',
#  u'beyond',
#  u'her',
#  u'daily',
#  u'reach',
#  u';',
#  u'and',
#  u'many',
#  u'a',
#  u'long',
#  u'October',
#  u'and',
#  u'November',
#  u'evening',
#  u'must',
#  u'be',
#  u'struggled',
#  u'through',
#  u'at',
#  u'Hartfield',
#  u',',
#  u'before',
#  u'Christmas',
#  u'brought',
#  u'the',
#  u'next',
#  u'visit',
#  u'from',
#  u'Isabella',
#  u'and',
#  u'her',
#  u'husband',
#  u',',
#  u'and',
#  u'their',
#  u'little',
#  u'child',
#  u',',
#  u'to',
#  u'fill',
#  u'the',
#  u'house',
#  u',',
#  u'and',
#  u'give',
#  u'her',
#  u'pleasant',
#  u'society',
#  u'again',
#  u'.',
#  u'Highbury',
#  u',',
#  u'the',
#  u'large',
#  u'and',
#  u'populous',
#  u'village',
#  u',',
#  u'almost',
#  u'amounting',
#  u'to',
#  u'a',
#  u'town',
#  u',',
#  u'to',
#  u'which',
#  u'Hartfield',
#  u',',
#  u'in',
#  u'spite',
#  u'of',
#  u'it',
#  u'separate',
#  u'lawn',
#  u',',
#  u'and',
#  u'shrubbery',
#  u',',
#  u'and',
#  u'name',
#  u',',
#  ...]

# %% [markdown]
# #### Question: What is the difference between tokenization and lemmatization?

# %% [markdown]
# ### Stop word removal

# %%
from nltk.corpus import stopwords

# %%
stop = stopwords.words('english')

# %%
sentence = "this is a foo bar sentence i am not good i you the"

# %%
print [i for i in sentence.split() if i not in stop]
# Out:
# ['foo', 'bar', 'sentence', 'good']

# %% [markdown]
# ### POS Tagging

# %%
from nltk import pos_tag, word_tokenize
text = word_tokenize("And now for something completely different")
nltk.pos_tag(text)
# Out:
# [('And', 'CC'),
#  ('now', 'RB'),
#  ('for', 'IN'),
#  ('something', 'NN'),
#  ('completely', 'RB'),
#  ('different', 'JJ')]

# %% [markdown]
# ### Problem
# #### Construct a sentence with a word that can be both a noun and a verb. Run POS tagging and examine the output.

# %% [markdown]
# ### Problem
# #### Which tags are most common in the brown corpus?
#
# Hint: use nltk.FreqDist
#
# #### Plot the frequency distribution.

# %% [markdown]
# ### Problem
# What are the most commonly used verbs in news corpus?

# %%
wsj = nltk.corpus.treebank.tagged_words(tagset='universal')
word_tag_fd = nltk.FreqDist(wsj)
[wt[0] for (wt, _) in word_tag_fd.most_common() if wt[1] == 'VERB']
# Out:
# [u'is',
#  u'said',
#  u'was',
#  u'are',
#  u'be',
#  u'has',
#  u'have',
#  u'will',
#  u'says',
#  u'would',
#  u'were',
#  u'had',
#  u'been',
#  u'could',
#  u"'s",
#  u'can',
#  u'do',
#  u'say',
#  u'make',
#  u'may',
#  u'did',
#  u'rose',
#  u'made',
#  u'does',
#  u'expected',
#  u'buy',
#  u'take',
#  u'get',
#  u'might',
#  u'sell',
#  u'added',
#  u'sold',
#  u'help',
#  u'including',
#  u'should',
#  u'reported',
#  u'according',
#  u'pay',
#  u'being',
#  u'compared',
#  u'began',
#  u'fell',
#  u'based',
#  u'closed',
#  u'used',
#  u"'re",
#  u'want',
#  u'see',
#  u'took',
#  u'yield',
#  u'priced',
#  u'offered',
#  u'set',
#  u'approved',
#  u'come',
#  u'cut',
#  u'noted',
#  u'ended',
#  u'increased',
#  u'found',
#  u'think',
#  u'become',
#  u'declined',
#  u'go',
#  u'proposed',
#  u'growing',
#  u'trying',
#  u'received',
#  u'named',
#  u'put',
#  u'give',
#  u'came',
#  u'held',
#  u'use',
#  u'paid',
#  u'going',
#  u'called',
#  u'raise',
#  u'estimated',
#  u'continue',
#  u'designed',
#  u'making',
#  u'expects',
#  u'seeking',
#  u'plans',
#  u'wo',
#  u'must',
#  u'got',
#  u'gained',
#  u'trading',
#  u'owns',
#  u'fined',
#  u'saying',
#  u'increasing',
#  u'acquired',
#  u'included',
#  u'filed',
#  u'holding',
#  u'reached',
#  u'announced',
#  u'seek',
#  u'became',
#  u'agreed',
#  u'taken',
#  u'find',
#  u'disclosed',
#  u'decided',
#  u'keep',
#  u'know',
#  u'failed',
#  u'run',
#  u'coming',
#  u'led',
#  u"'ve",
#  u'using',
#  u'traded',
#  u'lost',
#  u'built',
#  u'completed',
#  u'raised',
#  u'result',
#  u'went',
#  u'continued',
#  u'needed',
#  u'include',
#  u'told',
#  u'posted',
#  u'receive',
#  u'need',
#  u'wants',
#  u'paying',
#  u'helped',
#  u'provide',
#  u'scheduled',
#  u'believe',
#  u'indicated',
#  u'goes',
#  u'lead',
#  u'face',
#  u'caused',
#  u'ordered',
#  u'remains',
#  u"'m",
#  u'wanted',
#  u'gives',
#  u'changed',
#  u'following',
#  u'continues',
#  u'showed',
#  u'planned',
#  u'reduce',
#  u'launched',
#  u'continuing',
#  u'dropped',
#  u'includes',
#  u'issued',
#  u'believes',
#  u'like',
#  u'buying',
#  u'rise',
#  u'remain',
#  u'meet',
#  u'followed',
#  u'leading',
#  u'trade',
#  u'ca',
#  u'known',
#  u'improve',
#  u'involved',
#  u'earned',
#  u'operating',
#  u'given',
#  u'offset',
#  u'prevent',
#  u'increase',
#  u'consented',
#  u'win',
#  u'rejected',
#  u'feel',
#  u'makes',
#  u'having',
#  u'turned',
#  u'rising',
#  u'barred',
#  u'read',
#  u'seem',
#  u'asked',
#  u'build',
#  u'hurt',
#  u'sought',
#  u'aimed',
#  u'support',
#  u'begin',
#  u'introduced',
#  u'preferred',
#  u'offering',
#  u'gave',
#  u'acquire',
#  u'taking',
#  u'totaled',
#  u'carry',
#  u'required',
#  u'takes',
#  u'produced',
#  u'offer',
#  u'require',
#  u'cited',
#  u'won',
#  u'bought',
#  u'adds',
#  u'getting',
#  u'alleged',
#  u'own',
#  u'purchasing',
#  u'runs',
#  u'consider',
#  u'looking',
#  u'report',
#  u'fixed',
#  u'allowed',
#  u'advanced',
#  u'opened',
#  u'boosted',
#  u'doing',
#  u'prove',
#  u'remaining',
#  u'wrote',
#  u'giving',
#  u'considered',
#  u'left',
#  u'suspended',
#  u'hit',
#  u'close',
#  u'working',
#  u'fall',
#  u'reduced',
#  u'listed',
#  u'involving',
#  u'look',
#  u'bring',
#  u'prepared',
#  u'approve',
#  u'valued',
#  u'underlying',
#  u'boost',
#  u'losing',
#  u'mixed',
#  u'move',
#  u'extend',
#  u'selling',
#  u'appears',
#  u'described',
#  u'sells',
#  u'opposed',
#  u'seen',
#  u'let',
#  u'work',
#  u'hopes',
#  u'provided',
#  u'manufacturing',
#  u'placed',
#  u'According',
#  u'provides',
#  u'operate',
#  u'produce',
#  u'comment',
#  u'surged',
#  u'allow',
#  u'spent',
#  u'expect',
#  u'slowing',
#  u'seems',
#  u'created',
#  u'mature',
#  u'jumped',
#  u'ending',
#  u'operates',
#  u'leave',
#  u'eliminated',
#  u'violate',
#  u'seemed',
#  u'represent',
#  u'suggests',
#  u'elaborate',
#  u'settle',
#  u'avoid',
#  u'soared',
#  u"'ll",
#  u'stand',
#  u'passed',
#  u'worked',
#  u'stopped',
#  u'improved',
#  u'decline',
#  u'Says',
#  u'beginning',
#  u'force',
#  u'developed',
#  u'introduce',
#  u'shows',
#  u'asking',
#  u'becomes',
#  u'managing',
#  u'ease',
#  u'hold',
#  u'comes',
#  u'contributed',
#  u'create',
#  u'expire',
#  u'indicates',
#  u'end',
#  u'cause',
#  u'quoted',
#  u'kept',
#  u'believed',
#  u'watch',
#  u'thought',
#  u'related',
#  u'refused',
#  u'change',
#  u'raising',
#  u'threatened',
#  u'shall',
#  u'invested',
#  u'print',
#  u'eliminate',
#  u'stop',
#  u'fallen',
#  u'worried',
#  u'plunged',
#  u'appeared',
#  u'claim',
#  u'show',
#  u'fired',
#  u'met',
#  u'running',
#  u'disgorge',
#  u'file',
#  u'combined',
#  u'sent',
#  u'suggested',
#  u'suffer',
#  u'brought',
#  u'referred',
#  u'oppose',
#  u'block',
#  u'pursue',
#  u'replaced',
#  u'complete',
#  u'slow',
#  u'Take',
#  u'covered',
#  u'issue',
#  u'contain',
#  u'attributed',
#  u'managed',
#  u'argue',
#  u'occur',
#  u'succeed',
#  u'ran',
#  u'admitting',
#  u'add',
#  u'turning',
#  u'limited',
#  u'beat',
#  u'elected',
#  u'formed',
#  u'registered',
#  u'send',
#  u'requires',
#  u'shipped',
#  u'discovered',
#  u'forced',
#  u'denying',
#  u'act',
#  u'resulting',
#  u'becoming',
#  u'contained',
#  u'accused',
#  u'turn',
#  u'started',
#  u'attract',
#  u'return',
#  u'owned',
#  u'helping',
#  u'means',
#  u'matched',
#  u'done',
#  u'expanding',
#  u'happen',
#  u'developing',
#  u'playing',
#  u'finished',
#  u'focused',
#  u'thinking',
#  u'suggest',
#  u'raises',
#  u'climbed',
#  u'expressed',
#  u'confirmed',
#  u'ranged',
#  u'cutting',
#  u'attempting',
#  u'pending',
#  u"'d",
#  u'leaving',
#  u'building',
#  u'facing',
#  u'resigned',
#  u'decide',
#  u'creating',
#  u'carried',
#  u'retired',
#  u'causing',
#  u'signed',
#  u'start',
#  u'keeping',
#  u'charge',
#  u'regarding',
#  u'asks',
#  u'falling',
#  u'stay',
#  u'settled',
#  u'tried',
#  u'reporting',
#  u'voted',
#  u'discuss',
#  u'awarded',
#  u'delivered',
#  u'starting',
#  u'adjusted',
#  u'veto',
#  u'owed',
#  u'replace',
#  u'returned',
#  u'saw',
#  u'calls',
#  u'remained',
#  u'realize',
#  u'studied',
#  u'urged',
#  u'accepted',
#  u'stood',
#  u'financing',
#  u'identified',
#  u'written',
#  u'maintained',
#  u'providing',
#  u'expanded',
#  u'prompted',
#  u'moved',
#  u'follows',
#  u'offers',
#  u'expand',
#  u'bid',
#  u'adopted',
#  u'insist',
#  u'exercise',
#  u'felt',
#  u'lying',
#  u'concluded',
#  u'cover',
#  u'anticipated',
#  u'assuming',
#  u'declared',
#  u'finance',
#  u'talk',
#  u'reflect',
#  u'risk',
#  u'withdrawn',
#  u'citing',
#  u'realized',
#  u'capture',
#  u'showing',
#  u'begins',
#  u'publishing',
#  u'die',
#  u'fail',
#  u'limit',
#  u'protecting',
#  u'located',
#  u'proposing',
#  u'purchased',
#  u'profit',
#  u'spend',
#  u'learned',
#  u'worry',
#  u'marketed',
#  u'dismissed',
#  u'wait',
#  u'tied',
#  u'viewed',
#  u'care',
#  u'released',
#  u'chosen',
#  u'play',
#  u'choose',
#  u'joined',
#  u'hope',
#  u'lift',
#  u'total',
#  u'ring',
#  u'argued',
#  u'predicting',
#  u'financed',
#  u'reducing',
#  u'account',
#  u'maintaining',
#  u'exceed',
#  u'seeks',
#  u'tells',
#  u'pleased',
#  u'heard',
#  u'discussed',
#  u'considering',
#  u'treat',
#  u'reflected',
#  u'negotiate',
#  u'lowered',
#  u'declining',
#  u'sparked',
#  u'focus',
#  u'serve',
#  u'imported',
#  u'entered',
#  u'ruled',
#  u'admits',
#  u'drop',
#  u'representing',
#  u'grew',
#  u'gaining',
#  u'knows',
#  u'enters',
#  u'preventing',
#  u'live',
#  u'uses',
#  u'push',
#  u'determined',
#  u'complained',
#  u'holds',
#  u'grown',
#  u'failing',
#  u'denied',
#  u'broken',
#  u'qualified',
#  u'spread',
#  u'reflecting',
#  u'producing',
#  u'gets',
#  u'blamed',
#  u'slipped',
#  u'fueled',
#  u'encourage',
#  u'renewed',
#  u'appear',
#  u'ask',
#  u'grows',
#  u'pass',
#  u'apply',
#  u'intended',
#  u'cost',
#  u'signal',
#  u'gain',
#  u'determine',
#  u'opening',
#  u'insists',
#  u'associated',
#  u'mean',
#  u'assume',
#  u'needs',
#  u'carries',
#  u'divided',
#  u'join',
#  u'hired',
#  u'reflects',
#  u'explains',
#  u'costs',
#  u'dumped',
#  u'execute',
#  u'gotten',
#  u'caught',
#  u'heads',
#  u'receiving',
#  u'triggered',
#  u'applied',
#  u'warned',
#  u'walk',
#  u'Do',
#  u'responded',
#  u'review',
#  u'try',
#  u'speculated',
#  u'claims',
#  u'talking',
#  u'represents',
#  u'existing',
#  u'hear',
#  u'study',
#  u'obtain',
#  u'break',
#  u'mention',
#  u'targeting',
#  u'pushed',
#  u'permitted',
#  u'attend',
#  u'regarded',
#  u'dominated',
#  u'looming',
#  u'removed',
#  u'publishes',
#  u'regulated',
#  u'resolve',
#  u'shut',
#  u'Put',
#  u'protect',
#  u'withdraw',
#  u'weaken',
#  u'check',
#  u'amounted',
#  u'develop',
#  u'accommodate',
#  u'tumbled',
#  u'telling',
#  u'vote',
#  u'share',
#  u'investigating',
#  u'stands',
#  u'compete',
#  u'collected',
#  u'contends',
#  u'restructured',
#  u'accepting',
#  u'reach',
#  u'stepping',
#  u'auctioned',
#  u'subordinated',
#  u'presented',
#  u'secured',
#  u'forecast',
#  u'killed',
#  u'eliminates',
#  u'agree',
#  u'Buy',
#  u'copy',
#  u'remove',
#  u'clear',
#  u'executing',
#  u'hire',
#  u'stepped',
#  u'split',
#  u'promote',
#  u'abandoned',
#  u'occurred',
#  u'advertising',
#  u'prohibits',
#  u'curb',
#  u'turns',
#  u'changing',
#  u'spurred',
#  u'eased',
#  u'describes',
#  u'rumored',
#  u'warning',
#  u'cites',
#  u'specified',
#  u'indicate',
#  u'refund',
#  u'funded',
#  u'stem',
#  u'controlling',
#  u'extended',
#  u'supported',
#  u'conclude',
#  u'considers',
#  u'boosts',
#  u'call',
#  u'snapped',
#  u'banned',
#  u'feeling',
#  u'declaring',
#  u'predicted',
#  u'requested',
#  u'impose',
#  u'benefited',
#  u'point',
#  u'backed',
#  u'employed',
#  u'treating',
#  u'contacted',
#  u'accept',
#  u'plan',
#  u'charged',
#  u'damaged',
#  u'doubled',
#  u'offsetting',
#  u'increases',
#  u'consist',
#  u'leaves',
#  u'ought',
#  u'represented',
#  u'draw',
#  u'pointed',
#  u'employs',
#  u'drawn',
#  u'teach',
#  u'recognize',
#  u'surrendered',
#  u'deliver',
#  u'convicted',
#  u'deserve',
#  u'exercised',
#  u'improving',
#  u'covers',
#  u'retain',
#  u'edged',
#  u'notes',
#  u'executed',
#  u'yielding',
#  u'gone',
#  u'respond',
#  u'follow',
#  u'honor',
#  u'disappointed',
#  u'struggling',
#  u'expecting',
#  u'seeing',
#  u'Buying',
#  u'feared',
#  u'varying',
#  u'coupled',
#  u'marketing',
#  u'attached',
#  u'unveiled',
#  u'explained',
#  u'advertise',
#  u'breaks',
#  u'pursued',
#  u'earns',
#  u'joining',
#  u'belong',
#  u'perform',
#  u'discussing',
#  u'expelled',
#  u'booming',
#  u'restore',
#  u'died',
#  u'scrutinizing',
#  u'adding',
#  u'record',
#  u'reopen',
#  u'closing',
#  u'incurred',
#  u'printed',
#  u'committed',
#  u'insisted',
#  u'taught',
#  u'figure',
#  u'serving',
#  u'involve',
#  u'redeemed',
#  u'note',
#  u'meant',
#  u'permit',
#  u'knew',
#  u'imposed',
#  u'writing',
#  u'upheld',
#  u'revive',
#  u'trailed',
#  u'tend',
#  u'sign',
#  u'proving',
#  u'direct',
#  u'suspect',
#  u'performed',
#  u'cast',
#  u'integrated',
#  u'understand',
#  u'respected',
#  u'moving',
#  u'suspend',
#  u'revived',
#  u'grant',
#  u'stemming',
#  u'tested',
#  u'thinks',
#  u'compares',
#  u'tendered',
#  u'driving',
#  u'surviving',
#  u'played',
#  u'obtained',
#  u'jump',
#  u'fared',
#  u'ignoring',
#  u'denies',
#  u'specify',
#  u'hampered',
#  u'deny',
#  u'retained',
#  u'sink',
#  u'conduct',
#  u'drifted',
#  u'succeeded',
#  u'diluted',
#  u'strike',
#  u'transformed',
#  u'seize',
#  u'rule',
#  u'reaching',
#  u'Adds',
#  u'squeezed',
#  u'treated',
#  u'affect',
#  u'discontinued',
#  u'installed',
#  u'install',
#  u'match',
#  u'sleep',
#  u'prevents',
#  u'moderated',
#  u'stressed',
#  u'begun',
#  u'compiled',
#  u'relies',
#  u'criticized',
#  u'leveling',
#  u'claiming',
#  u'measured',
#  u'banning',
#  u'suing',
#  u'selected',
#  u'sending',
#  u'appeal',
#  u'casting',
#  u'absorbed',
#  u'plays',
#  u'balked',
#  u'belongs',
#  u'export',
#  u'lowering',
#  u'sustained',
#  u'killing',
#  u'lending',
#  u'ringing',
#  u'welcome',
#  u'link',
#  u'merge',
#  u'obligated',
#  u'contradict',
#  u'competes',
#  u'lent',
#  u'lives',
#  u'lack',
#  u'surrounding',
#  u'achieve',
#  u'vowed',
#  u'pointing',
#  u'spark',
#  u'condemned',
#  u'approach',
#  u'interviewed',
#  u'participate',
#  u'open',
#  u'occurs',
#  u'pick',
#  u'concentrated',
#  u'rushed',
#  u'diversify',
#  u'involves',
#  u'tracks',
#  u'solved',
#  u'throws',
#  u'promoting',
#  u'entitles',
#  u'place',
#  u'post',
#  u'laughing',
#  u'drove',
#  u'swap',
#  u'intend',
#  u'spur',
#  u'founded',
#  u'tune',
#  u'stored',
#  u'welcomed',
#  u'chooses',
#  u'diminished',
#  u'pegged',
#  u'violated',
#  u'doubted',
#  u'belonging',
#  u'brings',
#  u'advertised',
#  u'cope',
#  u'qualify',
#  u'signing',
#  u'connected',
#  u'regulating',
#  u'save',
#  u'limiting',
#  u'fails',
#  u'test',
#  u'engaged',
#  u'flows',
#  u'anticipates',
#  u'step',
#  u'Assuming',
#  u'risen',
#  u'blip',
#  u'weighed',
#  u'attempt',
#  u'pushing',
#  u'resulted',
#  u'fighting',
#  u'scrambling',
#  u'naming',
#  u'counts',
#  u'speaks',
#  u'pose',
#  u'concerned',
#  u'acquiring',
#  u'plunging',
#  u'concentrate',
#  u'joins',
#  u'controlled',
#  u'cautioned',
#  u'preserving',
#  u'exposed',
#  u'train',
#  u'feels',
#  u'agrees',
#  u'target',
#  u'contracted',
#  u'kill',
#  u'commit',
#  u'fill',
#  u'calculate',
#  u'fed',
#  u'beaten',
#  u'contributing',
#  u'chastised',
#  u'modify',
#  u'sounded',
#  u'served',
#  u'gauge',
#  u'implement',
#  u'focusing',
#  u'easing',
#  u'chaired',
#  u'upset',
#  u'refuse',
#  u'ward',
#  u'defended',
#  u'drive',
#  u'transferring',
#  u'question',
#  u'competing',
#  u'oriented',
#  u'range',
#  u'confined',
#  u'perceived',
#  u'targets',
#  u'attracted',
#  u'maintain',
#  u'hitting',
#  u'operated',
#  u'tripled',
#  u'withstand',
#  u'provoke',
#  u'identify',
#  u'advised',
#  u'advancing',
#  u'write',
#  u'responding',
#  u'enables',
#  u'sweetened',
#  u'allocated',
#  u'indicating',
#  u'halted',
#  u'regard',
#  u'exchange',
#  u'letting',
#  u'assured',
#  u'loaded',
#  u'romanticized',
#  u'estimates',
#  u'putting',
#  u'feed',
#  u'spends',
#  u'adjusting',
#  u'shrinks',
#  u'terminated',
#  u'banking',
#  u'talks',
#  u'puts',
#  u'declines',
#  u'promises',
#  u'resist',
#  u'forgiven',
#  ...]

# %%
cfd1 = nltk.ConditionalFreqDist(wsj)

# %%
cfd1['address'].most_common()
# Out:
# [(u'VERB', 2), (u'NOUN', 1)]

# %%
cfd1['sold'].most_common()
# Out:
# [(u'VERB', 39)]

# %%
cfd1['report'].most_common()
# Out:
# [(u'NOUN', 31), (u'VERB', 9)]

# %%
wsj = nltk.corpus.treebank.tagged_words()

# %%
cfd2 = nltk.ConditionalFreqDist((tag, word) for (word, tag) in wsj)

# %%
list(cfd2['DT'])
# Out:
# [u'all',
#  u'No',
#  u'Each',
#  u'some',
#  u'an',
#  u'another',
#  u'Neither',
#  u'any',
#  u'le',
#  u'no',
#  u'These',
#  u'Every',
#  u'del',
#  u'neither',
#  u'Those',
#  u'A',
#  u'Both',
#  u'that',
#  u'This',
#  u'AN',
#  u'every',
#  u'half',
#  u'The',
#  u'those',
#  u'a',
#  u'both',
#  u'All',
#  u'this',
#  u'la',
#  u'That',
#  u'Some',
#  u'An',
#  u'these',
#  u'THE',
#  u'either',
#  u'Another',
#  u'each',
#  u'the',
#  u'Any']

# %%
list(cfd2['VBN'])
# Out:
# [u'limited',
#  u'reorganized',
#  u'managed',
#  u'switched',
#  u'caused',
#  u'founded',
#  u'assembled',
#  u'concerned',
#  u'contained',
#  u'Rekindled',
#  u'automated',
#  u'bribed',
#  u'voted',
#  u'issued',
#  u'cluttered',
#  u'disapproved',
#  u'sent',
#  u'returned',
#  u'synchronized',
#  u'puzzled',
#  u'desired',
#  u'engineered',
#  u'headlined',
#  u'centralized',
#  u'advised',
#  u'stabbed',
#  u'continued',
#  u'perceived',
#  u'presented',
#  u'prolonged',
#  u'Related',
#  u'solved',
#  u'noted',
#  u'concluded',
#  u'Filmed',
#  u'infringed',
#  u'construed',
#  u'licensed',
#  u'knitted',
#  u'slowed',
#  u'enclosed',
#  u'replicated',
#  u'estimated',
#  u'imported',
#  u'risen',
#  u'assisted',
#  u'beaten',
#  u'contributed',
#  u'expressed',
#  u'enjoyed',
#  u'industrialized',
#  u'zoomed',
#  u'crossed',
#  u'learned',
#  u'filled',
#  u'told',
#  u'drafted',
#  u'deemed',
#  u'kicked',
#  u'led',
#  u'ranged',
#  u'slated',
#  u'reported',
#  u'focused',
#  u'auctioned',
#  u'crippled',
#  u'represented',
#  u'scrapped',
#  u'invented',
#  u'obtained',
#  u'colored',
#  u'skyrocketed',
#  u'involved',
#  u'changed',
#  u'funded',
#  u'expedited',
#  u'Founded',
#  u'diagnosed',
#  u'stressed',
#  u'postponed',
#  u'settled',
#  u'composed',
#  u'rigged',
#  u'named',
#  u'retired',
#  u'reclaimed',
#  u'distributed',
#  u'offset',
#  u'brought',
#  u'backed',
#  u'aimed',
#  u'trained',
#  u'armed',
#  u'strapped',
#  u'fed',
#  u'handled',
#  u'answered',
#  u'coupled',
#  u'planted',
#  u'upheld',
#  u'opposed',
#  u'taken',
#  u'cited',
#  u'surveyed',
#  u'mired',
#  u'started',
#  u'clobbered',
#  u'corrected',
#  u'hurt',
#  u'tested',
#  u'known',
#  u'mounted',
#  u'Confronted',
#  u'appointed',
#  u'respected',
#  u'valued',
#  u'locked',
#  u'pushed',
#  u'plunged',
#  u'labeled',
#  u'UPHELD',
#  u'romanticized',
#  u'believed',
#  u'specialized',
#  u'performed',
#  u'meant',
#  u'indicated',
#  u'stated',
#  u'approved',
#  u'organized',
#  u'confused',
#  u'heard',
#  u'ensnarled',
#  u'dropped',
#  u'purchased',
#  u'allowed',
#  u'sought',
#  u'bolstered',
#  u'influenced',
#  u'rationed',
#  u'floated',
#  u'conducted',
#  u'dismissed',
#  u'hampered',
#  u'located',
#  u'restructured',
#  u'tried',
#  u'battered',
#  u'Funded',
#  u'derived',
#  u'confirmed',
#  u'tied',
#  u'outlawed',
#  u'halted',
#  u'fueled',
#  u'designed',
#  u'outdistanced',
#  u'chilled',
#  u'reaped',
#  u'crowded',
#  u'discontinued',
#  u'accelerated',
#  u'divided',
#  u'twinned',
#  u'executed',
#  u'finalized',
#  u'welcomed',
#  u'developed',
#  u'pointed',
#  u'installed',
#  u'produced',
#  u'held',
#  u'Absorbed',
#  u'ratified',
#  u'committed',
#  u'argued',
#  u'blocked',
#  u'revived',
#  u'hunted',
#  u'rescheduled',
#  u'chosen',
#  u'fined',
#  u'Stung',
#  u'torn',
#  u'heated',
#  u'disclosed',
#  u'covered',
#  u'hidden',
#  u'troubled',
#  u'Continued',
#  u'overcome',
#  u'stepped',
#  u'repriced',
#  u'sweetened',
#  u'anticipated',
#  u'Annualized',
#  u'qualified',
#  u'impaired',
#  u'documented',
#  u'killed',
#  u'subordinated',
#  u'matched',
#  u'mollified',
#  u'overused',
#  u'notified',
#  u'warned',
#  u'classified',
#  u'arrested',
#  u'identified',
#  u'trimmed',
#  u'deteriorated',
#  u'found',
#  u'repaired',
#  u'characterized',
#  u'referred',
#  u'lifted',
#  u'exacerbated',
#  u'fired',
#  u'populated',
#  u'cultivated',
#  u'positioned',
#  u'related',
#  u'extended',
#  u'begun',
#  u'inflated',
#  u'intended',
#  u'shown',
#  u'opened',
#  u'attracted',
#  u'laid',
#  u'dominated',
#  u'got',
#  u'integrated',
#  u'announced',
#  u'shut',
#  u'disputed',
#  u'assured',
#  u'impressed',
#  u'favored',
#  u'parched',
#  u'sparked',
#  u'threatened',
#  u'cut',
#  u'Used',
#  u'complicated',
#  u'put',
#  u'wanted',
#  u'retained',
#  u'created',
#  u'Developed',
#  u'diminished',
#  u'shipped',
#  u'competed',
#  u'incorporated',
#  u'entrusted',
#  u'fallen',
#  u'exhibited',
#  u'chopped',
#  u'secured',
#  u'Rated',
#  u'rooted',
#  u'swapped',
#  u'omitted',
#  u'reflected',
#  u'owned',
#  u'talked',
#  u'done',
#  u'suspended',
#  u'reached',
#  u'noticed',
#  u'loaded',
#  u'buoyed',
#  u'given',
#  u'rated',
#  u'renovated',
#  u'needed',
#  u'caught',
#  u'structured',
#  u'plagued',
#  u'adopted',
#  u'clarified',
#  u'listed',
#  u'passed',
#  u'averted',
#  u'consented',
#  u'completed',
#  u'diversified',
#  u'expunged',
#  u'interviewed',
#  u'rejected',
#  u'released',
#  u'rectified',
#  u'wasted',
#  u'practiced',
#  u'eliminated',
#  u'convinced',
#  u'polarized',
#  u'decided',
#  u'depressed',
#  u'gotten',
#  u'protected',
#  u'orchestrated',
#  u'treated',
#  u'Regarded',
#  u'turned',
#  u'delisted',
#  u'customized',
#  u'depleted',
#  u'cleaned',
#  u'seen',
#  u'relaunched',
#  u'linked',
#  u'viewed',
#  u'forced',
#  u'implemented',
#  u'built',
#  u'pursued',
#  u'empowered',
#  u'instructed',
#  u'oriented',
#  u'absorbed',
#  u'attempted',
#  u'provoked',
#  u'collapsed',
#  u'embroiled',
#  u'added',
#  u'altered',
#  u'paid',
#  u'serviced',
#  u'rarefied',
#  u'hired',
#  u'connected',
#  u'printed',
#  u'assessed',
#  u'alarmed',
#  u'measured',
#  u'Asked',
#  u'soared',
#  u'singled',
#  u'insured',
#  u'considered',
#  u'calculated',
#  u'upset',
#  u'cushioned',
#  u'looked',
#  u'barred',
#  u'accounted',
#  u'left',
#  u'responded',
#  u'marketed',
#  u'overpriced',
#  u'contacted',
#  u'agreed',
#  u'supported',
#  u'scattered',
#  u'flirted',
#  u'nominated',
#  u'discovered',
#  u'rusted',
#  u'superimposed',
#  u'forecast',
#  u'pleased',
#  u'based',
#  u'quoted',
#  u'earned',
#  u'surged',
#  u'inserted',
#  u'staid',
#  u'failed',
#  u'won',
#  u'judged',
#  u'equipped',
#  u'employed',
#  u'pegged',
#  u'Left',
#  u'nullified',
#  u'merged',
#  u'borrowed',
#  u'hit',
#  u'harmed',
#  u'compiled',
#  u'banned',
#  u'designated',
#  u'preferred',
#  u'Put',
#  u'gored',
#  u'hailed',
#  u'shared',
#  u'classed',
#  u'interrogated',
#  u'justified',
#  u'ended',
#  u'tanked',
#  u'worried',
#  u'rung',
#  u'fixed',
#  u'rumored',
#  u'declared',
#  u'set',
#  u'achieved',
#  u'acquired',
#  u'instituted',
#  u'observed',
#  u'elected',
#  u'accused',
#  u'enhanced',
#  u'operated',
#  u'feared',
#  u'said',
#  u'mentioned',
#  u'harvested',
#  u'muted',
#  u'jumped',
#  u'diluted',
#  u'clamped',
#  u'rolled',
#  u'written',
#  u'determined',
#  u'closed',
#  u'surfaced',
#  u'drawn',
#  u'burned',
#  u'bought',
#  u'targeted',
#  u'sold',
#  u'negotiated',
#  u'tripled',
#  u'come',
#  u'faced',
#  u'received',
#  u'improved',
#  u'met',
#  u'clashed',
#  u'attributed',
#  u'milked',
#  u'coated',
#  u'planned',
#  u'publicized',
#  u'traded',
#  u'asked',
#  u'compressed',
#  u'climbed',
#  u'adjusted',
#  u'headed',
#  u'had',
#  u'maintained',
#  u'regulated',
#  u'ordered',
#  u'allocated',
#  u'withdrawn',
#  u'described',
#  u'condemned',
#  u'escalated',
#  u'been',
#  u'convicted',
#  u'defined',
#  u'combined',
#  u'expected',
#  u'entered',
#  u'chastised',
#  u'educated',
#  u'controlled',
#  u'reallocated',
#  u'painted',
#  u'offered',
#  u'formed',
#  u'priced',
#  u'finished',
#  u'tightened',
#  u'predicated',
#  u'terminated',
#  u'worked',
#  u'applied',
#  u'stacked',
#  u'abandoned',
#  u'frozen',
#  u'expanded',
#  u'expelled',
#  u'cast',
#  u'replaced',
#  u'pressed',
#  u'squeezed',
#  u'launched',
#  u'owed',
#  u'selected',
#  u'studied',
#  u'played',
#  u'dumped',
#  u'engaged',
#  u'helped',
#  u'examined',
#  u'commanded',
#  u'spooked',
#  u'amended',
#  u'grown',
#  u'overstated',
#  u'damaged',
#  u'subpoenaed',
#  u'granted',
#  u'stimulated',
#  u'split',
#  u'proved',
#  u'Posted',
#  u'used',
#  u'edged',
#  u'flooded',
#  u'boosted',
#  u'forgotten',
#  u'muffled',
#  u'nurtured',
#  u'blamed',
#  u'vowed',
#  u'midsized',
#  u'complained',
#  u'Named',
#  u'appropriated',
#  u'kept',
#  u'mortgaged',
#  u'spent',
#  u'echoed',
#  u'magnified',
#  u'thought',
#  u'relied',
#  u'Reached',
#  u'charged',
#  u'spurred',
#  u'proposed',
#  u'polled',
#  u'Given',
#  u'assigned',
#  u'recycled',
#  u'reimbursed',
#  u'advertised',
#  u'followed',
#  u'portrayed',
#  u'afflicted',
#  u'renewed',
#  u'regarded',
#  u'deprived',
#  u'guaranteed',
#  u'spread',
#  u'transformed',
#  u'born',
#  u'enacted',
#  u'excited',
#  u'surprised',
#  u'scheduled',
#  u'chaired',
#  u'increased',
#  u'read',
#  u'confined',
#  u'entrenched',
#  u'accepted',
#  u'disappointed',
#  u'advanced',
#  u'imposed',
#  u'heightened',
#  u'lost',
#  u'tendered',
#  u'discarded',
#  u'served',
#  u'endorsed',
#  u'reduced',
#  u'cooled',
#  u'exposed',
#  u'scared',
#  u'financed',
#  u'Guaranteed',
#  u'understood',
#  u'experienced',
#  u'outpaced',
#  u'provided',
#  u'tracked',
#  u'recorded',
#  u'moderated',
#  u'prosecuted',
#  u'denied',
#  u'forgiven',
#  u'stopped',
#  u'beleaguered',
#  u'run',
#  u'manufactured',
#  u'refused',
#  u'broken',
#  u'murdered',
#  u'prohibited',
#  u'become',
#  u'snapped',
#  u'exercised',
#  u'permitted',
#  u'shaken',
#  u'codified',
#  u'gained',
#  u'subdued',
#  u'carried',
#  u'obligated',
#  u'OFFERED',
#  u'discussed',
#  u'stoked',
#  u'mixed',
#  u'introduced',
#  u'wedded',
#  u'Provided',
#  u'raised',
#  u'own',
#  u'Concerned',
#  u'capped',
#  u'repaid',
#  u'speculated',
#  u'accumulated',
#  u'frightened',
#  u'prompted',
#  u'existed',
#  u'despised',
#  u'minted',
#  u'assumed',
#  u'relegated',
#  u'alleged',
#  u'liquidated',
#  u'awarded',
#  u'preapproved',
#  u'incurred',
#  u'resulted',
#  u'recruited',
#  u'touted',
#  u'revised',
#  u'triggered',
#  u'vested',
#  u'unsettled',
#  u'registered',
#  u'delayed',
#  u'collected',
#  u'lowered',
#  u'mailed',
#  u'recouped',
#  u'filed',
#  u'sustained',
#  u'removed',
#  u'posted',
#  u'directed',
#  u'made',
#  u'redeemed',
#  u'spun',
#  u'attached',
#  u'capitalized',
#  u'signed',
#  u'placed',
#  u'converted',
#  u'faded',
#  u'Estimated',
#  u'called',
#  u'detailed',
#  u'gone',
#  u'associated',
#  u'exhausted',
#  u'stripped',
#  u'specified',
#  u'moved',
#  u'fattened',
#  u'proven',
#  u'dashed',
#  u'promised',
#  u'fashioned',
#  u'watched',
#  u'compared',
#  u'initiated',
#  u'dressed',
#  u'overdone',
#  u'scrambled',
#  u'topped',
#  u'robbed',
#  u'interested',
#  u'fizzled',
#  u'requested',
#  u'obsessed',
#  u'delivered',
#  u'refunded',
#  u'felt',
#  u'prepared',
#  u'generated',
#  u'invested',
#  u'lent',
#  u'included',
#  u'decorated',
#  u'curbed',
#  u'died',
#  u'missed',
#  u'alienated',
#  u'accrued',
#  u'tailored',
#  u'required',
#  u'remarked']

# %% [markdown]
# ### Unigram Tagger

# %% [markdown]
# Tag each word separately.
# For each token, assign the tag that is most likely for that particular token.

# %%
from nltk.corpus import brown
brown_tagged_sents = brown.tagged_sents(categories='news')
brown_sents = brown.sents(categories='news')
unigram_tagger = nltk.UnigramTagger(brown_tagged_sents)
unigram_tagger.tag(brown_sents[2007])
# Out:
# [(u'Various', u'JJ'),
#  (u'of', u'IN'),
#  (u'the', u'AT'),
#  (u'apartments', u'NNS'),
#  (u'are', u'BER'),
#  (u'of', u'IN'),
#  (u'the', u'AT'),
#  (u'terrace', u'NN'),
#  (u'type', u'NN'),
#  (u',', u','),
#  (u'being', u'BEG'),
#  (u'on', u'IN'),
#  (u'the', u'AT'),
#  (u'ground', u'NN'),
#  (u'floor', u'NN'),
#  (u'so', u'QL'),
#  (u'that', u'CS'),
#  (u'entrance', u'NN'),
#  (u'is', u'BEZ'),
#  (u'direct', u'JJ'),
#  (u'.', u'.')]

# %%
unigram_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.9349006503968017

# %%
size = int(len(brown_tagged_sents) * 0.9)

# %%
size
# Out:
# 4160

# %%
train_sents = brown_tagged_sents[:size]
test_sents = brown_tagged_sents[size:]
unigram_tagger = nltk.UnigramTagger(train_sents)
unigram_tagger.evaluate(test_sents)
# Out:
# 0.8120203329014253

# %% [markdown]
# ### N-gram tagger

# %%
bigram_tagger = nltk.BigramTagger(train_sents)
bigram_tagger.tag(brown_sents[2007])
unseen_sent = brown_sents[4203]
bigram_tagger.tag(unseen_sent)
# Out:
# [(u'The', u'AT'),
#  (u'population', u'NN'),
#  (u'of', u'IN'),
#  (u'the', u'AT'),
#  (u'Congo', u'NP'),
#  (u'is', u'BEZ'),
#  (u'13.5', None),
#  (u'million', None),
#  (u',', None),
#  (u'divided', None),
#  (u'into', None),
#  (u'at', None),
#  (u'least', None),
#  (u'seven', None),
#  (u'major', None),
#  (u'``', None),
#  (u'culture', None),
#  (u'clusters', None),
#  (u"''", None),
#  (u'and', None),
#  (u'innumerable', None),
#  (u'tribes', None),
#  (u'speaking', None),
#  (u'400', None),
#  (u'separate', None),
#  (u'dialects', None),
#  (u'.', None)]

# %%
bigram_tagger.evaluate(test_sents)
# Out:
# 0.10276088906608193

# %% [markdown]
# # Module 4: Learning to Classify Text

# %% [markdown]
# ## Problem: Document Classification

# %%
from nltk.corpus import movie_reviews

# %%
documents = [(list(movie_reviews.words(fileid)), category)
    for category in movie_reviews.categories()
    for fileid in movie_reviews.fileids(category)]

# %%
import random
random.shuffle(documents)

# %%
all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words())
word_features = list(all_words)[:2000]
def document_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains({})'.format(word)] = (word in document_words)
    return features

# %%
print(document_features(movie_reviews.words('pos/cv957_8737.txt')))
# Out:
# {'contains(corporate)': False, 'contains(barred)': False, 'contains(batmans)': False, 'contains(menacing)': False, 'contains(rags)': False, 'contains(inquires)': False, 'contains(nosebleeding)': False, 'contains(playhouse)': False, 'contains(peculiarities)': False, 'contains(kilgore)': False, 'contains(tarnish)': False, 'contains(sand)': False, 'contains(busting)': False, 'contains(wedge)': False, 'contains(smelling)': False, 'contains(tulip)': False, 'contains(singled)': False, 'contains(wahlberg)': False, 'contains(needed)': False, 'contains(lydia)': False, 'contains(rick)': False, 'contains(cambodia)': False, 'contains(outfielders)': False, 'contains(jovivich)': False, 'contains(pinon)': False, 'contains(fix)': False, 'contains(marla)': False, 'contains(resources)': False, 'contains(nomi)': False, 'contains(irs)': False, 'contains(mason)': False, 'contains(vicariously)': False, 'contains(ingrained)': False, 'contains(skepticism)': False, 'contains(tested)': False, 'contains(spat)': False, 'contains(nfeatured)': False, 'contains(accomplishes)': False, 'contains(sierra)': False, 'contains(lunges)': False, 'contains(telefixated)': False, 'contains(wednesday)': False, 'contains(spiders)': False, 'contains(waft)': False, 'contains(jim)': False, 'contains(cinematic)': False, 'contains(pseudonymous)': False, 'contains(troubles)': False, 'contains(dimension)': False, 'contains(cassette)': False, 'contains(corsucant)': False, 'contains(absolute)': False, 'contains(harmonious)': False, 'contains(saying)': False, 'contains(misdemeanors)': False, 'contains(prodigious)': False, 'contains(reclining)': False, 'contains(loudness)': False, 'contains(lombard)': False, 'contains(sickening)': False, 'contains(cooking)': False, 'contains(oprah)': False, 'contains(platt)': False, 'contains(rolf)': False, 'contains(episodes)': False, 'contains(derivative)': False, 'contains(receipt)': False, 'contains(impactful)': False, 'contains(fonzie)': False, 'contains(chyron)': False, 'contains(dragonflies)': False, 'contains(ugliness)': False, 'contains(sauce)': False, 'contains(crossroads)': False, 'contains(paired)': False, 'contains(tomei)': False, 'contains(hounds)': False, 'contains(marshmallows)': False, 'contains(lick)': False, 'contains(hass)': False, 'contains(surges)': False, 'contains(watched)': False, 'contains(ivey)': False, 'contains(nuez)': False, 'contains(mentors)': False, 'contains(tricky)': False, 'contains(surveying)': False, 'contains(ditching)': False, 'contains(haystack)': False, 'contains(warriors)': False, 'contains(purged)': False, 'contains(rehabilitation)': False, 'contains(petitions)': False, 'contains(bogs)': False, 'contains(absense)': False, 'contains(courtesans)': False, 'contains(followed)': False, 'contains(har)': False, 'contains(anthesis)': False, 'contains(grotesqe)': False, 'contains(_i_know_what_you_did_last_summer_)': False, 'contains(survey)': False, 'contains(bartok)': False, 'contains(thivisol)': False, 'contains(exponential)': False, 'contains(birdie)': False, 'contains(cincinnati)': False, 'contains(unthrilling)': False, 'contains(balsan)': False, 'contains(bumming)': False, 'contains(celebrated)': False, 'contains(renovated)': False, 'contains(crowd)': False, 'contains(shows)': False, 'contains(lana)': False, 'contains(haskin)': False, 'contains(despite)': False, 'contains(scharzenegger)': False, 'contains(undergone)': False, 'contains(aissa)': False, 'contains(leit)': False, 'contains(mouth)': False, 'contains(demeaning)': False, 'contains(drilling)': False, 'contains(unsworth)': False, 'contains(bannister)': False, 'contains(wiseguy)': False, 'contains(lackies)': False, 'contains(norville)': False, 'contains(dampens)': False, 'contains(satisfactory)': False, 'contains(abuser)': False, 'contains(had)': False, 'contains(nature)': False, 'contains(awake)': False, 'contains(wiseguys)': False, 'contains(cerebrally)': False, 'contains(ballisitic)': False, 'contains(trauma)': False, 'contains(geography)': False, 'c ...

# %%
featuresets = [(document_features(d), c) for (d,c) in documents]
train_set, test_set = featuresets[100:], featuresets[:100]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.69

# %%
classifier.show_most_informative_features(5)
# Out:
# Most Informative Features
#           contains(sans) = True              neg : pos    =      9.0 : 1.0
#     contains(mediocrity) = True              neg : pos    =      7.7 : 1.0
#      contains(dismissed) = True              pos : neg    =      7.0 : 1.0
#          contains(wires) = True              neg : pos    =      6.3 : 1.0
#    contains(overwhelmed) = True              pos : neg    =      6.3 : 1.0

# %% [markdown]
# ## Problem: Sentiment Classification

# %%
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import movie_reviews

# %%
def word_feats(words):
    return dict([(word, True) for word in words])

# %%
negids = movie_reviews.fileids('neg')
posids = movie_reviews.fileids('pos')

# %%
negfeats = [(word_feats(movie_reviews.words(fileids=[f])), 'neg') for f in negids]
posfeats = [(word_feats(movie_reviews.words(fileids=[f])), 'pos') for f in posids]

# %%
negcutoff = int(len(negfeats)*3/4)
poscutoff = int(len(posfeats)*3/4)

# %%
trainfeats = negfeats[:negcutoff] + posfeats[:poscutoff]

# %%
testfeats = negfeats[negcutoff:] + posfeats[poscutoff:]
print 'train on %d instances, test on %d instances' % (len(trainfeats), len(testfeats))
# Out:
# train on 1500 instances, test on 500 instances

# %%
classifier = NaiveBayesClassifier.train(trainfeats)
print 'accuracy:', nltk.classify.util.accuracy(classifier, testfeats)
classifier.show_most_informative_features()
# Out:
# accuracy: 0.728
# Most Informative Features
#              magnificent = True              pos : neg    =     15.0 : 1.0
#              outstanding = True              pos : neg    =     13.6 : 1.0
#                insulting = True              neg : pos    =     13.0 : 1.0
#               vulnerable = True              pos : neg    =     12.3 : 1.0
#                ludicrous = True              neg : pos    =     11.8 : 1.0
#                   avoids = True              pos : neg    =     11.7 : 1.0
#              uninvolving = True              neg : pos    =     11.7 : 1.0
#               astounding = True              pos : neg    =     10.3 : 1.0
#              fascination = True              pos : neg    =     10.3 : 1.0
#                  idiotic = True              neg : pos    =      9.8 : 1.0
